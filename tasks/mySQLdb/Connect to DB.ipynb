# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from pathlib import Path

from db_setup import Base, Policy, engine, DBSession

# %%
session = DBSession()

# %%
for attribute, value in Policy.__dict__.items():
    print (attribute)
# Out:
# __module__
# __tablename__
# __table_args__
# id
# country
# geo_code
# source
# title
# reference
# authorship
# resume
# publication_date
# enforcement_date
# url
# doc_url
# doc_name
# doc_type
# doc_class
# doc_tags
# related_docs
# username
# timestamp
# save_to_db
# __doc__
# __table__
# _sa_class_manager
# __init__
# __mapper__

# %%
my_doc = Policy(geo_code = 'SLV', url = 'https://github.com/OmdenaAI/2', reference = 'CODIGO 1234', title ='MyTitle', source = "scraping", country='Salvador')

# %%
my_doc.save_to_db()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# &lt;ipython-input-12-707007c591b1&gt; in &lt;module&gt;
# ----&gt; 1 my_doc.save_to_db()
#
# g:\Omdena-WRI\wrilatinamerica\devops\db_setup.py in save_to_db(self)
#      34
#      35     def save_to_db(self):
# ---&gt; 36         session.add(self)
#      37         try:
#      38             session.commit()
#
# NameError: name &#39;session&#39; is not defined

# %%
# In case that your code throws an error you have to run session.rollback() before trying to do other things
session.rollback()

# %% [markdown]
# # Load csv to database

# %%
import pandas as pd

# %%
csv_path = Path.cwd().parent.joinpath('data').joinpath('external').joinpath('Scraped_Documents_Peru&Mexico.csv')
csv_path
# Out:
# WindowsPath(&#39;g:/Omdena-WRI/wrilatinamerica/data/external/Scraped_Documents_Peru&amp;Mexico.csv&#39;)

# %%
df = pd.read_csv(csv_path)

# %%
df.columns
# Out:
# Index([&#39;Unnamed: 0&#39;, &#39;index&#39;, &#39;country&#39;, &#39;title&#39;, &#39;reference&#39;, &#39;date&#39;,
#        &#39;category&#39;, &#39;url&#39;],
#       dtype=&#39;object&#39;)

# %%
for index, row in df.iterrows():
    my_doc = Policy()
    my_doc.country = row['country']
    my_doc.title = row['title']
    my_doc.reference = row['reference']
    my_doc.publication_date = row['date'] # the date has to be in the correct format, currently this produces '0000-00-00' in the database
    my_doc.doc_class = row['category']
    my_doc.doc_url = row['url']
    my_doc.save_to_db()
    #print(row['country'], row['title'])
# Out:
# el financiamiento de  has successfully been added to the database
# None Designan Director Ejecutivo de la Oficina General de Asesoría Jurídica del SIS has successfully been added to the database
# None Encargan el Puesto de Jefe de la Unidad de Asesoría Jurídica de la Autoridad Portuaria Nacional has successfully been added to the database
# None Designan temporalmente Responsable de entregar la información pública solicitada al CONCYTEC has successfully been added to the database
# None Designan Gerente General del Instituto Geológico, Minero y Metalúrgico - INGEMMET has successfully been added to the database
# None Modifican la Resolución de Presidencia del Consejo Directivo N° 094-2019-OEFA/PCD, sobre delegación  has successfully been added to the database
# None Designan Intendente de la Intendencia de Fiscalización y Sanción has successfully been added to the database
# None Disponen conformación de la Sala Civil Permanente de la Corte Suprema de Justicia has successfully been added to the database
# None Crean el “Registro Distrital de Casillas Electrónicas Institucionales para fines de Emplazamientos J has successfully been added to the database
# None Aprueban la Directiva “Asistencia técnica de la Contraloría General de la República, en el marco de  has successfully been added to the database
# None Convocan a ciudadana para que asuma el cargo de regidora del Concejo Distrital de Chiguirip, provinc has successfully been added to the database
# None Declaran Nulo todo lo actuado a partir del acto de notificación de la convocatoria a la Sesión Extra has successfully been added to the database
# None Confirman Resolución que sancionó a organización política con multa por no haber cumplido con presen has successfully been added to the database
# None Convocan a ciudadana para que asuma el cargo de regidora del Concejo Distrital de Tigre, provincia y has successfully been added to the database
# None Declaran infundada solicitud de vacancia presentada contra alcalde de la Municipalidad Distrital de  has successfully been added to the database
# None Disponen la suspensión de labores en los despachos fiscales cuya competencia territorial se encuentr has successfully been added to the database
# None Crean Fiscalías Provinciales Corporativas Especializadas en Violencia Contra la Mujer y los Integran has successfully been added to the database
# None Dejan sin efecto el nombramiento de Fiscal Adjunta Provincial Provisional del Distrito Fiscal de Lim has successfully been added to the database
# None Aceptan renuncia de Fiscal Adjunta Provincial Provisional del Distrito Fiscal de Lima Norte has successfully been added to the database
# None Autorizan al Banco Azteca del Perú S.A. el cierre de seis agencias y una oficina especial ubicadas e has successfully been added to the database
# None Modifican los artículos 22 y 60 del Reglamento de Atención de Reclamos y Solución de Controversias d has successfully been added to the database
# None FE DE ERRATAS has successfully been added to the database
# None Aprueban los “Lineamientos para autorizar la realización de estudios del patrimonio en el marco del  has successfully been added to the database
# None Modifican los “Lineamientos técnicos para la ejecución de inspecciones oculares previas a la aprobac has successfully been added to the database
# None Crean la Unidad de Evaluación de Riesgos de Alimentos Agropecuarios Primarios y Piensos, como unidad has successfully been added to the database
# None Designan Secretaria General del Ministerio has successfully been added to the database
# None Aprueban Normas Técnicas Peruanas en su versión 2020 referidas a vehículos ferroviarios y otros has successfully been added to the database
# None Designan Director General de la Dirección General de Desarrollo Empresarial del Despacho Viceministe has successfully been added to the database
# None Designan Ejecutiva Adjunta II del Despacho Ministerial has successfully been added to the database
# None Autorizan a DEVIDA efectuar transferencia financiera a favor de la Embajada de los Estados Unidos de has successfully been added to the database
# None Designan Asesora de la Alta Dirección del INDECI has successfully been added to the database
# None Resolución de Superintendencia que modifica la Resolución de Superintendencia N° 303-2016/SUNAT resp has successfully been added to the database
# None Aprueban la expedición del Certificado Registral Inmobiliario (CRI), con firma electrónica y código  has successfully been added to the database
# None Autorizan a Mitsui Auto Finance Perú S.A. el cierre definitivo de oficina especial ubicada en el dis has successfully been added to the database
# None Aprueban el Reglamento de la Reserva Técnica de Siniestros, modifican el Plan de Cuentas para empres has successfully been added to the database
# None Inscriben a ciudadanos y ciudadanas en el Registro Nacional de Intérpretes y Traductores de Lenguas  has successfully been added to the database
# None Aprueban el Texto Integrado actualizado del Reglamento de Organización y Funciones del Ministerio de has successfully been added to the database
# None Designan Director II de la Oficina de Administración del CONADIS has successfully been added to the database
# None Designan Director de la Oficina de Asesoría Jurídica del CONADIS has successfully been added to the database
# None Designan Director General de la Oficina General de Recursos Humanos del Ministerio has successfully been added to the database
# None Designan Asesor II - Jefe de Gabinete de Asesores del Despacho Ministerial has successfully been added to the database
# None Designan Directora de la Oficina de Seguridad y Defensa Nacional de la Secretaría General del Minist has successfully been added to the database
# None Designan Asesores II de la Secretaría General del Ministerio has successfully been added to the database
# None RESOLUCIÓN MINISTERIAL has successfully been added to the database
# None RESOLUCIÓN MINISTERIAL has successfully been added to the database
# None Designan Secretario General del Ministerio has successfully been added to the database
# None Designan Director de la Oficina de Tesorería de la Oficina General de Administración del Ministerio has successfully been added to the database
# None Autorizan Transferencia Financiera a favor de la Organización Panamericana de la Salud (OPS/OMS) par has successfully been added to the database
# None Aprueban la NTS N° 163-MINSA/2020/CDC, Norma Técnica de Salud para la Vigilancia de las Infecciones  has successfully been added to the database
# None Designan Jefa de Equipo del Despacho Ministerial has successfully been added to the database
# None Disponen archivo definitivo de expediente relativo a proceso de vacancia seguido contra alcalde de l has successfully been added to the database
# None Convocan a ciudadano para que asuma el cargo de consejero del Consejo Regional de Loreto por la prov has successfully been added to the database
# None Convocan a ciudadano para que asuma el cargo de regidor del Concejo Distrital de Samugari, provincia has successfully been added to the database
# None Convocan a ciudadano para que asuma el cargo de regidor del Concejo Distrital de Miraflores, provinc has successfully been added to the database
# None Convocan a ciudadanos para que asuman cargos de alcalde y regidor de la Municipalidad Distrital de P has successfully been added to the database
# None Convocan a ciudadana para que asuma el cargo de regidora del Concejo Distrital de Macate, provincia  has successfully been added to the database
# None Cancelan inscripción de persona natural en el Registro de Intermediarios y Auxiliares de Seguros, Em has successfully been added to the database
# None Autorizan inscripción de persona natural en el Registro de Intermediarios y Auxiliares de Seguros, E has successfully been added to the database
# None Autorizan transferencia financiera a favor de diversas municipalidades distritales, para la ejecució has successfully been added to the database
# None Prorrogan el plazo de vencimiento de beneficios establecidos en la Ordenanza N° 586/MDC “Beneficio d has successfully been added to the database
# None Ordenanza que define los lineamientos para determinar giros afines o complementarios y señala giros  has successfully been added to the database
# None Disponen la postergación de la Convocatoria y Cronograma Electoral del Proceso de Elección de Delega has successfully been added to the database
# None Aprueban Ordenanza para el Programa de Vivienda de Ventanilla - PROVIVE, y establecen procedimientos has successfully been added to the database
# None Decreto Supremo que modifica el Decreto Supremo N° 116-2020-PCM, Decreto Supremo que establece las m has successfully been added to the database
# None Aprueban el “Padrón del segundo grupo de hogares beneficiarios en el ámbito rural del subsidio monet has successfully been added to the database
# None Autorizan Transferencia de Partidas en el Presupuesto del Sector Público para el Año Fiscal 2020 a f has successfully been added to the database
# None None has successfully been added to the database
# None FE DE ERRATAS has successfully been added to the database
# None Designan responsables de brindar la información de Acceso Público en la Dirección Zonal Puno del Pro has successfully been added to the database
# None Autorizan Transferencia de Partidas en el Presupuesto del Sector Público para el Año Fiscal 2020 a f has successfully been added to the database
# None Autorizan Transferencia de Partidas en el Presupuesto del Sector Público para el Año Fiscal 2020 a f has successfully been added to the database
# None Autorizan Transferencia de Partidas en el Presupuesto del Sector Público para el Año Fiscal 2020 a f has successfully been added to the database
# None Aprueban el documento normativo denominado “Disposiciones para la evaluación extraordinaria del proc has successfully been added to the database
# None Aprueban el “Diseño Curricular Básico Nacional de la Formación Inicial Docente - Programa de Estudio has successfully been added to the database
# None Designan Presidenta del Consejo Directivo del Instituto Geológico, Minero y Metalúrgico - INGEMMET has successfully been added to the database
# None Delegan en el/la Procurador/a Público/a del Ministerio la facultad y atribución de aprobar la design has successfully been added to the database
# None Decreto Supremo que autoriza al Organismo Nacional de Sanidad Pesquera (SANIPES) a desarrollar un pr has successfully been added to the database
# None Disponen la publicación del proyecto de “Resolución Ministerial que establece los instrumentos de pe has successfully been added to the database
# None Designan Viceministro de MYPE e Industria del Ministerio de la Producción has successfully been added to the database
# None Dan término al nombramiento de Viceministro de Relaciones Exteriores has successfully been added to the database
# None Nombran Viceministro de Relaciones Exteriores has successfully been added to the database
# None Designan Asesora II del Despacho Viceministerial de Promoción del Empleo y Capacitación Laboral has successfully been added to the database
# None Designan Directora de Sistema Administrativo II de la Secretaría del Ministerio has successfully been added to the database
# None Otorgan a la empresa FIBERTEL PERU S.A., concesión para la prestación de los Servicios Públicos Móvi has successfully been added to the database
# None Otorgan a la empresa TELECOMUNICACIONES DAMAED S.A.C., Concesión Única para la prestación de los ser has successfully been added to the database
# None Designan Asesora II de la Secretaría General del Ministerio has successfully been added to the database
# None Designan Director de la Dirección de la Escuela de Bomberos de la INBP has successfully been added to the database
# None Autorizan transferencia financiera a favor del Pliego 019: Contraloría General de la República has successfully been added to the database
# None Aprueban la lista de beneficiarios del subsidio Bono Electricidad has successfully been added to the database
# None Designan Profesional V de la Dirección Ejecutiva de PROINVERSIÓN has successfully been added to the database
# None Aceptan renuncia de miembro del Consejo Consultivo has successfully been added to the database
# None Disponen que los Presidentes de las Cortes Superiores de Justicia del país habiliten en los accesos  has successfully been added to the database
# None Cesan por límite de edad a magistrada en el cargo de Jueza de Paz Letrado de la Provincia de Huaraz, has successfully been added to the database
# None Prorrogan funcionamiento de órganos jurisdiccionales para el juzgamiento de funcionarios comprendido has successfully been added to the database
# None Prorrogan funcionamiento de la Segunda Sala de Derecho Constitucional y Social Transitoria de la Cor has successfully been added to the database
# None Aprueban el documento denominado “Instructivo para el Cálculo de Aranceles por los Servicios Prestad has successfully been added to the database
# None Prorrogan funcionamiento de órganos jurisdiccionales transitorios de las Cortes Superiores de Justic has successfully been added to the database
# None Disponen la permanencia de magistrada como Juez Supernumeraria del 8º Juzgado de Paz Letrado de Surc has successfully been added to the database
# None Reconforman el Subcomité de Seguridad y Salud en el Trabajo de la Corte Superior de Justicia de Lima has successfully been added to the database
# None Dan por concluidas designaciones, reeligen y designan a Fiscales Supremos como representantes titula has successfully been added to the database
# None Aprueban modificación del Estatuto Social de la empresa Integro Andina S.A.C. Corredores de Reasegur has successfully been added to the database
# None Autorizan a la Caja Municipal de Ahorro y Crédito de Arequipa S.A. el traslado de agencias ubicadas  has successfully been added to the database
# None Autorizan inscripción de persona natural en el Registro de Intermediarios y Auxiliares de Seguros, E has successfully been added to the database
# None Autorizan inscripción de persona natural en el Registro de Intermediarios y Auxiliares de Seguros, E has successfully been added to the database
# None Aprueban la Transferencia del Proyecto de Inversión Pública: “Puesta en valor del atractivo turístic has successfully been added to the database
# None Autorizan Transferencia Financiera en la modalidad de aporte para el cumplimiento del Plan Operativo has successfully been added to the database
# None Disponen el embanderamiento general en el distrito has successfully been added to the database
# None Ordenanza que aprueba medidas de prevención y control para evitar la propagación del COVID-19 en el  has successfully been added to the database
# None Aprueban el Plan de Desarrollo Turístico Local (PDTL) del distrito de Miraflores 2021 - 2025 has successfully been added to the database
# None Ordenanza que aprueba el Plan Distrital de Seguridad Ciudadana 2020 has successfully been added to the database
# None Disponen el embanderamiento general del distrito has successfully been added to the database
# None Complementan el artículo 6° de la Ordenanza N° 411/MDSM y establecen disposiciones para el otorgamie has successfully been added to the database
# None Aprueban Reglamento que regula el Procedimiento de la Notificación Electrónica de los Actos emitidos has successfully been added to the database
# None Aprueban la Guía Técnica para los establecimientos que expenden alimentos y productos con modalidad  has successfully been added to the database
# None Ordenanza que establece la Recuperación de las Vías Públicas Ocupadas por el Comercio Ambulatorio, C has successfully been added to the database
# None None has successfully been added to the database
# None FE DE ERRATAS has successfully been added to the database
# None Autorizan una Transferencia de Partidas en el Presupuesto del Sector Público para el Año Fiscal 2020 has successfully been added to the database
# None Autorizan Transferencia de Partidas en el Presupuesto del Sector Público para el Año Fiscal 2020 a f has successfully been added to the database
# None Autorizan Transferencia de Partidas en el Presupuesto del Sector Público para el Año Fiscal 2020 a f has successfully been added to the database
# None Autorizan Transferencia de Partidas en el Presupuesto del Sector Público para el Año Fiscal 2020 a f has successfully been added to the database
# None Designan Director de la Oficina General de Administración de la PCM has successfully been added to the database
# None Aprueban el “Protocolo Sanitario ante el COVID-19 para la atención de visitas turísticas en las Área has successfully been added to the database
# None Prorrogan el plazo de la determinación de la protección provisional del Sitio Arqueológico “Santa Lu has successfully been added to the database
# None Aprueban el Texto Único de Servicios No Exclusivos – TUSNE del Centro de Altos Estudios Nacionales – has successfully been added to the database
# None Aprueban la desagregación de los recursos autorizados mediante el D.S. N° 194-2020-EF, en el Presupu has successfully been added to the database
# None Designan Asesor, Coordinador Parlamentario, del Gabinete de Asesores del Despacho Ministerial has successfully been added to the database
# None Designan Jefe de Gabinete de Asesores del Despacho Ministerial has successfully been added to the database
# None Designan Jefa de la Oficina General de Comunicación Estratégica del Ministerio has successfully been added to the database
# None Designan Jefe de la Oficina General de Planeamiento, Presupuesto y Modernización del Ministerio has successfully been added to the database
# None Disponen la publicación del proyecto de Decreto Supremo que aprueba el Reglamento del Decreto de Urg has successfully been added to the database
# None Disponen la publicación del proyecto de Resolución Ministerial que aprueba los “Contenidos para la F has successfully been added to the database
# None Aprueban asignación financiera de recursos provenientes del Fondo Especial para la Seguridad Ciudada has successfully been added to the database
# None Aprueban la desagregación de recursos aprobados en el D.S. N° 194-2020-EF, a fin de financiar las tr has successfully been added to the database
# None Designan Directora General de la Oficina General de Comunicación Social e Imagen Institucional has successfully been added to the database
# None Designan Asesora II del Despacho Viceministerial de Orden Interno has successfully been added to the database
# None Aceptan renuncia de Viceministro de Justicia has successfully been added to the database
# None Designan Viceministra de Justicia has successfully been added to the database
# None FE DE ERRATAS has successfully been added to the database
# None Aprueban el “Padrón del segundo grupo de hogares beneficiarios en el ámbito urbano del subsidio mone has successfully been added to the database
# None Designan Asesora II del Despacho Ministerial has successfully been added to the database
# None Designan Directora de la Oficina de Comunicaciones e Imagen Institucional has successfully been added to the database
# None Designan Director General de la Oficina General de Planeamiento y Presupuesto has successfully been added to the database
# None Aprueban transferencia financiera para financiar las prestaciones de salud no tarifadas, brindadas a has successfully been added to the database
# None Aprueban el “Procedimiento Tarifario aplicable en el marco del mecanismo de Apoyo del Concedente por has successfully been added to the database
# None Aprueban las “Disposiciones Temporales para la prestación del servicio del Sistema Eléctrico de Tran has successfully been added to the database
# None Aprueban el Reglamento para el Proceso de Elección de Miembros de los Consejos de Usuarios de la Sun has successfully been added to the database
# None Designan responsable de elaborar y actualizar el Portal de Transparencia del INAIGEM has successfully been added to the database
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# &lt;ipython-input-10-981290c4e355&gt; in &lt;module&gt;
#       7     my_doc.doc_class = row[&#39;category&#39;]
#       8     my_doc.doc_url = row[&#39;url&#39;]
# ----&gt; 9     my_doc.save_to_db()
#      10     #print(row[&#39;country&#39;], row[&#39;title&#39;])
#
# g:\Omdena-WRI\wrilatinamerica\devops\db_setup.py in save_to_db(self)
#      38         try:
#      39             session.commit()
# ---&gt; 40             return print(str(self.source)+ &#39; &#39; +  str(self.title) + &#39; has successfully been added to the database&#39;)
#      41         except Exception as e:
#      42             session.rollback()
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\attributes.py in __get__(self, instance, owner)
#     285             return dict_[self.key]
#     286         else:
# --&gt; 287             return self.impl.get(instance_state(instance), dict_)
#     288
#     289
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\attributes.py in get(self, state, dict_, passive)
#     716
#     717                 if key in state.expired_attributes:
# --&gt; 718                     value = state._load_expired(state, passive)
#     719                 elif key in state.callables:
#     720                     callable_ = state.callables[key]
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\state.py in _load_expired(self, state, passive)
#     650         toload = self.expired_attributes.intersection(self.unmodified)
#     651
# --&gt; 652         self.manager.deferred_scalar_loader(self, toload)
#     653
#     654         # if the loader failed, or this
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\loading.py in load_scalar_attributes(mapper, state, attribute_names)
#    1010             identity_key,
#    1011             refresh_state=state,
# -&gt; 1012             only_load_props=attribute_names,
#    1013         )
#    1014
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\loading.py in load_on_ident(query, key, refresh_state, with_for_update, only_load_props)
#     204         with_for_update=with_for_update,
#     205         only_load_props=only_load_props,
# --&gt; 206         identity_token=identity_token,
#     207     )
#     208
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\loading.py in load_on_pk_identity(query, primary_key_identity, refresh_state, with_for_update, only_load_props, identity_token)
#     284
#     285     try:
# --&gt; 286         return q.one()
#     287     except orm_exc.NoResultFound:
#     288         return None
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\query.py in one(self)
#    3461         &quot;&quot;&quot;
#    3462         try:
# -&gt; 3463             ret = self.one_or_none()
#    3464         except orm_exc.MultipleResultsFound as err:
#    3465             util.raise_(
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\query.py in one_or_none(self)
#    3430
#    3431         &quot;&quot;&quot;
# -&gt; 3432         ret = list(self)
#    3433
#    3434         l = len(ret)
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\query.py in __iter__(self)
#    3506         if self._autoflush and not self._populate_existing:
#    3507             self.session._autoflush()
# -&gt; 3508         return self._execute_and_instances(context)
#    3509
#    3510     def __str__(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\orm\query.py in _execute_and_instances(self, querycontext)
#    3531         )
#    3532
# -&gt; 3533         result = conn.execute(querycontext.statement, self._params)
#    3534         return loading.instances(querycontext.query, result, querycontext)
#    3535
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -&gt; 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --&gt; 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -&gt; 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -&gt; 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1512                 )
#    1513             else:
# -&gt; 1514                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1515
#    1516         finally:
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --&gt; 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
#    1276                     self.dialect.do_execute(
# -&gt; 1277                         cursor, statement, parameters, context
#    1278                     )
#    1279
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --&gt; 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --&gt; 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --&gt; 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, &#39;surrogateescape&#39;)
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --&gt; 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --&gt; 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\pymysql\connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -&gt; 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     644         buff = bytearray()
#     645         while True:
# --&gt; 646             packet_header = self._read_bytes(4)
#     647             #if DEBUG: dump_packet(packet_header)
#     648
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     681         while True:
#     682             try:
# --&gt; 683                 data = self._rfile.read(num_bytes)
#     684                 break
#     685             except (IOError, OSError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\envs\wrilatinamerica\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --&gt; 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
session.close()
