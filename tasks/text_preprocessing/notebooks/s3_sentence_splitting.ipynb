# %% [markdown]
# # Pipeline to split sentences and store them in S3 bucket

# %% [markdown]
# - Methods for sentence splitting

# %%
import re
import random
import nltk.data
import spacy 
import string
from collections import Counter
from collections import defaultdict
import nltk
import uuid
import json
import boto3
import csv
import s3fs
import codecs
import fasttext

path_to_pretrained_model = "/Users/dafirebanks/Projects/models/fasttext/lid.176.bin"
fmodel = fasttext.load_model(path_to_pretrained_model)

en_tokenizer = nltk.data.load("tokenizers/punkt/english.pickle")
es_tokenizer = nltk.data.load("tokenizers/punkt/spanish.pickle")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
def remove_html_tags(text):
    """Remove html tags from a string"""
    return re.sub(re.compile('<.*?>'), '', text)

def replace_links(text):
    text = re.sub(r'http\S+', '[URL]', text)
    return re.sub(r'www\S+', '[URL]', text)

def remove_multiple_spaces(text):
    return re.sub('\s+', ' ', text)

def parse_emails(text):
    """ 
    Remove the periods from emails in text, except the last one
    """
    emails = [email if email[-1] != "." else email[:-1] for email in re.findall(r"\S*@\S*\s?", text)]
    
    for email in emails:
        new_email = email.replace(".", "")
        text = text.replace(email, new_email)
        
    return text

def parse_acronyms(text):
    """ 
    Remove the periods from acronyms in the text (i.e "U.S." becomes "US") 
    """

    acronyms = re.findall(r"\b(?:[a-zA-Z]\.){2,}", text)
         
    for acronym in acronyms:
        new_acronym = acronym.replace(".", "")
        text = text.replace(acronym, new_acronym)
        
    return text

def english_preprocessing(txt):
    """
    Steps in the preprocessing of text:
        1. Remove HTML tags
        2. Replace URLS by a tag [URL]
        3. Replace new lines and tabs by normal spaces - sometimes sentences have new lines in the middle
        4. Remove excessive spaces (more than 1 occurrence)
        5. Parse abreviations and acronyms
    """
    txt = replace_links(remove_html_tags(txt)).strip()#.replace("\n", " ").replace("\t", " ").strip()
    txt = remove_multiple_spaces(txt)
    txt = parse_emails(txt)
    txt = parse_acronyms(txt)
    
    new_txt = ""
    all_period_idx = set([indices.start() for indices in re.finditer("\.", txt)])
    
    for i, char in enumerate(txt):
        if i in all_period_idx:
            # Any char following a period that is NOT a space means that we should not add that period
            if i + 1 < len(txt) and txt[i + 1] != " ":
                continue
            
            # Any char that is a number following a period will not count. 
            # For enumerations, we're counting on docs being enumerated as "(a)" or "(ii)", and if not, they will be separated by the . after the number ("3. Something" will just be "Something" as a sentence)
            if i + 2 < len(txt) and txt[i + 2].isnumeric(): 
                continue
            
            # If we wanted to have all numbered lists together, uncomment this, and comment out the previous condition
#             if i + 2 < len(txt) and not txt[i + 2].isalpha(): 
#                 continue
            
        new_txt += char

    return new_txt

def english_postprocessing(sents, min_num_words=4):
    """
    Remove sentences that are made of less than a given number of words. Default is 4
    """
    
    return [sent for sent in sents if len(sent.split()) >= min_num_words]

def get_nltk_sents(txt, tokenizer, extra_abbreviations=None):
    if extra_abbreviations:
        tokenizer._params.abbrev_types.update(extra_abbreviations)
        
    sents = tokenizer.tokenize(txt)
    return sents

def aws_credentials_from_file(f_name):
    with open(f_name, "r") as f:
        creds = json.load(f)
    
    return creds["aws"]["id"], creds["aws"]["secret"]

def format_sents_for_output(sents, doc_id):
    formatted_sents = {}

    for i, sent in enumerate(sents):
        formatted_sents.update({f"{doc_id}_sent_{i}": {"text": sent, "label": []}})

    return formatted_sents


def output_sents(sents, f_name, f_uuid, country, bucket, output_dir):

    sents_json = {}
    fformat = f_name.split(".")[-1]
    sents_json[f_uuid] = {"metadata":
                              {"n_sentences": len(sents),
                               "file_name": f_name,
                               "file_format": fformat,
                               "country": country},
                          "sentences": format_sents_for_output(sents, f_uuid)}
    
    s3.Object(bucket, f"{output_dir}/{f_uuid}_sents.json").put(Body=(json.dumps(sents_json, indent=4)))
    
    
def filenames_for_country(country, s3, bucket):
    metadata_fname = f"metadata/{country}_metadata.csv"
    obj = s3.Object(bucket_name = bucket, key = metadata_fname)
    
    filenames = []
    i = 0
    for row in csv.reader(codecs.getreader("utf-8")(obj.get()['Body'])):
        # Add original file ID without the file format
        filenames.append(row[3][:-4])
    
    return filenames

# %% [markdown]
# - Actual pipeline
#
# Reads from the S3 Bucket english documents, outputs to test_sentences
#
#
# Format of credentials JSON file:
# ```
# {
#     "aws": {
#         "id": "AWS ID",
#         "secret": "AWS SECRET"
#     }
# }
# ```

# %%
# Connection to AWS Jordi's way
folder = '/home/propietari/Documents/claus/' # TODO: change to your local path
file_name = 'AWS_S3_keys_wri.json' # TODO: Change to your filename
file = folder + file_name

with open(file, 'r') as dict:
    credentials = json.load(dict)
                                      
aws_id = list(credentials)[0]
aws_secret = list(credentials.values())[0]
region = 'us-east-1'
bucket = "wri-nlp-policy"
countries = ['India', 'USA']
s3 = boto3.resource(
    service_name = 's3',
    region_name = region,
    aws_access_key_id = aws_id,
    aws_secret_access_key = aws_secret
)

# %%
credentials_file = '/Users/dafirebanks/Documents/credentials.json'
aws_id, aws_secret = aws_credentials_from_file(credentials_file)
region = 'us-east-1'

s3 = boto3.resource(
    service_name = 's3',
    region_name = region,
    aws_access_key_id = aws_id,
    aws_secret_access_key = aws_secret
)

bucket = 'wri-nlp-policy'
countries = ['India', 'USA']

# %% [markdown]
# This pipeline is ready to be ran on the India documents only

# %%
# Define abbreviations per country - this can work for all english documents
usa_abrevs = {"no", "sec", "cong", "dist", "doc"}
india_abrevs = {"sub", "subs", "ins", "govt", "dy", "dept", "deptt", "ptg"} 

# Define country and output directory in S3 bucket
country = "India"
out_dir = "english_documents/test_sentences"
select_filenames = filenames_for_country(country, s3, bucket)

i = 0
for obj in s3.Bucket(bucket).objects.all().filter(Prefix="english_documents/text_files/"):
    
    # Don't get the directory itself
    if not obj.key.endswith("/"):
        file_id = obj.key.replace("english_documents/text_files/", "").replace(".txt", "")
        if file_id in select_filenames:
            text = obj.get()['Body'].read().decode('utf-8')
            preprocessed = english_preprocessing(text)
            # NOTE: Change abreviations in the future specific to country
            sents = get_nltk_sents(preprocessed, en_tokenizer, india_abrevs)
            post_processed_sents = english_postprocessing(sents, min_num_words=5)
            output_sents(post_processed_sents, obj.key, file_id, country, bucket, out_dir)

    i += 1
    if i == 2:
        break
    if i % 100 == 0:
        print(f"Processed {i} documents")

# %% [markdown]
# #### This cell incorporates the language detection

# %%
all_abrevs = {"no", "sec", "cong", "dist", "doc", "sub", "subs", "ins", "govt", "dy", "dept", "deptt", "ptg"} 

# Define country and output directory in S3 bucket
country = "India"
out_dir = "english_documents/test_sentences/processed"
select_filenames = filenames_for_country(country, s3, bucket)

i = 0
for obj in s3.Bucket(bucket).objects.all().filter(Prefix = "english_documents/text_files/new/"):
    
    # Don't get the directory itself
    if not obj.key.endswith("/"):
        file_id = obj.key.replace("english_documents/text_files/new/", "").replace(".txt", "")
        if file_id in select_filenames:
#             # Uncomment to do language detection before sentence splitting
#             text = ''
#             line_i = 0
#             for line in obj.get()['Body'].read().splitlines():
#                 line = line.decode('utf-8')
#                 try:
#                     result = fmodel.predict([line])
#                     print("--------------")
#                     print("Line:", line, " || Language:", result[0][0][-2:])
#                     print("--------------")
#                     if result[0][0][0][-2:] == 'en' and result[1][0][0] > 0.7:
#                         text = text + line + "\n"
#                         print(">>>>>>>>>>> English sentence:", line)
#                     line_i += 1
#                     if line_i == 100:
#                         break
#                 except:
#                     print("*** ", line)
#                     continue
#             text = obj.get()['Body'].read().decode('utf-8')
#             preprocessed = english_preprocessing(text)
#             # NOTE: Change abreviations in the future specific to country
#             sents = get_nltk_sents(preprocessed, en_tokenizer, all_abrevs)
#             post_processed_sents = english_postprocessing(sents, min_num_words=5)
#             ---------------------------------------------------------------------------
#             # Uncomment if you want to apply language detection after sentence splitting
#             sent_i = 0
#             for sent in post_processed_sents:
#                 try:
#                     result = fmodel.predict(sent)
#                     print("--------------")
#                     print("Sentence:", sent, " || Language:", result[0][0][-2:])
#                     print("--------------")
#                     if result[0][0][0][-2:] == 'en' and result[1][0][0] > 0.7:
#                         print(">>>>> English sentence:", sent)
#                     sent_i += 1
#                     if sent_i == 100:
#                         break
#                 except:
#                     print("*** ", sent)
#                     continue

#             output_sents(post_processed_sents, obj.key, file_id, country, bucket, out_dir)

    i += 1
    if i == 2:
        break
    if i % 100 == 0:
        print(f"Processed {i} documents")
# Out:
# --------------
# Sentence: 137 (72) PTSTENT 2101-97, TORER 21, 2002 4 (TT) 4 (") (2) The words and expressions used but not defined in CAD & WU DEPARTMENT thece urles have the same meaning as are respectively assigned NOTIFICATION to them in the Act.  || Language: en
# --------------
# --------------
# Sentence: THE RAJASTHAN FARMERS' PARTICIPATION IN CHAPTER-II MANAGEMENT OF IRRICATION SYSTEMS FORMATION OF TERRITORIAL CONSTITUENCIES RULES, 2002 3.  || Language: en
# --------------
# --------------
# Sentence: Formation of territorial constituencies-(1) Every Jaipur, October 22, 2002.  || Language: en
# --------------
# --------------
# Sentence: G. S. R 80--In exercise of the powers conferred by in water users area shall divided by the Project Authority in to section 47 of the Rajasthan Farmers' Participation such number of territorial constituencies as given below- 2000), the State Government hereby makes the following Management of Irrigation Systems Act, 2000 (Act No 21 of Area of Water Users Number of Association territorial rules, namely- constituencies CHAPTER-I up to 1000 hectares four Preliminary From 1001 to 1500 hectares six 1.  || Language: en
# --------------
# --------------
# Sentence: Short title and commencement-(1 These rules may be called the Rajasthan Farmers' Participation in From 1501 to 2000 hectares eight Management of Irrigation Systems rules, 2002. more than 2000 hectares ten (2) They shall come in to force from the date of their (2) While dividing a water users area in to territorial publication in the Official Gazette.  || Language: en
# --------------
# --------------
# Sentence: constituencies, project authority shall as far as practicable, 2.  || Language: en
# --------------
# --------------
# Sentence: Definition-(1) In these rules unless the context place area under a direct pipeline or a pipe out let in a otherwise requires,- territorial constituency.  || Language: en
# --------------
# --------------
# Sentence: (a) "Act" means Rajasthan Farmers' Participation in (3) Each constituency shall be assigned a separate Management of Irrigation Systems Act, 2000 (Act serial number.  || Language: en
# --------------
# --------------
# Sentence: No 21 of 2000); "Commissioner" means the Commissioner (4) Map/sketch of each water users area showing the (b) appointed under section 35 of the Act; boundaries of territorial constituencies shall be prepared by "Election Officer" means officer appointed by the Project Authority.  || Language: en
# --------------
# --------------
# Sentence: List containing the survey numbers of (c) project authority for conduct of election of the land situated in each territorial constituency shall also be Farmers' Organization; prepared by the Project Authority.  || Language: en
# --------------
# --------------
# Sentence: "Electoral Registration Officer" means Officer (5) Map/Sketch and list prepared under sub rule (4) (d) appointed as such by the Project Authority for shall be published by Project Authority by affixing them on the preparation of voter list of constituency of the notice board of the office of the Project Authority and Water Users Association; notice board of the concerned panchayat, Water User's (e) "Form" means form appended to these rules; Association, Distributory Committee for information of water and users who are land owners.  || Language: en
# --------------
# --------------
# Sentence: (f) "Irrigation Agency" means Irrigation Department (6) Any adult member of water users area may, if he or Command Area Development Department or objects to any thing contained in the map/sketch or list Indira Gandhi Canal Department as the case published under sub-rule 5, may submit his objection 1, may be 137 (74) 27572117 2131991 "- FOLER 21, 2002 4 (71) writing to the Project Authority within seven day's from the 41171 i ("I) 21315417 TOTER 21, 2002 137 (75) date of affixing of such nap/sketch and list.  || Language: en
# --------------
# --------------
# Sentence: (7) All objection received under sub-rule (6), shall be objects to the inclusion of his own name or the name of any affixed on the notice board of the office of the Project other person in that roll, may prefer a claim or objection Authority.  || Language: en
# --------------
# --------------
# Sentence: After time prescribed for receipt of objection is personally or by sending it by post to the Electoral Registration over, the Project Authority.  || Language: en
# --------------
# --------------
# Sentence: shall consider the objection if any Office.  || Language: en
# --------------
# --------------
# Sentence: All objections or claims shall be received within the received and shall decide the objections and there after amend, period prescribed under sub-rule (2) of rule 4 and no claim or if necessary, the Map/sketch and list prepared under sub- objection received after that time shall be entertained.  || Language: en
# --------------
# --------------
# Sentence: rule (4) and finally determine the area of each territorial (2) Every claim shall be in Form-I and shall be signed constituency and shall publish the same by affixing final by the person desiring his name to be included in the electoral map/sketch and list of survey number included in each roll.  || Language: en
# --------------
# --------------
# Sentence: constituency on the notice board of office of the Project (3) Every objection to the inclusion of name in the Authority, Panchyat, Water Users Association and Distributory electoral roll shall be in Form Il and preferred by the person Committee concerned.  || Language: en
# --------------
# --------------
# Sentence: whose name is already included in the electoral roll of any CHAPTER-III territorial constituency of Wate Users' Association Voter List concerned 4.  || Language: en
# --------------
# --------------
# Sentence: Preparation of voters list-(1) The Tehsildar of the (-)) Every objection to a particular or particulars of area shall prepare list of Water Users who are land owners entry in the electoral roll shall be in Form-III and shall only and renew it every year during the month of January on the be preferred by the person to whom such entry relates.  || Language: en
# --------------
# --------------
# Sentence: basis of record of land rights and sent it to the Project (5) A claim or objection may be accompanied by the Authority as well as to the Water Useres' Association documents on which the claimant or objector relies.  || Language: en
# --------------
# --------------
# Sentence: concerned by 31st of January.  || Language: en
# --------------
# --------------
# Sentence: On the basis of the list so (6) No claim or objection shall be entertained unless a prepared the Electoral Registration Officer shall prepare or copy of such claim or objection has been left in the office of cause to be prepared territorial constituency wise members the Tehsildar concerned.  || Language: en
# --------------
# --------------
# Sentence: list consisting of those land holders who have been shown as 6.  || Language: en
# --------------
# --------------
# Sentence: Disposal of claims and objection-(1 The Electoral adults in the list prepared by the Tehsildar of the area.  || Language: en
# --------------
# --------------
# Sentence: Registration Officer before deciding whether or not to allow (2) The list prepared under sub rule (1) shall be the claim or objection cause notice to be served- displayed on the notice board of the office of the Project (a) In the case of a claim on the claimant; Authority concerned Gram Panchayat and Water User's (b) Association along with a notice inviting objections and fixing In the case of an objector to a particular or particulars in an entry, to the objector and on date and time by which objection shall be entertained.  || Language: en
# --------------
# --------------
# Sentence: the person to the inclusion of whose name the 5.  || Language: en
# --------------
# --------------
# Sentence: Claims and objection--11 Any person, whose name objection relates; is not entered in electoral roll or is entered at an incorrect (c) In the case of an objection to a particular or place or in an incorrect manner or with incorrect particulars or any person whose name is entered in the roll and who particualrs in an entry to the objector; and (d) In all cases to the concerned Tehsildar who shall file his report within 15days of the receipt of the notice : 137 (76) PIGET 21G19, 7000 21, 2002 27TU 4 (71) 4 (T)) TORER 21, 2002 137 (77) Provided that any claim or objection which for the purpose or may require the evidence be is not lodged within period, or in the Form and tendered by filing affidavit duly attested.  || Language: en
# --------------
# --------------
# Sentence: manner, as prescribed, shall be rejected : (6) No person shall be represented by any legal Provided further that it shall not be practitioner in any proceeding under this rule.  || Language: en
# --------------
# --------------
# Sentence: necessary to serve any such notice where the The Electoral Registration Officer shall also Electoral Registration Officer on being satisfied correct any clerical or printing errors which he as to the validity of the claim or objection and may discover in the roll.  || Language: en
# --------------
# --------------
# Sentence: decides to allow it without further inquiry : 7.  || Language: en
# --------------
# --------------
# Sentence: Inclusion of names inadvertently omitted and Provided further also that a list containing deletion of names of dead electors and persons who are not the names and addresses of the persons applying entitled to be registered-It it appears to the Electoral for inclusion of their names shall be exhibited Registration Officer at any time before the final publication on the notice board of the office of the Electoral of the roll that owing to inadvertence or error or otherwise Registration Officer, Project Authority, Water the names of any electors have been left out of the roll or the Users' Association and Gram Panchayat, for 3 name of dead persons or of persons who are otherwise not clear days before making an order on the claim.  || Language: en
# --------------
# --------------
# Sentence: entitled to be registered in that roll have been included in the roll and that remedial action should be taken under this rule, (2) A notice under sub rule (1) shall be given either personally or by registered post or by affixing it to the the Electoral Registration Officer shall,- persons' residence or last known residence with in the (a) prepare a list of the names and other details of constituency or left in the office of the Tehsildar in case of such electors; clause (d) of sub-rule (1), (b) exhibit on the notice board of his office and (3) The Electoral Registration Officer shall hold a Water Users' Association a copy of the list summary inquiry into every claim or objection in respect of together with a notice as to the time and place which notice has been given under sub-rule (1) and shall at which the quesion of deletion or inclusion of consider the report of the Tehsildar, if any, and record his these names as the case may be from the roll decision thereon.  || Language: en
# --------------
# --------------
# Sentence: will be considered, and also publishthe list and (4) At the hearing, the claimant or as the case may be the notice in such other manner as he may think fit; and the objector and the person objected to and any other person who, in the opinion of the Electoral Registration Officer is (c) after considering any verbal or written objections likely to be of assistance to him, shall be entitled to appear that may be preferred, decide whether all or any and be heard.  || Language: en
# --------------
# --------------
# Sentence: of the names should be deleted from the roll or (5) The Electoral Registration Officer may in his included in the roll as the case may be.  || Language: en
# --------------
# --------------
# Sentence: Final publication of roll-(1) The Electoral require any claimant, objector or person objected Registration Officer shall thereafter; (a) to, to appear in person before him.  || Language: en
# --------------
# --------------
# Sentence: (a) prepare a list of amendments to carry out his (b) require that the evidence tendered by any person decisions under rule 6 and 7 and to correct any shall be given on oath and administer an oath clerical or printing errors or other inaccuracies subsequently discovered in the roll: and ; (71) 71411 137 (78) 21314917 7914 21, 2002 4 (T1) 11.  || Language: en
# --------------
# --------------
# Sentence: Interim alteration-(1) II une Electoral Registration (b) publish the roll together with the list of amendments, Officer on his own motion or on the application made to bim by making a complete copy thereof avaiable for is satisfied after such inquiry as he thinks lit, that any entry inspection and displaying a notice at his office and in O electoral roll--- may also publish it in the office of the concerned (a) is erroncous or defective in any particular, Water Users' Association in the same manner.  || Language: en
# --------------
# --------------
# Sentence: (b) should be transposed to the electoral roll of an (2) On such publication the roll together with the list other constituency on the ground that the person of amendments shall be the electoral roll of the ward or the concerned has exchanged his land; or constituency (c) should be deleted on the ground that the person 9.  || Language: en
# --------------
# --------------
# Sentence: Duration of electoral rolls-Every electoral roil concerned is not entitled to be registered in the referred to in sub-rule (2) of rule 8 shall continue to be in roll; force until revised in accordance with rule 10.  || Language: en
# --------------
# --------------
# Sentence: (d) should be deleted on the ground that the person 10.  || Language: en
# --------------
# --------------
# Sentence: Revision of rolls- (1) The roll for every concerned is dead or is not entitled to be constituency shall De revised either intensively or summarily registered in the roll, he shall subject to such or partly intensively and party summarily, as the Project general or special directio: ii any, given by Authority may direct with reference to the qualifying date, i. the Project Authority in : dis behalf, amend, e 1st January of the year in which it is so revised.  || Language: en
# --------------
# --------------
# Sentence: transpos or delete the entry: (2) Where the roll is to be revised intensively, it shall Provided that before taking any action be prepared afresh and rule 4 to 8 shall apply in relation to undor this rule on the ground that the person such revision as they apply in relation to the first preparation concerned is not entitled to be registered in the of a roll.  || Language: en
# --------------
# --------------
# Sentence: electoral roll of that constituency, the Electoral (3) When the roll or any part thereof is to be revised Registration Officre shall give the person concerned a reasonable opportunity of being summarily, the Elecoral Registration Officer shall cause 10 be prepared a list of amendments to the roll on the basis of such heard in respect of the action proposed to be taken in relation to him.  || Language: en
# --------------
# --------------
# Sentence: information as may be readily available and publish the together with the list of amendments in draft.  || Language: en
# --------------
# --------------
# Sentence: (2) Any person whose name is not included in the _(-1) Notwithstanding any thing contained in sub-rule electoral roll of a constituency, may apply to Electoral 1 roject may at any time for reasons to be Registration Officer for inclusion of his name in that roll and recorded, direct a special revisions of the electoral roll for the Aforesaid officer, if satisfied that the applicant is entitled any constituency constituencies in such manner as it may to be registered is such roll direct his name to be included deem fit: therein.  || Language: en
# --------------
# --------------
# Sentence: l'to ided that the electoral noll as in force (3) A list oi persons applying under sub-rule (1) or (2) shall be exh bite d on the notice board of the Electora.  || Language: en
# --------------
# --------------
# Sentence: at the time of the issue of any such direction, continue to be in force until the completion Registration Officer for a period of three clear days before special revisions so directed.  || Language: en
# --------------
# --------------
# Sentence: making an order 137 ( SO) RIGH top 13 21, 2002 (4) No amendment, transpostion, or deletion of any 97T°T 4 (TI) 2105F2177 TOLOR 21, 2002 137 (81) entry shall be made urder sub-rule (1) and no direction for (4) Decision of the Project Authority shall be final, but the inclusion of a name in the electoral roll shall be given under sub-rule (2) after the issue of the public notice for in CO far as it reverses or modifies the decision of Electoral election under rule 17 and until completion of elections.  || Language: en
# --------------
# --------------
# Sentence: Registration Officer, it shall take effect only from the date of decision in appeal.  || Language: en
# --------------
# --------------
# Sentence: (5) The Electoral Registration Officer may cause to be 13.  || Language: en
# --------------
# --------------
# Sentence: Custody and preservation of rolls-(1) After the corrected any clerical error in the electoral roll at any time.  || Language: en
# --------------
# --------------
# Sentence: roll for a constituency has been finally published the following (6) The electoral rel altered in accordance with this papers shall be kept in the office of the Electoral Registration rule shall be deemed to be the roll for the time being in force.  || Language: en
# --------------
# --------------
# Sentence: Officer until the completion of the next intensive revision of (7) The application referred to in sub-rule (i) and (2) that roll- sharl be in Form lor Il or III as the case may be.  || Language: en
# --------------
# --------------
# Sentence: (i) One complete copy of the electoral roll duly 12.  || Language: en
# --------------
# --------------
# Sentence: Appeals-(1) An apeal shall lie to the Project authenticated by the Electoral Registration Authority from an order made under rule 6 or 11 by a Officer; Electoral Registration Officer within a period of 15 days from (ii) All application in regard to the preparation of the date of order: draft electoral roll; Provided that an appeal shall not be lie (iii) All manuscript copied prepared by the where a prson desiring.  || Language: en
# --------------
# --------------
# Sentence: to appeal has not availed enumerating agencies and used for compiling himself of his right to be heard by, or to make the draft electoral roll; representation to, the Electoral Registration (iv) All claims and objections to the draft electoral Officer on the matter which is the subject of roll; appeal.  || Language: en
# --------------
# --------------
# Sentence: (v) All decisions passed on the claims and objections; (2) Such appeal shall be; (vi) in the Form of memorandum signed by the Papers relating to appeals under rule 12; and (a) applicant; (viii) Applications under rule 11.  || Language: en
# --------------
# --------------
# Sentence: (b) accompanied by a copy of the order appealed (2) One complete copy of the roll for each constituency from and fee of rupees ten shall be paid in the duly authenticated by the Electoral Registration Officer shall Form of non-judicial stamps; and also be kept in the office of the Project Authority until the completion of the next intensive revision of that roll.  || Language: en
# --------------
# --------------
# Sentence: (c) presented to the Project Authority or sent by registered post SO as () reach him within the (3) The papers referred to in sub-rule (1) shall, on said period.  || Language: en
# --------------
# --------------
# Sentence: expire of the period specified by the Project Authority, be disposed of in such manner as the Project Authority may (3) The presentation of an appeal under this rule shall direct.  || Language: en
# --------------
# --------------
# Sentence: not have the effect of staying or postponing any action to be taken by the Electoral Registration Officer under rule 8 or 10: (4) Copies of electoral rolls, until disposal under sub- Provided that order shall not be stayed in rule (3) shall be made available for sale to public at such price fixed by the Project Authority.  || Language: en
# --------------
# --------------
# Sentence: case where the subject of appeal is an order made under rule 11 14.  || Language: en
# --------------
# --------------
# Sentence: Option for territorial constituency-Ir case, a land owner holds land in more than one Territorial 137 (82) 7atal 21, 2002 27TM 4 (T)) 4 (") PIGF TOROR 21, 2002 137 (83) Constituency of a water user area the land owner shall opt Managing Committee of the Project Committee, the Project for one constituency by giving a declaration in Form-IV to Authority shall appoint by order an officer as an Election the Electoral Registration Officer.  || Language: en
# --------------
# --------------
# Sentence: If no such option is Officer.  || Language: en
# --------------
# --------------
# Sentence: excercised by the lamd owner, the Electoral Registration Officer shall allot his vote according to his best judgment.  || Language: en
# --------------
# --------------
# Sentence: (2) The Project Election Authority may appoint one or more persons as Assistant Election Officers to assist the CHAPTER-IV Election Officer : Appointment of Project Authority, Election Officer, Provided that every such person shall be an employee Assistant Election Officer and their duties of the State Government 15.  || Language: en
# --------------
# --------------
# Sentence: Control over Election--(1) Election of Members of (3) Every Assistant Election Officer shall, subject to the the Managing Committee and President/Chair person of the control of the Election Officer, be competent to perform all or Farmers' organisations in the State under the Act for ordinary any of the functions of the Election Officer : vacancies and casual vacancies shall be held under general Provided that no Assistant Election Officer shall suprintendance and control of Commissioner appointed under section 35 of the Act.  || Language: en
# --------------
# --------------
# Sentence: perform any function of the Election Officer which relate to the scrutiny of nominations unless the Election Officer is (2) Appointment of Project Authorities-For pupose unavoidably prevented from performing the said functions.  || Language: en
# --------------
# --------------
# Sentence: of this Act following shall be the Project Authorities for- (4) It shall be the general duty of the Election Officer at (i) IGNP Command area Commissioner, CAD, any election to do all such acts and things as may be necessary Bikaner; for conducting election in the manner provided under the (ii) Chambal Command area Commissioner, CAD, Act and the rules or orders made thereunder.  || Language: en
# --------------
# --------------
# Sentence: Kota; CHAPTER V (iii) Mahi Command Area Chief Engineer (Irrigation), Election of Members of the Managing Committee and President of the Water Users' Association Banswara; Chief Engineer concerned; 17.  || Language: en
# --------------
# --------------
# Sentence: Notice of Election-(1 The election of the President (iv) For all other major and Member of Managing Committee of Water Users Irrigation project Association shall be held on the day fixed by the Project (v) For all other medium Superintending Engineer Authority.  || Language: en
# --------------
# --------------
# Sentence: Irrigation project concerned; and (2) The notice for conduct of election shall be given by (vi) For all other minor Executive Engineer the Election Officer to the members by one or more of the Irrigation project & concerned.  || Language: en
# --------------
# --------------
# Sentence: (a) by affixing at the notice board of Water Users' 16.  || Language: en
# --------------
# --------------
# Sentence: Appointment of Election Officer, Assistant Election Association, or Officer and their duties-(1) For Every election to fill the (b) seats of Members of Managing Committee and President of by affixing at the notice board of concerned Water Users' Association and the Distributary Committee, Panchyat; or and for the office of the Chairperson and member of the (c) by affixin.  || Language: en
# --------------
# --------------
# Sentence: on conspicuous place in Water Users' Area, as may be decided by the Election Officer 137 (84) 79202 21, 2002 97TH 4 ("T) 27 4 (TI) RTUTE-TIT7 2101-97, 7drek 21, 2002 137 (85) (3) The notice shall contain information regarding: (3) Every nomination paper accompanied with the (a) the number of vacancies for which election is security amount as mentioned below and shall be presented in person to the Election Officer, by the or candidate himself being held ; (b) constituency from which the members are to by his proposer, before the date and hour specified for nomination in notice referred to in sub-rule (3) of rule 17:- be elected; 1.  || Language: en
# --------------
# --------------
# Sentence: Security amount for election for the office of Rs 500/- (c) the day on which, the place at which and the President/Chairperson hours between which nomination papers are to 2.  || Language: en
# --------------
# --------------
# Sentence: Security amount for election for the office of Rs 200/- be presented, such date being not less than member of managing committee.  || Language: en
# --------------
# --------------
# Sentence: seven clear days before the date fixed for election, or if that day is a public holiday the next (4) The Elelction Officer shall enter on the nomination succeeding day which is not a public holiday.  || Language: en
# --------------
# --------------
# Sentence: paper its serial number and certify the date and hour at which the nomination paper is received by him and also Explanation-In this clause "Public holiday" means any immediately acknowledge receipt of the nomination paper.  || Language: en
# --------------
# --------------
# Sentence: day which is a public holiday for the purposes of section 25 of the Negotiable (5) Nomination papers received after the date and Instruments Act, 1881 (Central Act XXVI), hours fixed under sub-rule (3) of rule 17 shall be liable to be or any day which has been notified by the rejected.  || Language: en
# --------------
# --------------
# Sentence: Government to be a holiday for the 19.  || Language: en
# --------------
# --------------
# Sentence: Scrutiny of nomination papers-(1) The Election Government Offices in the State; Officer shall take up the scrutiny of the nomination papers (d) the day on which, the place at which and the on the day and time fixed under clause (d) of sub-rule (3) of hour when the nomination papers will be rule 17.  || Language: en
# --------------
# --------------
# Sentence: The candidate for election or the proposers may scrutinized; present themselves at time of scrutiny.  || Language: en
# --------------
# --------------
# Sentence: The Election Officer (e) the day on which and the hours by which shall scrutinise the nomination papers and decide all nomination may be withdrawn; and objections which may be made at the time of scrutiny.  || Language: en
# --------------
# --------------
# Sentence: After a (f) the day on which, the place at which and the summary enquiry, he can reject any nomination paper for valid reasins: hours between which the poll shall be taken.  || Language: en
# --------------
# --------------
# Sentence: Provided that the nomination of a candidate shall not 18.  || Language: en
# --------------
# --------------
# Sentence: Presentation of Nomination Papers-(1) The nomination of a candidate for the election of member of be rejected merely on the ground of an incorrect description Managing committee and for the election of president shall of his name or of the name of his proposer or of any other be in Form--V which shall be supplied to a member on particulars relating to the candidate or his proposer as entered payment of Rupee five by the Election Officer.  || Language: en
# --------------
# --------------
# Sentence: in the voter list prepared under these rules, if the identity of the candidate or proposer, as the case may be, is established (2) Every nominated paper shall be signed by the voter whose name is included in the voter list prepared under otherwise beyond reasonable doubt.  || Language: en
# --------------
# --------------
# Sentence: The nomination paper shall contain a (2) The Election Officer shall give all reasonable facilities declaration signed by the candidate proposed for election to to the contesting candidates or his proposer to examine all the efect that he is willing to stand for the election.  || Language: en
# --------------
# --------------
# Sentence: nomination papers 137 (86) PISTERT 7ddar 21, 2002 4 (T) 4 (T) 2101-97, Tdrok 21, 2002 137 (87) (3) The Election Officer shall endorse on each member of managing committee separately in Form VIII, nomination paper his decision accepting or rejecting the giving the names of all contesting candidates and symbols same and, if the nomination paper is rejected he shall record allotted to them and display it on the notice board of his in writing a brief statement of his reasons for such rejection.  || Language: en
# --------------
# --------------
# Sentence: office and also arrange to display at public place of the area (4) The list of valid nomination, shall be published in or polling station.  || Language: en
# --------------
# --------------
# Sentence: Form-VI on the notice board of the office of the election 22.  || Language: en
# --------------
# --------------
# Sentence: Poll-(1) If the number of candidates for any area officer on the same day on which the scrutiny is completed.  || Language: en
# --------------
# --------------
# Sentence: or constituency as the case may be for which valid nominations 20.  || Language: en
# --------------
# --------------
# Sentence: Withdrawal from Candidature-(1) Any candidate have been received is more than one the Election Officer shall may withdraw his candidature by notice in writing signed arrange for holding a poll on the date fixed for the purpose.  || Language: en
# --------------
# --------------
# Sentence: by him and delivered at any time after the presentation of his (2) The Election Officer shall arrange the ballot boxes, nomination paper but not later than the time fixed for ballot papers, copy of the list of voters and such other articles withdrawal under clause (e) of sub-rule (3) of rule 17.  || Language: en
# --------------
# --------------
# Sentence: A as may be necessary for the conduct of the election.  || Language: en
# --------------
# --------------
# Sentence: The notice of withdrawal of candidature once given shall be final.  || Language: en
# --------------
# --------------
# Sentence: ballot box shall be SO constructed that ballot papers can be introduced therein but cannot be taken out therefrom without (2) No notice of withdrawal shall be entertained after the box being unlocked.  || Language: en
# --------------

# %% [markdown]
# Extra functions to read the abbreviations file from S3, and move files between S3 bucket folders

# %%
abbreviations_fname = f"abbreviations/english_abbreviations.txt"
obj = s3.Object(bucket_name = bucket, key = abbreviations_fname)

# %%
obj.get()['Body'].read().decode('utf-8').split("\n")
# Out:
# ['sub',
#  'subs',
#  'ins',
#  'govt',
#  'dy',
#  'dept',
#  'deptt',
#  'ptg',
#  'no',
#  'sec',
#  'cong',
#  'dist',
#  'doc']

# %%
def move_s3_object(obj_name, obj_old_folder, obj_new_folder, s3, bucket_name):
    """
    Moves an object from a given S3 folder to another by copying it to the new folder it and then deleting it from the old one
    """
    try:
        s3.Object(bucket_name, f"{obj_new_folder}/{obj_name}").copy_from(CopySource=f"{bucket_name}/{obj_old_folder}/{obj_name}")
        response = s3.Object(bucket_name, f"{obj_old_folder}/{obj_name}").delete()
    except Exception as e:
        print(f"Exception while moving {obj_name} from {obj_old_folder} to {obj_new_folder}:")
        print(e)

# %%
move_s3_object("english_abbreviations.txt", "english_documents", "abbreviations", s3, "wri-nlp-policy")

# %% [markdown]
# ## Testing language detection on sample file

# %%
with open("/Users/dafirebanks/Downloads/011e041eced3f90558b955e5f65c7682608e35cc.txt", "r") as f:
    text = f.read()

# %% [markdown]
# ### 1. Apply language detection before sentence splitting

# %%
for line in text.splitlines():
    try:
        result = fmodel.predict([line])
        print("--------------")
        print("Line:", line, " || Language:", result[0][0][-2:])
        print("lang_detect:", detect_langs(line))
        print("Probability:", result[1][0])
        print("--------------")
        if result[0][0][0][-2:] == 'en' and result[1][0][0] > 0.7:
            text = text + line + "\n"
            print(">>>>>>>>>>> English sentence:", line)
    except:
        print("*** ", line)
        continue
# Out:
# --------------
# Line: 12456  || Language: ['__label__gu']
# lang_detect:
# ***  12456
# --------------
# Line: THE GAZETTE OF INDIA, NOVEMBER 10, 2012 (KARTIKA 19, 1934)  || Language: ['__label__en']
# lang_detect:
# [en:0.999994980952714]
# Probability: [0.3980843]
# --------------
# --------------
# Line: [PART III-SEC. 4  || Language: ['__label__en']
# lang_detect:
# [id:0.9999939202976486]
# Probability: [0.5178548]
# --------------
# --------------
# Line: University Grants Commission  || Language: ['__label__en']
# lang_detect:
# [en:0.9999950418111176]
# Probability: [0.7218409]
# --------------
# >>>>>>>>>>> English sentence: University Grants Commission
# --------------
# Line: No. F. 15-3/2012 (ARC)  || Language: ['__label__en']
# lang_detect:
# [pt:0.9999956692468923]
# Probability: [0.62202793]
# --------------
# --------------
# Line: 8 October, 2012  || Language: ['__label__en']
# lang_detect:
# [en:0.9999956111997939]
# Probability: [0.83474034]
# --------------
# >>>>>>>>>>> English sentence: 8 October, 2012
# --------------
# Line: In exercise of powers conferred under clause (g) of sub-section (1) of  || Language: ['__label__en']
# lang_detect:
# [en:0.9999976210186923]
# Probability: [0.9264741]
# --------------
# >>>>>>>>>>> English sentence: In exercise of powers conferred under clause (g) of sub-section (1) of
# --------------
# Line: section 26 of the University Grants Commission Act 1956 (3 of 1956) the,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999981038743955]
# Probability: [0.7925899]
# --------------
# >>>>>>>>>>> English sentence: section 26 of the University Grants Commission Act 1956 (3 of 1956) the,
# --------------
# Line: University Grants Commission here by makes the following regulations,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999972147047576]
# Probability: [0.95837456]
# --------------
# >>>>>>>>>>> English sentence: University Grants Commission here by makes the following regulations,
# --------------
# Line: namely:-  || Language: ['__label__uk']
# lang_detect:
# [hu:0.9999960137954038]
# Probability: [0.27649692]
# --------------
# --------------
# Line: (1) These regulations may be called the "curbing the Menace of Ragging  || Language: ['__label__en']
# lang_detect:
# [en:0.9999965436208202]
# Probability: [0.9359413]
# --------------
# >>>>>>>>>>> English sentence: (1) These regulations may be called the "curbing the Menace of Ragging
# --------------
# Line: in Higher Educational Institutions (Amendment) Regulations,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999966747149268]
# Probability: [0.9450163]
# --------------
# >>>>>>>>>>> English sentence: in Higher Educational Institutions (Amendment) Regulations,
# --------------
# Line: 2012."  || Language: ['__label__en']
# lang_detect:
# ***  2012."
# --------------
# Line: (2) They shall come into force on the date of their publication in the  || Language: ['__label__en']
# lang_detect:
# [en:0.9999967117967556]
# Probability: [0.9797279]
# --------------
# >>>>>>>>>>> English sentence: (2) They shall come into force on the date of their publication in the
# --------------
# Line: Official Gazette.  || Language: ['__label__en']
# lang_detect:
# [it:0.9999958172840794]
# Probability: [0.48006582]
# --------------
# --------------
# Line: 2. In UGC Regulations on Curbing the Menace of Ragging in Higher  || Language: ['__label__en']
# lang_detect:
# [en:0.9999945823330314]
# Probability: [0.85070413]
# --------------
# >>>>>>>>>>> English sentence: 2. In UGC Regulations on Curbing the Menace of Ragging in Higher
# --------------
# Line: Educational Institutions, 2009, (hereinafter referred to as the Principal  || Language: ['__label__en']
# lang_detect:
# [en:0.9999974374410279]
# Probability: [0.9321455]
# --------------
# >>>>>>>>>>> English sentence: Educational Institutions, 2009, (hereinafter referred to as the Principal
# --------------
# Line: regulations), in regulation 1, in sub-regulation 1.1, for the letters and  || Language: ['__label__en']
# lang_detect:
# [en:0.9999975158639614]
# Probability: [0.8781401]
# --------------
# >>>>>>>>>>> English sentence: regulations), in regulation 1, in sub-regulation 1.1, for the letters and
# --------------
# Line: words "ÜGC Regulations on curbing the Menace of Ragging in Higher  || Language: ['__label__en']
# lang_detect:
# [en:0.9999975408506914]
# Probability: [0.87605095]
# --------------
# >>>>>>>>>>> English sentence: words "ÜGC Regulations on curbing the Menace of Ragging in Higher
# --------------
# Line: Educational Institutions", the words "Curbing the Menace of Ragging in  || Language: ['__label__en']
# lang_detect:
# [en:0.9999965821731442]
# Probability: [0.8410501]
# --------------
# >>>>>>>>>>> English sentence: Educational Institutions", the words "Curbing the Menace of Ragging in
# --------------
# Line: Higher Educational Institutions Regulations" shall be substituted.  || Language: ['__label__en']
# lang_detect:
# [en:0.9999944636063325]
# Probability: [0.77946126]
# --------------
# >>>>>>>>>>> English sentence: Higher Educational Institutions Regulations" shall be substituted.
# --------------
# Line: 3. In the principal regulations, in regulation 8,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999949769777582]
# Probability: [0.8822929]
# --------------
# >>>>>>>>>>> English sentence: 3. In the principal regulations, in regulation 8,
# --------------
# Line: (a) In sub-regulation 8.1, in clause (f), for the words "Central  || Language: ['__label__en']
# lang_detect:
# [en:0.9999968345069296]
# Probability: [0.8532584]
# --------------
# >>>>>>>>>>> English sentence: (a) In sub-regulation 8.1, in clause (f), for the words "Central
# --------------
# Line: Government", the words "University Grants Commission" shall  || Language: ['__label__en']
# lang_detect:
# [en:0.9999977916882238]
# Probability: [0.8489497]
# --------------
# >>>>>>>>>>> English sentence: Government", the words "University Grants Commission" shall
# --------------
# Line: be substituted;  || Language: ['__label__en']
# lang_detect:
# [en:0.999998890820895]
# Probability: [0.50006944]
# --------------
# --------------
# Line: (b)  || Language: ['__label__id']
# lang_detect:
# [so:0.9999925948246114]
# Probability: [0.48992276]
# --------------
# --------------
# Line: In sub-regulation 8.2, in clause (f), for the words, brackets,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999966948915642]
# Probability: [0.8985636]
# --------------
# >>>>>>>>>>> English sentence: In sub-regulation 8.2, in clause (f), for the words, brackets,
# --------------
# Line: letter and figures "clause (g) of regulation 8.1", the words,  || Language: ['__label__en']
# lang_detect:
# [en:0.999996360052624]
# Probability: [0.8755231]
# --------------
# >>>>>>>>>>> English sentence: letter and figures "clause (g) of regulation 8.1", the words,
# --------------
# Line: brackets, letter and figures "clause (f) of Regulation 8.1" shall  || Language: ['__label__en']
# lang_detect:
# [en:0.9999969350114409]
# Probability: [0.8522094]
# --------------
# >>>>>>>>>>> English sentence: brackets, letter and figures "clause (f) of Regulation 8.1" shall
# --------------
# Line: be substituted.  || Language: ['__label__en']
# lang_detect:
# [en:0.9999962634009719]
# Probability: [0.7281144]
# --------------
# >>>>>>>>>>> English sentence: be substituted.
# --------------
# Line: Foot Note: The principal Regulations were published in the Gazette of  || Language: ['__label__en']
# lang_detect:
# [en:0.9999955230599582]
# Probability: [0.9927141]
# --------------
# >>>>>>>>>>> English sentence: Foot Note: The principal Regulations were published in the Gazette of
# --------------
# Line: India, vide notification number 27 dated 04.07.2009.  || Language: ['__label__en']
# lang_detect:
# [it:0.5714276342492478, en:0.42857130009154176]
# Probability: [0.44165713]
# --------------
# --------------
# Line: (N. Adil Kazmi)  || Language: ['__label__en']
# lang_detect:
# [tr:0.9999956771436527]
# Probability: [0.43291193]
# --------------
# --------------
# Line: Secretary  || Language: ['__label__en']
# lang_detect:
# [en:0.9999964650882454]
# Probability: [0.96704406]
# --------------
# >>>>>>>>>>> English sentence: Secretary
# --------------
# Line: 2102/10 618-7  || Language: ['__label__ru']
# lang_detect:
# ***  2102/10 618-7
# --------------
# Line: plifts  || Language: ['__label__pl']
# lang_detect:
# [en:0.8571380939825928, da:0.14286102329009995]
# Probability: [0.36159214]
# --------------
# --------------
# Line: (Ificing whjle bii)  || Language: ['__label__en']
# lang_detect:
# [en:0.9999959592456558]
# Probability: [0.253656]
# --------------
# --------------
# Line: 13 Dic  || Language: ['__label__it']
# lang_detect:
# [de:0.9999961831193127]
# Probability: [0.16495788]
# --------------
# --------------
# Line: 1209 PIEJLUPK # yolf-y 17 thedted 'hhinld up Palte "teblet befit  || Language: ['__label__en']
# lang_detect:
# [en:0.9999957496977102]
# Probability: [0.29862335]
# --------------
# --------------
# Line: flatner  || Language: ['__label__en']
# lang_detect:
# [da:0.9999954900998607]
# Probability: [0.6615383]
# --------------
# --------------
# Line: I Hedlen 1hop Phjlarulk 1313 up (chi) Eard up L8 HRAJES. 2.A an  || Language: ['__label__en']
# lang_detect:
# [en:0.9999977105235257]
# Probability: [0.55165815]
# --------------
# --------------
# Line: ,Sll (pp upkak (in plted pl jop 142024 3016 Pfillate up (H()) Sabd '18  || Language: ['__label__en']
# lang_detect:
# [sl:0.5714261045099492, en:0.42856977951531805]
# Probability: [0.48310873]
# --------------
# --------------
# Line: >h Hird up Helhed pd flap 1942024 1/2016 upkek # (sod) Entd Z8 teated he  || Language: ['__label__en']
# lang_detect:
# [en:0.9999966767490347]
# Probability: [0.58968395]
# --------------
# --------------
# Line: 111dilln 1keef Phjurdylk 1213 Wiftile tiple  || Language: ['__label__en']
# lang_detect:
# [da:0.9999925959844254]
# Probability: [0.13768853]
# --------------
# --------------
# Line: th Ellad cp ,dippard h/keep, (cp 1/9916 Upte t (ad) Sned 'L'8 Halle be (b)  || Language: ['__label__en']
# lang_detect:
# [en:0.9999980210346583]
# Probability: [0.51931715]
# --------------
# --------------
# Line: NOW Lile 1hup juby PJeshe up 8 telley (t (tertel male E  || Language: ['__label__en']
# lang_detect:
# [en:0.9999967966087018]
# Probability: [0.6742045]
# --------------
# --------------
# Line: (HIDILIN peef upFak , H3ptd lakkly  || Language: ['__label__en']
# lang_detect:
# [nl:0.9999951310803661]
# Probability: [0.44279245]
# --------------
# --------------
# Line: dh Hbyll ye 10/1/ # 4/10/1216 20122A Plessite up LL Halle be up  || Language: ['__label__fr']
# lang_detect:
# [en:0.7142851996154641, fr:0.28571422435313143]
# Probability: [0.6015688]
# --------------
# --------------
# Line: 'f taties of (in fidlth fild (t hid up (titelye) reaft (tr (t tapite) OF ill depj Offly  || Language: ['__label__en']
# lang_detect:
# [en:0.9999946653405205]
# Probability: [0.6416092]
# --------------
# --------------
# Line: 1313 We Dg lakely dh Hbdlin up (t (H-lated 4/10/1366 App2A up) (in 600Z  || Language: ['__label__en']
# lang_detect:
# [en:0.999997201503525]
# Probability: [0.69949406]
# --------------
# --------------
# Line: teated 11/11/E Hislie Healln 1bco Phllarelk (x had teff (cp 12016  || Language: ['__label__en']
# lang_detect:
# [en:0.9999967326632044]
# Probability: [0.9134338]
# --------------
# >>>>>>>>>>> English sentence: teated 11/11/E Hislie Healln 1bco Phllarelk (x had teff (cp 12016
# --------------
# Line: tis - , f3pt lakkly Àh HEdfler up 10/1/1 (t HIRDED epinftalls 20/22E Z  || Language: ['__label__en']
# lang_detect:
# [sv:0.571426465846538, en:0.42857158643388077]
# Probability: [0.24571116]
# --------------
# --------------
# Line: I fuilten filts Yelfo 13 (d cly (pp 1-16140K (I Khlnid flucdit HdGld R (z)  || Language: ['__label__en']
# lang_detect:
# [en:0.9999954907113071]
# Probability: [0.68195826]
# --------------
# --------------
# Line: 111cd 11-11n to Elle up therfer (/p  || Language: ['__label__fr']
# lang_detect:
# [en:0.9999980452621559]
# Probability: [0.6570478]
# --------------
# --------------
# Line: fed Okjnly (p up 10/1/ t (WissH epinitials apk2A (4p HREJet 1.5 (1)  || Language: ['__label__en']
# lang_detect:
# [en:0.9999957587756547]
# Probability: [0.52629524]
# --------------
# --------------
# Line: -ge 1040 1.1nFx  || Language: ['__label__zh']
# lang_detect:
# [af:0.9999948667411542]
# Probability: [0.18811628]
# --------------
# --------------
# Line: 14p trevel try 1213 Withle Hislit It HysLite cp tisibaly up (i) Dikha  || Language: ['__label__en']
# lang_detect:
# [en:0.9999980698892437]
# Probability: [0.5193753]
# --------------
# --------------
# Line: fop (Hy) Sard up 9Z IMb (ip 9961 1/fle HIPL-E BWIBPLOSP  || Language: ['__label__en']
# lang_detect:
# [en:0.999992306614258]
# Probability: [0.6118402]
# --------------
# --------------
# Line: -- ZIOZ/E-SI  || Language: ['__label__it']
# lang_detect:
# [de:0.9999963537641383]
# Probability: [0.16744046]
# --------------
# --------------
# Line: 2102 yolipte 8 4011-21  || Language: ['__label__sv']
# lang_detect:
# [tr:0.8571408828928433, ro:0.14285694014262484]
# Probability: [0.1451556]
# --------------
# --------------
# Line: Leftelle UpDIC  || Language: ['__label__fr']
# lang_detect:
# [da:0.9999937814235433]
# Probability: [0.601337]
# --------------
# --------------
# Line: '61 401110 zioz '01 Herpt 'khknd 14 path  || Language: ['__label__en']
# lang_detect:
# [nl:0.9999954800773475]
# Probability: [0.17196982]
# --------------
# --------------
# Line: 2  || Language: ['__label__sv']
# lang_detect:
# ***  2
# --------------
# Line: ,EE  || Language: ['__label__en']
# lang_detect:
# [es:0.9999921302859875]
# Probability: [0.7167056]
# --------------
# >>>>>>>>>>> English sentence: ,EE
# --------------
# Line: University Grants Commission  || Language: ['__label__en']
# lang_detect:
# [en:0.9999974245681955]
# Probability: [0.7218409]
# --------------
# >>>>>>>>>>> English sentence: University Grants Commission
# --------------
# Line: 8 October, 2012  || Language: ['__label__en']
# lang_detect:
# [en:0.9999964305848954]
# Probability: [0.83474034]
# --------------
# >>>>>>>>>>> English sentence: 8 October, 2012
# --------------
# Line: In exercise of powers conferred under clause (g) of sub-section (1) of  || Language: ['__label__en']
# lang_detect:
# [en:0.9999962859052942]
# Probability: [0.9264741]
# --------------
# >>>>>>>>>>> English sentence: In exercise of powers conferred under clause (g) of sub-section (1) of
# --------------
# Line: section 26 of the University Grants Commission Act 1956 (3 of 1956) the,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999979334285781]
# Probability: [0.7925899]
# --------------
# >>>>>>>>>>> English sentence: section 26 of the University Grants Commission Act 1956 (3 of 1956) the,
# --------------
# Line: University Grants Commission here by makes the following regulations,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999960680725914]
# Probability: [0.95837456]
# --------------
# >>>>>>>>>>> English sentence: University Grants Commission here by makes the following regulations,
# --------------
# Line: (1) These regulations may be called the "curbing the Menace of Ragging  || Language: ['__label__en']
# lang_detect:
# [en:0.9999956951906495]
# Probability: [0.9359413]
# --------------
# >>>>>>>>>>> English sentence: (1) These regulations may be called the "curbing the Menace of Ragging
# --------------
# Line: in Higher Educational Institutions (Amendment) Regulations,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999946686357822]
# Probability: [0.9450163]
# --------------
# >>>>>>>>>>> English sentence: in Higher Educational Institutions (Amendment) Regulations,
# --------------
# Line: (2) They shall come into force on the date of their publication in the  || Language: ['__label__en']
# lang_detect:
# [en:0.9999982826926859]
# Probability: [0.9797279]
# --------------
# >>>>>>>>>>> English sentence: (2) They shall come into force on the date of their publication in the
# --------------
# Line: 2. In UGC Regulations on Curbing the Menace of Ragging in Higher  || Language: ['__label__en']
# lang_detect:
# [en:0.9999973523491004]
# Probability: [0.85070413]
# --------------
# >>>>>>>>>>> English sentence: 2. In UGC Regulations on Curbing the Menace of Ragging in Higher
# --------------
# Line: Educational Institutions, 2009, (hereinafter referred to as the Principal  || Language: ['__label__en']
# lang_detect:
# [en:0.9999980165122717]
# Probability: [0.9321455]
# --------------
# >>>>>>>>>>> English sentence: Educational Institutions, 2009, (hereinafter referred to as the Principal
# --------------
# Line: regulations), in regulation 1, in sub-regulation 1.1, for the letters and  || Language: ['__label__en']
# lang_detect:
# [en:0.9999985109884337]
# Probability: [0.8781401]
# --------------
# >>>>>>>>>>> English sentence: regulations), in regulation 1, in sub-regulation 1.1, for the letters and
# --------------
# Line: words "ÜGC Regulations on curbing the Menace of Ragging in Higher  || Language: ['__label__en']
# lang_detect:
# [en:0.999994515534205]
# Probability: [0.87605095]
# --------------
# >>>>>>>>>>> English sentence: words "ÜGC Regulations on curbing the Menace of Ragging in Higher
# --------------
# Line: Educational Institutions", the words "Curbing the Menace of Ragging in  || Language: ['__label__en']
# lang_detect:
# [en:0.9999955595996861]
# Probability: [0.8410501]
# --------------
# >>>>>>>>>>> English sentence: Educational Institutions", the words "Curbing the Menace of Ragging in
# --------------
# Line: Higher Educational Institutions Regulations" shall be substituted.  || Language: ['__label__en']
# lang_detect:
# [en:0.9999953192756355]
# Probability: [0.77946126]
# --------------
# >>>>>>>>>>> English sentence: Higher Educational Institutions Regulations" shall be substituted.
# --------------
# Line: 3. In the principal regulations, in regulation 8,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999980744099021]
# Probability: [0.8822929]
# --------------
# >>>>>>>>>>> English sentence: 3. In the principal regulations, in regulation 8,
# --------------
# Line: (a) In sub-regulation 8.1, in clause (f), for the words "Central  || Language: ['__label__en']
# lang_detect:
# [en:0.999996054200925]
# Probability: [0.8532584]
# --------------
# >>>>>>>>>>> English sentence: (a) In sub-regulation 8.1, in clause (f), for the words "Central
# --------------
# Line: Government", the words "University Grants Commission" shall  || Language: ['__label__en']
# lang_detect:
# [en:0.9999958778423927]
# Probability: [0.8489497]
# --------------
# >>>>>>>>>>> English sentence: Government", the words "University Grants Commission" shall
# --------------
# Line: In sub-regulation 8.2, in clause (f), for the words, brackets,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999969136759825]
# Probability: [0.8985636]
# --------------
# >>>>>>>>>>> English sentence: In sub-regulation 8.2, in clause (f), for the words, brackets,
# --------------
# Line: letter and figures "clause (g) of regulation 8.1", the words,  || Language: ['__label__en']
# lang_detect:
# [en:0.9999969074919864]
# Probability: [0.8755231]
# --------------
# >>>>>>>>>>> English sentence: letter and figures "clause (g) of regulation 8.1", the words,
# --------------
# Line: brackets, letter and figures "clause (f) of Regulation 8.1" shall  || Language: ['__label__en']
# lang_detect:
# [en:0.9999947715629146]
# Probability: [0.8522094]
# --------------
# >>>>>>>>>>> English sentence: brackets, letter and figures "clause (f) of Regulation 8.1" shall
# --------------
# Line: be substituted.  || Language: ['__label__en']
# lang_detect:
# [en:0.9999965547128352]
# Probability: [0.7281144]
# --------------
# >>>>>>>>>>> English sentence: be substituted.
# --------------
# Line: Foot Note: The principal Regulations were published in the Gazette of  || Language: ['__label__en']
# lang_detect:
# [en:0.9999975161756006]
# Probability: [0.9927141]
# --------------
# >>>>>>>>>>> English sentence: Foot Note: The principal Regulations were published in the Gazette of
# --------------
# Line: Secretary  || Language: ['__label__en']
# lang_detect:
# [en:0.9999973334916843]
# Probability: [0.96704406]
# --------------
# >>>>>>>>>>> English sentence: Secretary
# --------------
# Line: teated 11/11/E Hislie Healln 1bco Phllarelk (x had teff (cp 12016  || Language: ['__label__en']
# lang_detect:
# [en:0.9999962604108656]
# Probability: [0.9134338]
# --------------
# >>>>>>>>>>> English sentence: teated 11/11/E Hislie Healln 1bco Phllarelk (x had teff (cp 12016
# --------------
# Line: ,EE  || Language: ['__label__en']
# lang_detect:
# [es:0.9999917817894757]
# Probability: [0.7167056]
# --------------
# >>>>>>>>>>> English sentence: ,EE

# %% [markdown]
# ### 2. Apply language detection after sentence splitting

# %%
all_abrevs = {"no", "sec", "cong", "dist", "doc", "sub", "subs", "ins", "govt", "dy", "dept", "deptt", "ptg"} 
preprocessed = english_preprocessing(text)
# NOTE: Change abreviations in the future specific to country
sents = get_nltk_sents(preprocessed, en_tokenizer, all_abrevs)
post_processed_sents = english_postprocessing(sents, min_num_words=5)
for sent in post_processed_sents:
    try:
        result = fmodel.predict(sent)
        print("--------------")
        print("Sentence:", sent, " || Language:", result[0][0][-2:])
        print("lang_detect:", detect_langs(sent))
        print("Probability:", result[1][0])
        print("--------------")
        if result[0][0][0][-2:] == 'en' and result[1][0][0] > 0.7:
            print(">>>>> English sentence:", sent)
    except:
        print("*** ", sent)
        continue
# Out:
# --------------
# Sentence: 12456 THE GAZETTE OF INDIA, NOVEMBER 10, 2012 (KARTIKA 19, 1934) [PART III-SEC 4 University Grants Commission No. F 15-3/2012 (ARC) 8 October, 2012 In exercise of powers conferred under clause (g) of sub-section (1) of section 26 of the University Grants Commission Act 1956 (3 of 1956) the, University Grants Commission here by makes the following regulations, namely:- (1) These regulations may be called the "curbing the Menace of Ragging in Higher Educational Institutions (Amendment) Regulations, 2012" (2) They shall come into force on the date of their publication in the Official Gazette 2.  || Language: en
# lang_detect: [en:0.9999970044210891]
# Probability: 0.8904610276222229
# --------------
# --------------
# Sentence: In UGC Regulations on Curbing the Menace of Ragging in Higher Educational Institutions, 2009, (hereinafter referred to as the Principal regulations), in regulation 1, in sub-regulation 11, for the letters and words "ÜGC Regulations on curbing the Menace of Ragging in Higher Educational Institutions", the words "Curbing the Menace of Ragging in Higher Educational Institutions Regulations" shall be substituted 3.  || Language: en
# lang_detect: [en:0.9999965367622845]
# Probability: 0.8798258304595947
# --------------
# --------------
# Sentence: In the principal regulations, in regulation 8, (a) In sub-regulation 81, in clause (f), for the words "Central Government", the words "University Grants Commission" shall be substituted; (b) In sub-regulation 82, in clause (f), for the words, brackets, letter and figures "clause (g) of regulation 81", the words, brackets, letter and figures "clause (f) of Regulation 81" shall be substituted.  || Language: en
# lang_detect: [en:0.9999969727338864]
# Probability: 0.8608548641204834
# --------------
# --------------
# Sentence: Foot Note: The principal Regulations were published in the Gazette of India, vide notification number 27 dated 04072009.  || Language: en
# lang_detect: [en:0.9999964052210829]
# Probability: 0.9478631019592285
# --------------
# --------------
# Sentence: (N. Adil Kazmi) Secretary 2102/10 618-7 plifts (Ificing whjle bii) 13 Dic 1209 PIEJLUPK # yolf-y 17 thedted 'hhinld up Palte "teblet befit flatner I Hedlen 1hop Phjlarulk 1313 up (chi) Eard up L8 HRAJES 2A an ,Sll (pp upkak (in plted pl jop 142024 3016 Pfillate up (H()) Sabd '18 >h Hird up Helhed pd flap 1942024 1/2016 upkek # (sod) Entd Z8 teated he 111dilln 1keef Phjurdylk 1213 Wiftile tiple th Ellad cp ,dippard h/keep, (cp 1/9916 Upte t (ad) Sned 'L'8 Halle be (b) NOW Lile 1hup juby PJeshe up 8 telley (t (tertel male E (HIDILIN peef upFak , H3ptd lakkly dh Hbyll ye 10/1/ # 4/10/1216 20122A Plessite up LL Halle be up 'f taties of (in fidlth fild (t hid up (titelye) reaft (tr (t tapite) OF ill depj Offly 1313 We Dg lakely dh Hbdlin up (t (H-lated 4/10/1366 App2A up) (in 600Z teated 11/11/E Hislie Healln 1bco Phllarelk (x had teff (cp 12016 tis - , f3pt lakkly Àh HEdfler up 10/1/1 (t HIRDED epinftalls 20/22E Z I fuilten filts Yelfo 13 (d cly (pp 1-16140K (I Khlnid flucdit HdGld R (z) 111cd 11-11n to Elle up therfer (/p fed Okjnly (p up 10/1/ t (WissH epinitials apk2A (4p HREJet 15 (1) -ge 1040 11nFx 14p trevel try 1213 Withle Hislit It HysLite cp tisibaly up (i) Dikha fop (Hy) Sard up 9Z IMb (ip 9961 1/fle HIPL-E BWIBPLOSP -- ZIOZ/E-SI 2102 yolipte 8 4011-21 Leftelle UpDIC '61 401110 zioz '01 Herpt 'khknd 14 path 2 ,EE University Grants Commission 8 October, 2012 In exercise of powers conferred under clause (g) of sub-section (1) of section 26 of the University Grants Commission Act 1956 (3 of 1956) the, University Grants Commission here by makes the following regulations, (1) These regulations may be called the "curbing the Menace of Ragging in Higher Educational Institutions (Amendment) Regulations, (2) They shall come into force on the date of their publication in the 2.  || Language: en
# lang_detect: [en:0.9999968133694247]
# Probability: 0.6933713555335999
# --------------
# --------------
# Sentence: In UGC Regulations on Curbing the Menace of Ragging in Higher Educational Institutions, 2009, (hereinafter referred to as the Principal regulations), in regulation 1, in sub-regulation 11, for the letters and words "ÜGC Regulations on curbing the Menace of Ragging in Higher Educational Institutions", the words "Curbing the Menace of Ragging in Higher Educational Institutions Regulations" shall be substituted 3.  || Language: en
# lang_detect: [en:0.9999963797477827]
# Probability: 0.8798258304595947
# --------------
# --------------
# Sentence: In the principal regulations, in regulation 8, (a) In sub-regulation 81, in clause (f), for the words "Central Government", the words "University Grants Commission" shall In sub-regulation 82, in clause (f), for the words, brackets, letter and figures "clause (g) of regulation 81", the words, brackets, letter and figures "clause (f) of Regulation 81" shall be substituted.  || Language: en
# lang_detect: [en:0.9999992024146708]
# Probability: 0.8715804815292358
# --------------
# --------------
# Sentence: Foot Note: The principal Regulations were published in the Gazette of Secretary teated 11/11/E Hislie Healln 1bco Phllarelk (x had teff (cp 12016 ,EE University Grants Commission 8 October, 2012 In exercise of powers conferred under clause (g) of sub-section (1) of section 26 of the University Grants Commission Act 1956 (3 of 1956) the, University Grants Commission here by makes the following regulations, (1) These regulations may be called the "curbing the Menace of Ragging in Higher Educational Institutions (Amendment) Regulations, (2) They shall come into force on the date of their publication in the 2.  || Language: en
# lang_detect: [en:0.9999977245033009]
# Probability: 0.9519173502922058
# --------------
# --------------
# Sentence: In UGC Regulations on Curbing the Menace of Ragging in Higher Educational Institutions, 2009, (hereinafter referred to as the Principal regulations), in regulation 1, in sub-regulation 11, for the letters and words "ÜGC Regulations on curbing the Menace of Ragging in Higher Educational Institutions", the words "Curbing the Menace of Ragging in Higher Educational Institutions Regulations" shall be substituted 3.  || Language: en
# lang_detect: [en:0.9999974183295282]
# Probability: 0.8798258304595947
# --------------
# --------------
# Sentence: In the principal regulations, in regulation 8, (a) In sub-regulation 81, in clause (f), for the words "Central Government", the words "University Grants Commission" shall In sub-regulation 82, in clause (f), for the words, brackets, letter and figures "clause (g) of regulation 81", the words, brackets, letter and figures "clause (f) of Regulation 81" shall be substituted.  || Language: en
# lang_detect: [en:0.9999946602547066]
# Probability: 0.8715804815292358
# --------------
# --------------
# Sentence: Foot Note: The principal Regulations were published in the Gazette of Secretary teated 11/11/E Hislie Healln 1bco Phllarelk (x had teff (cp 12016 ,EE University Grants Commission 8 October, 2012 In exercise of powers conferred under clause (g) of sub-section (1) of section 26 of the University Grants Commission Act 1956 (3 of 1956) the, University Grants Commission here by makes the following regulations, (1) These regulations may be called the "curbing the Menace of Ragging in Higher Educational Institutions (Amendment) Regulations, (2) They shall come into force on the date of their publication in the 2.  || Language: en
# lang_detect: [en:0.9999976320464825]
# Probability: 0.9519173502922058
# --------------
# --------------
# Sentence: In UGC Regulations on Curbing the Menace of Ragging in Higher Educational Institutions, 2009, (hereinafter referred to as the Principal regulations), in regulation 1, in sub-regulation 11, for the letters and words "ÜGC Regulations on curbing the Menace of Ragging in Higher Educational Institutions", the words "Curbing the Menace of Ragging in Higher Educational Institutions Regulations" shall be substituted 3.  || Language: en
# lang_detect: [en:0.9999974833974721]
# Probability: 0.8798258304595947
# --------------
# --------------
# Sentence: In the principal regulations, in regulation 8, (a) In sub-regulation 81, in clause (f), for the words "Central Government", the words "University Grants Commission" shall In sub-regulation 82, in clause (f), for the words, brackets, letter and figures "clause (g) of regulation 81", the words, brackets, letter and figures "clause (f) of Regulation 81" shall be substituted.  || Language: en
# lang_detect: [en:0.9999973513199059]
# Probability: 0.8715804815292358
# --------------
# --------------
# Sentence: Foot Note: The principal Regulations were published in the Gazette of Secretary teated 11/11/E Hislie Healln 1bco Phllarelk (x had teff (cp 12016 ,EE  || Language: en
# lang_detect: [en:0.9999952122408097]
# Probability: 0.9792892336845398
# --------------

# %%
sample_text = " taties of (in fidlth fild (t hid up (titelye) reaft (tr (t tapite) OF ill depj Offly"

# %%
from langdetect import DetectorFactory, detect, detect_langs

# %%
# detect(sample_text) #  'cs'
detect_langs(sample_text)  # [cs:0.7142840957132709, pl:0.14285810606233737, sk:0.14285779665739756]
# Out:
# [en:0.9999959850517358]
