# %%
import codecs
import pdfkit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-367dffd9912d> in <module>
#       1 import codecs
# ----> 2 import pdfkit
#
# ModuleNotFoundError: No module named 'pdfkit'

# %%
f = open("/home/propietari/Documents/GitHub/policy-data-analyzer/tasks/Scrapy/scrapy_official_newspapers/pdfs/prova.html", "r", encoding = "utf-8")
s = f.read()
z = codecs.decode(s, 'unicode-escape')
print(z)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"> <HTML> <head>   <title>DECLARATORIA de la Causa de Utilidad P̼blica de 109-66-87</title>                            <style type='text/css'> .ANOTACION {text-indent:0.0pt;text-align:center;font-size:9.0pt;margin-left:0.0pt;margin-bottom:5.05pt;font-family:serif,Times,Times Roman,Times-Roman;margin-top:5.05pt;font-weight:bold;} .Fechas {margin-right:14.4pt;text-indent:0.0pt;text-align:justify;font-size:9.0pt;border-bottom: 0.75pt solid rgb(0,0,0);margin-left:14.4pt;margin-bottom:0.0pt;font-family:serif,Times,Times Roman,Times-Roman;padding-bottom:0.05pt;} .Normal {text-indent:0.0pt;font-size:12.0pt;margin-left:0.0pt;font-family:serif,Times,Times Roman,Times-Roman;} .Texto {text-indent:14.4pt;text-align:justify;font-size:9.0pt;margin-left:0.0pt;margin-bottom:5.05pt;font-family:Tahoma,Arial Unicode MS,Verdana,system, , ,Arial Black,sans-serif,Helvetica,dialog;} .Titulo_2 {padding-top:0.05pt;text-i
# ...
