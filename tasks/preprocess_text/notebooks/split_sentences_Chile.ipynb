# %% [markdown]
# ## Section Headings Curation and sentences spliter of Chilean Policies
#
# In this notebook there are a series of dictionaries and methods to curate section headings of El Salvador policies. Policies from El Salvador have a rather definite structure, so that the law text is organized under section headings. There are two kinds of sections, the ones that are general and that can be often found in many policies, and the ones which are specific. The sections headings which are more general often come with a whole range of name variants which makes the task of machine recognition difficult.
#
# The goal of this notebook is to group all pretreatment methods that would harmonize sections heading to make the further processing machine friendly.

# %%
from pathlib import Path
import boto3, json, operator, os, re, string
import numpy as np

# %% [markdown]
# ### Dictionaries of particular vocabularies to help in the curation of section headings

# %%
# Most policies come with the final signatures. This is a piece of text that we want to be able to recognize. To make the
# detection of signatures easier, this dictionary contain the most common terms that can be found in these lines of text.
official_positions = {"ALCALDE" : 0,
"Alcalde" : 0,
"MINISTRA" : 0,
"Ministra" : 0,
"MINISTRO" : 0,
"Ministro" : 0,
"PRESIDENTA" : 0,
"Presidenta" : 0,
"PRESIDENTE" : 0,
"Presidente" : 0,
"REGIDOR" : 0,
"Regidor"  : 0,
"REGIDORA" : 0,
"regidora" : 0,
"SECRETARIA" : 0,
"Secretaria" : 0,
"SECRETARIO" : 0,
"Secretario" : 0,
"SINDICA" : 0,
"Sindica" : 0,
"SINDICO" : 0,
"Sindico" : 0,
"VICEPRESIDENTA" : 0,
"Vicepresidenta" : 0,
"VICEPRESIDENTE" : 0,
"Vicepresidente" : 0
}

end_of_file_tags = {
    "Anótese" : 0,
    "Anotese" : 0,
    "Publíquese" : 0,
    "Publiquese" : 0
}
# This dictionary contains some correspondences among different text headings. This is under development and needs further
# improvement.The idea is to merge in a single name all the headings that point to the same conceptual concept. For example,
# "Definiciones" is a heading that can come alone or together with other terms so it can appear as "Definiciones básicas" or
# "Definiciones generales". With the dictionary we can fetch all headings that contain the word "Definiciones" and change the
# heading to "Definiciones".
merges = {
    "CONCEPTOS" : "DISPOSICIONES GENERALES",
    "Considerando:" : "CONSIDERANDO",
    "DEFINICIONES" : "DISPOSICIONES GENERALES",
    "DISPOSICIONES FINALES" : "DISPOSICIONES GENERALES",
    "DISPOSICIONES GENERALES" : "DISPOSICIONES GENERALES",
    "DISPOSICIONES PRELIMINARES" : "DISPOSICIONES GENERALES",
    "DISPOSICIONES REGULADORAS" : "DISPOSICIONES ESPECIALES",
    "DISPOSICIONES RELATIVAS" : "DISPOSICIONES ESPECIALES",
    "DISPOSICIONES ESPECIALES" : "DISPOSICIONES ESPECIALES",
    "DISPOSICIONES TRANSITORIAS" : "DISPOSICIONES GENERALES",
    "DISPOSICIONES VARIAS Y TRANSITORIAS" : "DISPOSICIONES GENERALES",
    "DISPOSICIONES VARIAS" : "DISPOSICIONES GENERALES",
    "INCENTIVOS" : "INCENTIVOS",
    "INFRACCIONES" : "INFRACCIONES",
    "INFRACCION ES" : "INFRACCIONES",
    "OBJETIVO" : "OBJETO",
    "OBJETO" : "OBJETO",
    "DERECHOS" : "DERECHOS, OBLIGACIONES Y PROHIBICIONES",
    "DEBERES" : "DERECHOS, OBLIGACIONES Y PROHIBICIONES",
    "OBLIGACIONES" : "DERECHOS, OBLIGACIONES Y PROHIBICIONES",
    "OBLIGACIONE" : "DERECHOS, OBLIGACIONES Y PROHIBICIONES",
    "OBLIGACION" : "DERECHOS, OBLIGACIONES Y PROHIBICIONES",
    "OBLIGATORIEDAD" : "DERECHOS, OBLIGACIONES Y PROHIBICIONES",
    "PROHIBICIONES" : "DERECHOS, OBLIGACIONES Y PROHIBICIONES",
    "PROHIBICION" : "DERECHOS, OBLIGACIONES Y PROHIBICIONES",
    "DE LAS FORMAS DE AUTORIZACION" : "PERMISOS",
    "DE LOS PERMISOS Y LAS PATENTES" : "PERMISOS",
    "DE LOS PERMISOS" : "PERMISOS",
    "DE LAS SOLICITUDES DE PERMISOS" : "PERMISOS",
    "DEL OTORGAMIENTO DEL PERMISO" : "PERMISOS",
    "POR TANTO" : "POR TANTO",
    "POR LO TANTO" : "POR TANTO",
    "Decreto:" : "RESUELVO",
    "Resuelvo:" : "RESUELVO",
    "Se resuelve" : "RESUELVO",
    "S e  r e s u e l v e:" : "RESUELVO",
    "R e s u e l v o:" : "RESUELVO",
    "FISCALIZACION Y SANCIONES" : "SANCIONES",
    "DE LAS SANCIONES" : "SANCIONES",
    "Visto:" : "VISTO",
    "Vistos:" : "VISTO",
    "Vistos estos antecedentes:" : "VISTO",
    "--------------" : "HEADING"
}
section_tags = {
    "Considerando:" : "CONSIDERANDO",
    "Considerando\n" : "CONSIDERANDO",
    "Decreto:" : "RESUELVO",
    "Disposiciones Generales" : "DISPOSICIONES GENERALES", 
    "Resuelvo:" : "RESUELVO",
    "R e s u e l v o:" : "RESUELVO",
    "Se resuelve" : "RESUELVO",
    "S e  r e s u e l v e:" : "RESUELVO",
    "Visto:" : "VISTO",
    "Vistos:" : "VISTO",
    "Vistos estos antecedentes:" : "VISTO",
    "--------------" : "HEADING"
}
merges_lower = {}
for key, value in merges.items():
    merges_lower[key.lower()] = value
# Eventhough the general gramar rule in Spanish is not to accent uppercase, there are many cases where a word in a heding might
# appear accented. This is a dictionary to armonize all headings without accents. The list is rather comprehensive, but there is
# still room for improvement.
# If we find some bug beyond simple misspelling which will be solved by spell checker, we can include it here. The example is in
# the first row with "ACTIVIDADESUSOS" which was found several times in headings.
bugs = {"ACTIVIDADESUSOS" : "ACTIVIDADES DE USOS"}

# %% [markdown]
# ### Connection to the AWS S3 bucket
# To effectively run this cell you need Omdena's credentials. Please keep them local and do not sync them in GitHub repos nor cloud drives. Before doing anything with this json file, please think of security!!

# %%
json_folder = Path("C:/Users/user/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Notebooks/credentials/")
# json_folder = Path("C:/Users/jordi/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Notebooks/credentials/")
filename = "Omdena_key_S3.json"
file = json_folder / filename

with open(file, 'r') as f:
    cred = json.load(f) 

for key in cred:
    KEY = key
    SECRET = cred[key]

s3 = boto3.resource(
    service_name = 's3',
    region_name = 'us-east-2',
    aws_access_key_id = KEY,
    aws_secret_access_key = SECRET
)

# %% [markdown]
# ### Regular expressions

# %%
# To clear html tags (here is basically to remove the page tags)
cleanr = re.compile(r'<.*?>')

# To catch accents and dictionary to change them
accents_out = re.compile(r'[áéíóúÁÉÍÓÚ]')
accents_dict = {"á":"a","é":"e","í":"i","ó":"o","ú":"u","Á":"A","É":"E","Í":"I","Ó":"O","Ú":"U"}

# To remove special characters
clean_special_char = re.compile(r'(\*\.)|(\”\.)')

# To search for acronyms
clean_acron = re.compile(r'(A\s*\.M\s*\.)|(\b[Aa][Rr][Tt][Ss]*\s*\.)|(\b[Aa][Vv]\s*\.)|(\bDr\s*\.)|(\bIng\s*\.)|(\bLic\s*\.)|(\bLicda\s*\.)|(\bLIC\s*\.)|(mm\s*\.)|(mts\s*\.)|([Oo]rd\s*\.)|(\bNo\s*\.)|(P\s*\.M\s*\.)|(\bprof\s*\.)|(\bprofa\s*\.)|(\bsp\s*\.)|(\bssp\s*\.)|(\bsr\s*\.)|(\bsra\s*\.)|(\bto\s*\.)|(\bta\s*\.)|(\bvar\s*\.)')  

# Remove extra white spaces
whitespaces = re.compile(r'[ ]{2,}')

# Regular expression to clear punctuation from a string
clean_punct = re.compile('[%s]' % re.escape(string.punctuation))
clean_period = re.compile(r'\.')
# Regular expression to clear words that introduce unnecessary variability to headings. Some regex still not work 100% we need
# to improve them.
clean_capitulo = re.compile(r'(APARTADO \S*)|(APARTADO\s)|(^ART\.\s*\S*)|(^ART\.\s*)|(^Art\.\s*\S*)|(^Art\.\s*)|(^Arts\.\s*\S*)|(^[Aa][Rr][Tt][Ii][Cc][Uu][Ll][Oo]\.*\s*\S*\.-)|(Capítulo \S*)|(CAPITULO \S*)|(CAPITULO\S*)|(CAPÍTULO \S*)|(CAPITULÓ \S*)|(CAPITULOS \S*)|(CAPITUO \S*)|(CATEGORIA\b)|(CATEGORÍA\b)|(SUBCATEGORIA\b)|(SUBCATEGORÍA\b)|(TITULO\s\S*)|(TÍTULO\s\S*)')
clean_bullet_char = re.compile(r'^[A-Za-z]\s*\.|^[A-Za-z]\s*\.\s*|^[A-Za-z]\s*\-\s*|^[A-Za-z]\s*\)\s*|\.\s*\b[B-Za-z]\b|^[A-Z]{1,4}\s*\.')
clean_bullet_number = re.compile(r'^\d+\s*\.\s*-|^\d+\s*\.\s*\d*|^\d+\s*\.\s*[A-Za-z]\s|^\d+\)|^\d+\D\s')
clean_bullet_point = re.compile(r'^-\s*')

# %% [markdown]
# ### Functions

# %%
is_empty = re.compile(r'^\s*\r+\n*')
def is_empty_line(line):
    return bool(is_empty.findall(line))

is_line_break = re.compile(r'\.\s*$|\.\t*$|;\s*$|:\s*$|\s+y$')
def is_end_of_paragraph(line):
    return bool(is_line_break.findall(line))

# Function to calculate the uppercase ratio in a string. It is used to detect section headings
def uppercase_ratio(string):
    if len(re.findall(r'[a-z]',string)) == 0:
        return 1
    else:
        return(len(re.findall(r'[A-Z]',string))/len(re.findall(r'[a-z]',string)))

def end_of_heading(line, flag, content):
    if "URL" in line and "https:" in line:
        flag = False
        content = False
        return flag, content
    else:
        return flag, content

def is_section(line):
    section = False
    for key in section_tags:
        if key in line:
            section = True
            break
    return section
            
def end_of_document(line):
    end_of_file = False
    for key in end_of_file_tags:
        if key in line:
            end_of_file = True
            break
    return end_of_file

# Te function to clear html tags
def clean_html_tags(string):
  return cleanr.sub('', string)
    
def is_por_tanto(line):
    if "POR TANTO" in line:
        return True
    else:
        return False

# Function to remove the last lines of a document, the ones that contain the signatures of the officials. It depends on the
# dictionary "official_positions"
def remove_signatures(line):
    signature = False
    for key in official_positions:
        if key in line:
            signature = True
            break
    return signature

# Function to change accented words by non-accented counterparts. It depends on the dictionary "accent_marks_bugs" 
def remove_accents(string):
    for accent in accents_out.findall(string):
        string = string.replace(accent, accents_dict[accent])
    return string

# Function to merge headlines expressing the same concept in different words. It depends on the dictionary "merges"
def merge_concepts(line):
    for key in merges:
        if key in line:
            line = merges[key]
            break
    return line

def clean_bugs(line):
    for key in bugs:
        if key in line:
            line = line.replace(key, bugs[key])
    return line

def clean_special_characters(line):
    char = clean_special_char.findall(line)
    for item in char:
        for character in item:
            if character != '':
                line = line.replace(character, "")
    return line

def clean_acronyms(line):
    acro = clean_acron.findall(line)
    for item in acro:
        for acronym in item:
            if acronym != '':
                line = line.replace(acronym, clean_punct.sub('', acronym))
    return line

def clean_whitespace(line):
    if whitespaces.sub(' ', line).rstrip().lstrip() != None:
        return whitespaces.sub(' ', line).rstrip().lstrip()
    else:
        return line

decimal_points = re.compile(r'(\b\d+\s*\.\s*\d+|\(\.\)|\b\d+\.\s*[A-Za-z]|\b[A-Za-z]\.\s*\d+)')
def change_decimal_points(line):
    dec = decimal_points.findall(line)
    for decimal in dec:
        if decimal != '':
#             print(decimal)
            line = line.replace(decimal, clean_period.sub('^', decimal))
    return line

def get_decimal_points_back(line):
    line = line.replace("^", ".")
    return line
                
# Function sentence
def clean_sentence(string):
    string = clean_capitulo.sub('', string)
    string = clean_bullet_char.sub('', string).rstrip().lstrip()
    string = clean_bullet_number.sub('', string).rstrip().lstrip()
    string = clean_bullet_point.sub('', string).rstrip().lstrip()
    if string != "":
        return string
    else:
        return ""    
    
# points = re.compile(r'(\b\w+\s*\.\s*\b[^\d\W]+)')
# def check_points(line):
#     return points.findall(line)
#     print(points.findall(line))
# This is to check sentences that have just three words
points = re.compile(r'(\b\w+\b\s*){3,}')
def check_sentence(line):
    if points.findall(line):
        return True
    else:
        return False

def split_into_sentences(line, sep):
    sentence_list = []
    for sentence in line.split(sep):
        if check_sentence(sentence):
            sentence = sentence.rstrip().lstrip()
            sentence_list.append(sentence)
    return sentence_list

# Function to add items to the dictionary with duplicate removal
def add_to_dict(string, dictionary, dupl_dict):
    if string in dupl_dict or string == None:
        pass
    else:
        dupl_dict[string] = 0
        if string in dictionary:
            dictionary[string] = dictionary[string] + 1
        else:
            dictionary[string] = 1
    return dictionary
def full_cleaning(line):
    line = clean_html_tags(line)
    line = remove_accents(line)
    line = clean_special_characters(line)
    line = clean_bugs(line)
    line = clean_acronyms(line)
    line = clean_whitespace(line)
#     print(line)
    line = clean_sentence(line)
#     print(line)
    return line
def is_visto(string, section_name, counter, dictionary):
    if section_name == "VISTO" and len(split_into_sentences(string, ":")) > 1:
        visto = split_into_sentences(string, ":")
        for sentence in split_into_sentences(visto[1], ";"):
            counter += 1
            sentence_id = filename[0:7] + '_' + str(counter)
            dictionary[filename][section]["sentences"][sentence_id] = {"text" : sentence, "labels" : []}
    elif section == "VISTO" and len(split_into_sentences(string, ":")) < 2:
        for sentence in split_into_sentences(string, ";"):
            counter += 1
            sentence_id = filename[0:7] + '_' + str(counter)
            dictionary[filename][section]["sentences"][sentence_id] = {"text" : sentence, "labels" : []}
    return counter, dictionary

# %%
test_string = "Que el Art. 204 Ordinal 3*. y 5”. de la Constitución, regula. A. Hola, em dic Jordi. B. No sé massa perquè l'Art *. 22 conté 22.34€. Tanmateix sembla que la Licda. una cosa. voldria  55.22. no fotis"
# test_string = "Prova senzilleta per veure què passa si no hi ha punt"
test_string = clean_sentence(test_string)
test_string = clean_special_characters(test_string)
test_string = clean_acronyms(test_string)
test_string = clean_whitespace(test_string)
test_string = change_decimal_points(test_string)
print(test_string)
sentences = []
[sentences.append(sentence) for sentence in split_into_sentences(test_string)]
print(sentences)
# print(sentences)

# if check_sentence(test_string):
#

# %% [markdown]
# ### Pipeline to process files from S3 bucket
# By executing this cell you will go through all policies in El Salvador and process section headings that will be saved in a dictionary. This should be merged with the notebook that builds up the final json files out of plain txt files.

# %%
in_folder = "text-extraction/"
out_folder = "JSON/"
counter = 0
name4 = {}
name5 = {}
name6 = {}
name7 = {}
for obj in s3.Bucket('wri-latin-talent').objects.all().filter(Prefix='text-extraction'):
    if in_folder in obj.key and obj.key.replace(in_folder, "") != "":# and filename in obj.key   # Un comment the previous string to run the code just in one sample document.
        file = obj.get()['Body'].read().decode('utf-8')  #get the file from S3 and read the body content
        lines = file.split("\n") # Split by end of line and pipe lines into a list
        file_name = obj.key.replace(in_folder, "").replace('.pdf.txt', '')        
        name4[file_name[0:4]] = 0
        name5[file_name[0:5]] = 0
        name6[file_name[0:6]] = 0
        name7[file_name[0:7]] = 0

        counter += 1

# %%
print(counter)
print(len(name4))
print(len(name5))
print(len(name6))
print(len(name7))

# %%
string_test = "     Artículo 26º.- Los traslados médicos deberán justificarse mediante la presentación de certificado médico. Podrá contemplarse por indicación médica un solo acompañante si el estado de salud así lo amerita.\r\n"
print(string_test)
if is_end_of_paragraph(string_test):
    print("yes")
# Out:
#      Artículo 26º.- Los traslados médicos deberán justificarse mediante la presentación de certificado médico. Podrá contemplarse por indicación médica un solo acompañante si el estado de salud así lo amerita.
#
# yes

# %%
in_folder = "Chile/full/"
out_folder = "JSON/"
filename = "418ca89" # This is only if you want to test on a single file
# bag_of_words = {}
# sentences = []
# sentences_dict = {}
json_file = {}
for obj in s3.Bucket('wri-latin-talent').objects.all().filter(Prefix='Chile/full/'):
    if in_folder in obj.key and obj.key.replace(in_folder, "") != "" and filename in obj.key:#   # Un comment the previous string to run the code just in one sample document.
        file = obj.get()['Body'].read().decode('utf-8')  #get the file from S3 and read the body content
        lines = file.split("\n") # Split by end of line and pipe lines into a list
        key = obj.key.replace(in_folder, out_folder).replace('pdf.txt', 'json')
        filename = key.replace('.json', '').replace(out_folder, '')
        print(filename)
        json_file[filename] = {}
        line_counter = 0
        heading_flag = True
        heading_content = False
        has_section = False
        end_of_paragraph = True
        json_file[filename]["HEADING"] = {"tags" : [], "sentences" : {}}
        for line in lines:
            if is_empty_line(line):
                print("empty")
                continue
            print(line_counter)
            print(line)
            line = clean_whitespace(line)
            # Processing document heading
            if heading_flag:
                if "Tipo Norma" in line:
                    heading_content = True
                if heading_content:
                    line = full_cleaning(line)
                    if line != None:
                        if ":" in line:
                            line_counter += 1
                            sentence_id = filename[0:7] + '_' + str(line_counter)
                            json_file[filename]["HEADING"]["sentences"][sentence_id] = {"text" : line, "labels" : []}
                            json_file[filename]["HEADING"]["sentences"][sentence_id]["text"] = line
                        else:
                            json_file[filename]["HEADING"]["sentences"][sentence_id]["text"] = json_file[filename]["HEADING"]["sentences"][sentence_id]["text"] + " " + line
#                 print("**", line)
                heading_flag, heading_content = end_of_heading(line, heading_flag, heading_content)

            # Breaking when document signatures are found    
            elif end_of_document(line):
#                 print(line)
                break
            # Getting section headings
            elif (uppercase_ratio(line) == 1 and len(line) > 10 and line_counter > 0) or is_section(line):
#                 print("line--", line)
                line = remove_accents(line)
                line = clean_bugs(line)
                line = clean_sentence(line)
                if line == None:
                    continue
                else:
                    has_section = True
                    section = merge_concepts(line)
#                     print("**", section)
                    if section not in json_file[filename]:
                        json_file[filename][section] = {"tags" : [], "sentences" : {}}
                    line_counter, json_file = is_visto(line, section, line_counter, json_file)

            elif has_section:
                line = full_cleaning(line)
                if line == None:
                    continue                    
                else:
                    if section == "VISTO":
                        line_counter, json_file = is_visto(line, section, line_counter, json_file)
                    else:
                        line = change_decimal_points(line)
                        if is_end_of_paragraph(line):
                            print("end is yes", line)
                            if not end_of_paragraph:
                                json_file[filename][section]["sentences"][sentence_id]["text"] = json_file[filename][section]["sentences"][sentence_id]["text"] + " " + line                                
                                end_of_paragraph = True
                            else:
                                for sentence in split_into_sentences(line, "."):
                                    sentence = get_decimal_points_back(sentence)
                                    line_counter += 1
                                    sentence_id = filename[0:7] + '_' + str(line_counter)
                                    json_file[filename][section]["sentences"][sentence_id] = {"text" : sentence, "labels" : []}
                                    end_of_paragraph = True
                        else:
                            print("end is not",line)
                            if end_of_paragraph:
                                sentence = get_decimal_points_back(sentence)
                                line_counter += 1
                                sentence_id = filename[0:7] + '_' + str(line_counter)
                                json_file[filename][section]["sentences"][sentence_id] = {"text" : line, "labels" : []}
                                end_of_paragraph = False
                            else:
                                json_file[filename][section]["sentences"][sentence_id]["text"] = json_file[filename][section]["sentences"][sentence_id]["text"] + " " + line
                            
#         s3.Object('wri-latin-talent', key).put(Body = str(json.dumps(json_file)))#This will save all the contents in the string variable "content" into a txt file in the Pre-processed folder
# Out:
# 418ca899c646b9c1b2d21392d7241dad4e381f2b
# 0
#  Biblioteca del Congreso Nacional
# 0
#  --------------------------------
# empty
# empty
# empty
# 0
# Tipo Norma               :Decreto 112 EXENTO
# 1
# Fecha Publicación        :09-01-2014
# 2
# Fecha Promulgación       :21-10-2013
# 3
# Organismo                :MINISTERIO DEL TRABAJO Y PREVISIÓN SOCIAL; SUBSECRETARÍA
# 4
#                           DE PREVISIÓN SOCIAL
# 4
# Título                   :DEROGA REGLAMENTO PARTICULAR DEL SERVICIO DE BIENESTAR DE
# 5
#                           LOS TRABAJADORES DE LA EMPRESA NACIONAL DE MINERÍA,
# 5
#                           APROBADO POR DECRETO Nº 163, DE 1995, Y APRUEBA NUEVO
# 5
#                           REGLAMENTO PARTICULAR DEL MISMO SERVICIO
# 5
# Tipo Versión             :Texto Original     De : 09-ENE-2014
# 6
# Inicio Vigencia          :09-01-2014
# 7
# Fin Vigencia             :20-06-2014
# 8
# Id Norma                 :1058088
# 9
# URL                      :https://www.leychile.cl/N?i=1058088&f=2014-01-09
# empty
# empty
# empty
# empty
# 10
# DEROGA REGLAMENTO PARTICULAR DEL SERVICIO DE BIENESTAR DE LOS TRABAJADORES DE LA EMPRESA NACIONAL DE MINERÍA, APROBADO POR DECRETO Nº 163, DE 1995, Y APRUEBA NUEVO REGLAMENTO PARTICULAR DEL MISMO SERVICIO
# empty
# 10
#      Núm. 112 exento.- Santiago, 21 de octubre de 2013.- Vistos: Lo dispuesto en el artículo 134 de la ley Nº 11.764; en el artículo 24 de la ley Nº 16.395; en la ley Nº 17.538; en el decreto supremo Nº 28, de 1994, del Ministerio del Trabajo y Previsión Social, y decreto supremo Nº 4, de 2013, del Ministerio del Trabajo y Previsión Social; en la resolución Nº 1.600, de 2008, de la Contraloría General de la República; en lo informado por la Superintendencia de Seguridad Social, y en la facultad que me confiere el artículo 32 Nº 6 de la Constitución Política de la República.
# empty
# 16
#      Decreto:
# empty
# empty
# 16
#      1.- Derógase el Reglamento del Servicio de Bienestar de la Empresa Nacional de Minería, aprobado por DS Nº 163, del 31 de octubre de 1995, modificado por DS Nº 2, del 4 de enero de 2005, y el decreto exento Nº 7 de 1 de febrero de 2010, todos del Ministerio del Trabajo y Previsión Social, Subsecretaría de Previsión Social.
# end is yes Derogase el Reglamento del Servicio de Bienestar de la Empresa Nacional de Mineria, aprobado por DS Nº 163, del 31 de octubre de 1995, modificado por DS Nº 2, del 4 de enero de 2005, y el decreto exento Nº 7 de 1 de febrero de 2010, todos del Ministerio del Trabajo y Prevision Social, Subsecretaria de Prevision Social.
# empty
# empty
# empty
# 17
#      2. Apruébase el siguiente Reglamento para el Servicio de Bienestar de los Trabajadores de la Empresa Nacional de Minería.
# end is yes Apruebase el siguiente Reglamento para el Servicio de Bienestar de los Trabajadores de la Empresa Nacional de Mineria.
# empty
# empty
# empty
# empty
# 18
#      TÍTULO I
# end is not
# 19
#      Del Servicio de Bienestar
# end is not Del Servicio de Bienestar
# empty
# empty
# empty
# 19
#      Artículo 1º.- El Servicio de Bienestar de la Empresa Nacional de Minería, en adelante "el Servicio de Bienestar", tendrá por objeto proveer asistencia médica, económica y social a los trabajadores afiliados y a sus cargas familiares legalmente acreditadas, en la medida que sus recursos financieros lo permitan y todo ello dentro de las normas que se establecen en el DS Nº 28, de 1994, del Ministerio del Trabajo y Previsión Social, en adelante "Reglamento General", y en el presente Reglamento.
# end is yes El Servicio de Bienestar de la Empresa Nacional de Mineria, en adelante "el Servicio de Bienestar", tendra por objeto proveer asistencia medica, economica y social a los trabajadores afiliados y a sus cargas familiares legalmente acreditadas, en la medida que sus recursos financieros lo permitan y todo ello dentro de las normas que se establecen en el DS Nº 28, de 1994, del Ministerio del Trabajo y Prevision Social, en adelante "Reglamento General", y en el presente Reglamento.
# empty
# 19
#      TÍTULO II
# end is not
# 20
#      De los beneficios, subsidios y préstamos
# end is not De los beneficios, subsidios y prestamos
# empty
# empty
# empty
# 20
#      Artículo 2º.- Los afiliados al Servicio de Bienestar y sus cargas familiares legalmente acreditadas, de acuerdo a las disponibilidades presupuestarias, tendrán derecho a gozar de los beneficios, subsidios y préstamos sociales en la forma que en cada caso se indica.
# end is yes Los afiliados al Servicio de Bienestar y sus cargas familiares legalmente acreditadas, de acuerdo a las disponibilidades presupuestarias, tendran derecho a gozar de los beneficios, subsidios y prestamos sociales en la forma que en cada caso se indica.
# empty
# empty
# 20
#      Párrafo Primero
# end is not Parrafo Primero
# 21
#      De los beneficios de salud
# end is not De los beneficios de salud
# empty
# empty
# empty
# 21
#      Artículo 3º.- El Servicio de Bienestar otorgará los siguientes beneficios a todos sus afiliados y cargas familiares legalmente acreditadas, por los siguientes conceptos:
# end is yes El Servicio de Bienestar otorgara los siguientes beneficios a todos sus afiliados y cargas familiares legalmente acreditadas, por los siguientes conceptos:
# empty
# 21
#      a. Medicamentos.
# end is yes Medicamentos.
# 21
#      b. Traslados y estadía por motivos médicos.
# end is yes Traslados y estadia por motivos medicos.
# empty
# 22
#      El Consejo Administrativo determinará anualmente, en su primera sesión, los porcentajes de las bonificaciones que serán de cargo del Servicio de Bienestar, y el monto máximo a que podrán ascender para cada prestación. Estos beneficios serán informados a los socios a través de circulares.
# end is yes El Consejo Administrativo determinara anualmente, en su primera sesion, los porcentajes de las bonificaciones que seran de cargo del Servicio de Bienestar, y el monto maximo a que podran ascender para cada prestacion. Estos beneficios seran informados a los socios a traves de circulares.
# 24
#      Adicionalmente, el Servicio de Bienestar otorgará los siguientes beneficios médicos a todos sus afiliados activos y pasivos, y a sus respectivas cargas familiares legalmente acreditadas, siempre que no los hayan percibido, en virtud de un contrato de seguro complementario de salud contratado al efecto por la Empresa Nacional de Minería:
# end is yes Adicionalmente, el Servicio de Bienestar otorgara los siguientes beneficios medicos a todos sus afiliados activos y pasivos, y a sus respectivas cargas familiares legalmente acreditadas, siempre que no los hayan percibido, en virtud de un contrato de seguro complementario de salud contratado al efecto por la Empresa Nacional de Mineria:
# empty
# 25
#      a) Consulta médica, consulta médica domiciliaria,
# end is not Consulta medica, consulta medica domiciliaria,
# 26
#         interconsulta y junta médica;
# end is yes interconsulta y junta medica;
# 26
#      b) Intervención quirúrgica, atención de anestesista y
# end is yes Intervencion quirurgica, atencion de anestesista y
# 27
#         arsenalera;
# end is yes arsenalera;
# 27
#      c) Hospitalizaciones;
# end is yes Hospitalizaciones;
# 27
#      d) Exámenes de laboratorio, rayos X, histopatológicos y
# end is yes Examenes de laboratorio, rayos X, histopatologicos y
# 28
#         especializados de carácter médico;
# end is yes especializados de caracter medico;
# 29
#      e) Atención odontológica;
# end is yes Atencion odontologica;
# 29
#      f) Implantes;
# end is yes Implantes;
# 29
#      g) Marcapasos;
# end is yes Marcapasos;
# 29
#      h) Tratamientos médicos especializados;
# end is yes Tratamientos medicos especializados;
# 30
#      i) Consulta y tratamientos especializados para la
# end is not Consulta y tratamientos especializados para la
# 31
#         recuperación de la salud efectuados por el personal
# end is not recuperacion de la salud efectuados por el personal
# 31
#         profesional o técnico autorizado de colaboración médica;
# end is yes profesional o tecnico autorizado de colaboracion medica;
# 31
#      j) Adquisición de anteojos, lentes de contacto, audífonos y
# end is yes Adquisicion de anteojos, lentes de contacto, audifonos y
# 32
#         aparatos ortopédicos;
# end is yes aparatos ortopedicos;
# 32
#      k) Toma de muestras de exámenes a domicilio;
# end is yes Toma de muestras de examenes a domicilio;
# 33
#      l) Atención de urgencia, primeros auxilios y enfermería;
# end is yes Atencion de urgencia, primeros auxilios y enfermeria;
# 34
#      m) Atención obstétrica, y
# end is yes Atencion obstetrica, y
# 34
#      n) Insumos necesarios para el otorgamiento de las
# end is not Insumos necesarios para el otorgamiento de las
# 35
#         prestaciones referidas en las letras b), c), f), g), h),
# end is not prestaciones referidas en las letras b), c), f), g), h),
# 35
#         i), j) y l) precedentes.
# end is yes , j) y l) precedentes.
# empty
# 35
#      Para los afiliados pasivos que ya no cuenten con un seguro complementario de salud contratado por la Empresa Nacional de Minería, los porcentajes que se determinen para las bonificaciones indicadas en este artículo se entenderán referidos a los derechos arancelarios fijados para la modalidad de libre elección del DFL Nº 1, de 2005, del Ministerio de Salud.
# end is yes Para los afiliados pasivos que ya no cuenten con un seguro complementario de salud contratado por la Empresa Nacional de Mineria, los porcentajes que se determinen para las bonificaciones indicadas en este articulo se entenderan referidos a los derechos arancelarios fijados para la modalidad de libre eleccion del DFL Nº 1, de 2005, del Ministerio de Salud.
# 36
#      Respecto de las prestaciones que no estuvieren consideradas en dicho arancel, el porcentaje de la ayuda se aplicará sobre el valor real de la prestación, no pudiendo exceder el monto del beneficio del tope máximo que hubiere fijado el Consejo Administrativo.
# end is yes Respecto de las prestaciones que no estuvieren consideradas en dicho arancel, el porcentaje de la ayuda se aplicara sobre el valor real de la prestacion, no pudiendo exceder el monto del beneficio del tope maximo que hubiere fijado el Consejo Administrativo.
# empty
# empty
# empty
# 37
#      Artículo 4º.- El Servicio de Bienestar podrá financiar, de acuerdo con sus disponibilidades presupuestarias, el valor de las primas de seguros con cargo a sus propios recursos, y contratar seguros de vida para sus afiliados y seguros de salud para ellos y sus cargas legalmente acreditadas, con el objeto de solventar los gastos de salud no cubiertos por los sistemas de salud previsional.
# end is yes El Servicio de Bienestar podra financiar, de acuerdo con sus disponibilidades presupuestarias, el valor de las primas de seguros con cargo a sus propios recursos, y contratar seguros de vida para sus afiliados y seguros de salud para ellos y sus cargas legalmente acreditadas, con el objeto de solventar los gastos de salud no cubiertos por los sistemas de salud previsional.
# empty
# 38
#      Párrafo Segundo
# end is not Parrafo Segundo
# 39
#      De los subsidios de orden económico
# end is not De los subsidios de orden economico
# empty
# empty
# empty
# 39
#      Artículo 5º.- El Servicio de Bienestar otorgará los siguientes subsidios no sujetos a restitución, por las causales y de acuerdo con las modalidades que a continuación se indican:
# end is yes El Servicio de Bienestar otorgara los siguientes subsidios no sujetos a restitucion, por las causales y de acuerdo con las modalidades que a continuacion se indican:
# empty
# 39
#      a) Matrimonio: Se otorgará un subsidio a cada afiliado que contraiga
# end is not Matrimonio: Se otorgara un subsidio a cada afiliado que contraiga
# 40
#         matrimonio. Si ambos contrayentes fueren afiliados, el subsidio se
# end is not matrimonio. Si ambos contrayentes fueren afiliados, el subsidio se
# 40
#         pagará a cada uno de ellos;
# end is yes pagara a cada uno de ellos;
# 40
#      b) Nacimiento: Se otorgará al afiliado un subsidio cuando compruebe el
# end is not Nacimiento: Se otorgara al afiliado un subsidio cuando compruebe el
# 41
#         nacimiento de cada hijo con el certificado correspondiente. En caso
# end is not nacimiento de cada hijo con el certificado correspondiente. En caso
# 41
#         de nacimientos múltiples, se otorgará este subsidio por cada hijo
# end is not de nacimientos multiples, se otorgara este subsidio por cada hijo
# 41
#         nacido vivo.
# end is yes nacido vivo.
# empty
# 41
#      Si ambos padres son afiliados, el subsidio de nacimiento lo percibirá cada uno de ellos;
# end is yes Si ambos padres son afiliados, el subsidio de nacimiento lo percibira cada uno de ellos;
# empty
# 42
#      c) Fallecimiento: Se otorgará un subsidio por fallecimiento del
# end is not Fallecimiento: Se otorgara un subsidio por fallecimiento del
# 43
#         afiliado y de cada una de sus cargas familiares, incluido el
# end is not afiliado y de cada una de sus cargas familiares, incluido el
# 43
#         mortinato a partir del quinto mes de gestación y el fallecimiento
# end is not mortinato a partir del quinto mes de gestacion y el fallecimiento
# 43
#         del hijo recién nacido que no hubiere sido aún reconocido como carga
# end is not del hijo recien nacido que no hubiere sido aun reconocido como carga
# 43
#         familiar.
# end is yes familiar.
# empty
# 43
#      En caso de fallecimiento del afiliado, esta ayuda se pagará en el siguiente orden de precedencia:
# end is yes En caso de fallecimiento del afiliado, esta ayuda se pagara en el siguiente orden de precedencia:
# empty
# 44
#      1) A la persona que el afiliado haya designado expresamente para este
# end is not A la persona que el afiliado haya designado expresamente para este
# 45
#         efecto.
# end is yes efecto.
# 45
#      2) Al cónyuge sobreviviente.
# end is yes Al conyuge sobreviviente.
# 46
#      3) A los herederos del causante.
# end is yes A los herederos del causante.
# 47
#      4) A la persona que haya efectuado los gastos, los que deberán ser
# end is not A la persona que haya efectuado los gastos, los que deberan ser
# 48
#         debidamente acreditados.
# end is yes debidamente acreditados.
# empty
# 48
#      Si ambos padres son afiliados, el subsidio de fallecimiento en caso de mortinato o de fallecimiento del recién nacido que no hubiere sido aún reconocido como carga familiar lo percibirá cada uno de ellos.
# end is yes Si ambos padres son afiliados, el subsidio de fallecimiento en caso de mortinato o de fallecimiento del recien nacido que no hubiere sido aun reconocido como carga familiar lo percibira cada uno de ellos.
# empty
# 49
#      d) Becas de estudio: El afiliado tendrá derecho, una vez al año, al
# end is not Becas de estudio: El afiliado tendra derecho, una vez al año, al
# 50
#         pago de este beneficio, cuando curse estudios regulares de enseñanza
# end is not pago de este beneficio, cuando curse estudios regulares de enseñanza
# 50
#         básica, media, técnica especializada o superior, en establecimientos
# end is not basica, media, tecnica especializada o superior, en establecimientos
# 50
#         del Estado o reconocidos por éste, y
# end is yes del Estado o reconocidos por este, y
# 50
#      e) Ayuda médica: En caso de enfermedad grave y/o tratamiento médico
# end is not Ayuda medica: En caso de enfermedad grave y/o tratamiento medico
# 51
#         prolongado de alto costo, calificados como tales por el Consejo
# end is not prolongado de alto costo, calificados como tales por el Consejo
# 51
#         Administrativo, del afiliado o de sus cargas familiares legalmente
# end is not Administrativo, del afiliado o de sus cargas familiares legalmente
# 51
#         acreditadas, se podrá otorgar al afiliado un subsidio económico
# end is not acreditadas, se podra otorgar al afiliado un subsidio economico
# 51
#         complementario a los contemplados en el artículo 3º del presente
# end is not complementario a los contemplados en el articulo 3º del presente
# 51
#         Reglamento. Se exceptúan, para estos efectos, las enfermedades y
# end is yes Reglamento. Se exceptuan, para estos efectos, las enfermedades y
# 51
#         tratamientos oncológicos del afiliado en la parte cubierta por
# end is not tratamientos oncologicos del afiliado en la parte cubierta por
# 52
#         seguros contratados por la Empresa Nacional de Minería.
# end is yes seguros contratados por la Empresa Nacional de Mineria.
# empty
# 52
#      Párrafo Tercero
# end is not Parrafo Tercero
# 53
#      De los préstamos y Fondos a Rendir Cuenta
# end is not De los prestamos y Fondos a Rendir Cuenta
# empty
# empty
# empty
# 53
#      Artículo 6º.- El Servicio de Bienestar concederá los préstamos no reajustables que a continuación se señalan:
# end is yes El Servicio de Bienestar concedera los prestamos no reajustables que a continuacion se señalan:
# empty
# 53
#      a) Préstamo asistencial: Se otorgará como ayuda a los
# end is not Prestamo asistencial: Se otorgara como ayuda a los
# 54
#         beneficios médicos establecidos en el artículo 3º.
# end is yes beneficios medicos establecidos en el articulo 3º.
# 54
#      b) Préstamo de emergencia: Se otorgará para atender
# end is not Prestamo de emergencia: Se otorgara para atender
# 55
#         necesidades y problemas socioeconómicos del
# end is not necesidades y problemas socioeconomicos del
# 55
#         afiliado.
# end is yes afiliado.
# 55
#      c) Fondos a Rendir Cuenta: Los Fondos a Rendir Cuenta
# end is not Fondos a Rendir Cuenta: Los Fondos a Rendir Cuenta
# 56
#         deberán entregarse sólo por concepto de enfermedad
# end is not deberan entregarse solo por concepto de enfermedad
# 56
#         y deberán rendirse antes de noventa (90) días,
# end is not y deberan rendirse antes de noventa (90) dias,
# 56
#         contados desde la fecha de su otorgamiento.
# end is yes contados desde la fecha de su otorgamiento.
# empty
# 56
#      El monto máximo de los préstamos antes señalados será determinado anualmente por el Consejo Administrativo, y su reintegro deberá efectuarse en un plazo no superior a 24 meses, respecto de la letra a), y a 12 meses en el caso de la letra b).
# end is yes El monto maximo de los prestamos antes señalados sera determinado anualmente por el Consejo Administrativo, y su reintegro debera efectuarse en un plazo no superior a 24 meses, respecto de la letra a), y a 12 meses en el caso de la letra b).
# 57
#      Los plazos indicados en el inciso anterior podrán ser reducidos a solicitud del afiliado, en cuyo caso los intereses correspondientes se devengarán hasta la fecha de los pagos respectivos.
# end is yes Los plazos indicados en el inciso anterior podran ser reducidos a solicitud del afiliado, en cuyo caso los intereses correspondientes se devengaran hasta la fecha de los pagos respectivos.
# empty
# empty
# empty
# 58
#      Artículo 7º.- Para conceder un préstamo el Consejo Administrativo deberá considerar, especialmente, las posibilidades de recuperación de los dineros prestados. Además, será requisito indispensable la constitución de la garantía de dos codeudores solidarios, que sean trabajadores con contrato de trabajo de duración indefinida y su solvencia será calificada por dicho Consejo Administrativo.
# end is yes Para conceder un prestamo el Consejo Administrativo debera considerar, especialmente, las posibilidades de recuperacion de los dineros prestados. Ademas, sera requisito indispensable la constitucion de la garantia de dos codeudores solidarios, que sean trabajadores con contrato de trabajo de duracion indefinida y su solvencia sera calificada por dicho Consejo Administrativo.
# empty
# 60
#      Para solicitar cualquier tipo de préstamo el afiliado deberá tener, por lo menos, tres meses de afiliación ininterrumpida al Servicio de Bienestar.
# end is yes Para solicitar cualquier tipo de prestamo el afiliado debera tener, por lo menos, tres meses de afiliacion ininterrumpida al Servicio de Bienestar.
# empty
# empty
# 61
#      Artículo 8º.- El reintegro de los préstamos señalados en las letras a) y b) del artículo 5º, deberá hacerse en cuotas mensuales, iguales y sucesivas. Las referidas cuotas serán descontadas a partir del mes siguiente al de su otorgamiento. La tasa de interés que devengarán estos préstamos será fijada anualmente por el Consejo Administrativo, antes del inicio de cada ejercicio financiero, y consistirá en un porcentaje del interés corriente para operaciones no reajustables fijado por la Superintendencia de Bancos e Instituciones Financieras, vigente al día primero del mes en que se otorga el préstamo.
# end is yes El reintegro de los prestamos señalados en las letras a) y b) del articulo 5º, debera hacerse en cuotas mensuales, iguales y sucesivas. Las referidas cuotas seran descontadas a partir del mes siguiente al de su otorgamiento. La tasa de interes que devengaran estos prestamos sera fijada anualmente por el Consejo Administrativo, antes del inicio de cada ejercicio financiero, y consistira en un porcentaje del interes corriente para operaciones no reajustables fijado por la Superintendencia de Bancos e Instituciones Financieras, vigente al dia primero del mes en que se otorga el prestamo.
# empty
# 64
#      Para que el afiliado solicite un nuevo préstamo de aquellos señalados en las letras a), b) y c) del artículo 5º, será necesario haber pagado la totalidad de la deuda que mantenga por el mismo concepto.
# end is yes Para que el afiliado solicite un nuevo prestamo de aquellos señalados en las letras a), b) y c) del articulo 5º, sera necesario haber pagado la totalidad de la deuda que mantenga por el mismo concepto.
# empty
# empty
# 65
#      Artículo 9º.- El afiliado, de manera previa a la obtención de cualquiera de los prestamos señalados en el artículo 5º, deberá autorizar expresamente y por escrito al Servicio de Bienestar para realizar estos descuentos en sus remuneraciones para así pagar dichos préstamos.
# end is yes El afiliado, de manera previa a la obtencion de cualquiera de los prestamos señalados en el articulo 5º, debera autorizar expresamente y por escrito al Servicio de Bienestar para realizar estos descuentos en sus remuneraciones para asi pagar dichos prestamos.
# empty
# 66
#      Estos descuentos en su conjunto no podrán ser superiores al quince por ciento (15%) de la remuneración total del afiliado.
# end is yes Estos descuentos en su conjunto no podran ser superiores al quince por ciento (15%) de la remuneracion total del afiliado.
# empty
# 67
#      TÍTULO III
# end is not
# 68
#      Del Consejo Administrativo
# end is not Del Consejo Administrativo
# empty
# empty
# empty
# 68
#      Artículo 10º.- El Servicio de Bienestar será administrado por un Consejo Administrativo compuesto de ocho miembros e integrado de la siguiente forma:
# end is yes El Servicio de Bienestar sera administrado por un Consejo Administrativo compuesto de ocho miembros e integrado de la siguiente forma:
# empty
# 68
#      a) Por el Vicepresidente Ejecutivo, en su calidad de Jefe Superior de
# end is not Por el Vicepresidente Ejecutivo, en su calidad de Jefe Superior de
# 69
#         la Empresa, o por la persona que éste designe en su reemplazo, quien
# end is not la Empresa, o por la persona que este designe en su reemplazo, quien
# 69
#         lo presidirá.
# end is yes lo presidira.
# 69
#      b) Por dos representantes de la Empresa Nacional de Minería elegidos
# end is not Por dos representantes de la Empresa Nacional de Mineria elegidos
# 70
#         por el Vicepresidente Ejecutivo de la Empresa, uno de los cuales
# end is not por el Vicepresidente Ejecutivo de la Empresa, uno de los cuales
# 70
#         actuará como Vicepresidente del Consejo Administrativo y reemplazará
# end is not actuara como Vicepresidente del Consejo Administrativo y reemplazara
# 70
#         al Presidente en ausencia o impedimento de éste. En caso de ausencia
# end is not al Presidente en ausencia o impedimento de este. En caso de ausencia
# 70
#         o impedimento del Vicepresidente del Consejo Administrativo será
# end is not o impedimento del Vicepresidente del Consejo Administrativo sera
# 70
#         reemplazado por su suplente en el cargo.
# end is yes reemplazado por su suplente en el cargo.
# 70
#      c) Por el Fiscal de la empresa o el abogado de la institución que éste
# end is not Por el Fiscal de la empresa o el abogado de la institucion que este
# 71
#         designe al efecto. En este último caso se deberá designar un abogado
# end is not designe al efecto. En este ultimo caso se debera designar un abogado
# 71
#         titular y otro suplente, y
# end is yes titular y otro suplente, y
# 71
#      d) Por cuatro representantes de los trabajadores afiliados, uno de los
# end is not Por cuatro representantes de los trabajadores afiliados, uno de los
# 72
#         cuales será designado por el Sindicato de Trabajadores, cuando
# end is not cuales sera designado por el Sindicato de Trabajadores, cuando
# 72
#         proceda, de acuerdo con lo dispuesto en el inciso tercero del
# end is not proceda, de acuerdo con lo dispuesto en el inciso tercero del
# 72
#         artículo 18 del Reglamento General.
# end is yes articulo 18 del Reglamento General.
# empty
# 72
#      El Contador del Servicio de Bienestar actuará como Secretario del Consejo Administrativo, teniendo derecho a voz pero no a voto. Los representantes de los trabajadores afiliados en el Consejo Administrativo, a que se refiere esta letra, deberán cumplir los requisitos establecidos en el artículo 12º de este Reglamento.
# end is yes El Contador del Servicio de Bienestar actuara como Secretario del Consejo Administrativo, teniendo derecho a voz pero no a voto. Los representantes de los trabajadores afiliados en el Consejo Administrativo, a que se refiere esta letra, deberan cumplir los requisitos establecidos en el articulo 12º de este Reglamento.
# empty
# empty
# 74
#      Artículo 11º.- Los representantes titulares y suplentes de los trabajadores afiliados al Consejo Administrativo, serán elegidos por éstos en votación directa y secreta en un solo acto. Resultarán elegidos los que obtengan las más altas mayorías, durarán dos años en sus funciones y podrán ser reelegidos hasta por dos períodos consecutivos. En caso de impedimento o ausencia temporal, serán reemplazados por los suplentes. Se entenderán elegidos suplentes los afiliados que tengan las siguientes mayorías.
# end is yes Los representantes titulares y suplentes de los trabajadores afiliados al Consejo Administrativo, seran elegidos por estos en votacion directa y secreta en un solo acto. Resultaran elegidos los que obtengan las mas altas mayorias, duraran dos años en sus funciones y podran ser reelegidos hasta por dos periodos consecutivos. En caso de impedimento o ausencia temporal, seran reemplazados por los suplentes. Se entenderan elegidos suplentes los afiliados que tengan las siguientes mayorias.
# empty
# empty
# 78
#      Artículo 12º.- La elección de los representantes de los trabajadores afiliados en el Consejo Administrativo se llevará a efecto 15 días antes de la expiración de sus funciones. El escrutinio final se practicará por los integrantes a que se refieren las letras a), b) y c) del artículo 9º y por un representante de los afiliados de la letra d) del mismo artículo, elegidos por ellos mismos y será público.
# end is yes La eleccion de los representantes de los trabajadores afiliados en el Consejo Administrativo se llevara a efecto 15 dias antes de la expiracion de sus funciones. El escrutinio final se practicara por los integrantes a que se refieren las letras a), b) y c) del articulo 9º y por un representante de los afiliados de la letra d) del mismo articulo, elegidos por ellos mismos y sera publico.
# empty
# empty
# 80
#      Artículo 13º.- Para ser elegido representante de los afiliados al Consejo Administrativo, se requiere:
# end is yes Para ser elegido representante de los afiliados al Consejo Administrativo, se requiere:
# empty
# 81
#      a) Ser afiliado del Servicio de Bienestar con una antigüedad no
# end is not Ser afiliado del Servicio de Bienestar con una antigüedad no
# 82
#         inferior a seis meses;
# end is yes inferior a seis meses;
# 82
#      b) No ser integrante del Consejo Administrativo en representación de la
# end is not No ser integrante del Consejo Administrativo en representacion de la
# 83
#         entidad empleadora;
# end is yes entidad empleadora;
# 83
#      c) No haber sido objeto de medida disciplinaria alguna durante el año
# end is not No haber sido objeto de medida disciplinaria alguna durante el año
# 84
#         anterior de la elección, y
# end is yes anterior de la eleccion, y
# 84
#      d) Estar al día en el cumplimiento de sus obligaciones con el Servicio
# end is not Estar al dia en el cumplimiento de sus obligaciones con el Servicio
# 85
#         de Bienestar.
# end is yes de Bienestar.
# empty
# empty
# 85
#      Artículo 14º.- El Consejo Administrativo celebrará sesiones ordinarias y extraordinarias. En las sesiones extraordinarias sólo podrán tratarse las materias determinadas en la convocatoria o en el acuerdo que las origine.
# end is yes El Consejo Administrativo celebrara sesiones ordinarias y extraordinarias. En las sesiones extraordinarias solo podran tratarse las materias determinadas en la convocatoria o en el acuerdo que las origine.
# empty
# 87
#      Las citaciones a ambos tipos de sesiones se harán por escrito por el Presidente del Consejo del Servicio de Bienestar, con 72 horas de anticipación a lo menos.
# end is yes Las citaciones a ambos tipos de sesiones se haran por escrito por el Presidente del Consejo del Servicio de Bienestar, con 72 horas de anticipacion a lo menos.
# empty
# empty
# 88
#      Artículo 15º.- El Consejo Administrativo sesionará a lo menos cada dos meses, con la mayoría absoluta de sus miembros, y sus decisiones se tomarán por simple mayoría, salvo las excepciones que se consignen en el presente Reglamento. En caso de empate decidirá el voto del Presidente.
# end is yes El Consejo Administrativo sesionara a lo menos cada dos meses, con la mayoria absoluta de sus miembros, y sus decisiones se tomaran por simple mayoria, salvo las excepciones que se consignen en el presente Reglamento. En caso de empate decidira el voto del Presidente.
# empty
# 90
#      TÍTULO IV
# end is not
# 91
#      Del financiamiento, presupuesto y control de cuentas
# end is not Del financiamiento, presupuesto y control de cuentas
# empty
# empty
# empty
# 91
#      Artículo 16º.- El Servicio de Bienestar se financiará con los siguientes recursos:
# end is yes El Servicio de Bienestar se financiara con los siguientes recursos:
# empty
# 91
#      a) Con una cuota de incorporación que pagarán al ingresar los
# end is not Con una cuota de incorporacion que pagaran al ingresar los
# 92
#         trabajadores afiliados, equivalente al 1% de sus remuneraciones
# end is not trabajadores afiliados, equivalente al 1% de sus remuneraciones
# 92
#         mensuales imponibles para pensiones o de sus pensiones según
# end is not mensuales imponibles para pensiones o de sus pensiones segun
# 92
#         corresponda;
# end is yes corresponda;
# 92
#      b) Con un aporte de la Empresa equivalente a la cuota de incorporación
# end is not Con un aporte de la Empresa equivalente a la cuota de incorporacion
# 93
#         de los trabajadores afiliados;
# end is yes de los trabajadores afiliados;
# 93
#      c) Con un aporte mensual sobre la totalidad de las remuneraciones
# end is not Con un aporte mensual sobre la totalidad de las remuneraciones
# 94
#         imponibles para pensiones de los trabajadores afiliados al Servicio
# end is not imponibles para pensiones de los trabajadores afiliados al Servicio
# 94
#         de Bienestar, que será de cargo de la Empresa, el cual no podrá ser
# end is not de Bienestar, que sera de cargo de la Empresa, el cual no podra ser
# 94
#         inferior al 1%;
# end is yes inferior al 1%;
# 94
#      d) Con un aporte mensual sobre la totalidad de las remuneraciones
# end is not Con un aporte mensual sobre la totalidad de las remuneraciones
# 95
#         imponibles para pensiones de los trabajadores afiliados al Servicio
# end is not imponibles para pensiones de los trabajadores afiliados al Servicio
# 95
#         de Bienestar, que será de cargo de éstos, el que no podrá exceder
# end is not de Bienestar, que sera de cargo de estos, el que no podra exceder
# 95
#         del 3%;
# end is yes del 3%;
# 95
#      e) Con un aporte mensual sobre la totalidad de su pensión de
# end is not Con un aporte mensual sobre la totalidad de su pension de
# 96
#         jubilación, de cargo de los jubilados, cuyo porcentaje deberá ser
# end is not jubilacion, de cargo de los jubilados, cuyo porcentaje debera ser
# 96
#         igual al de la Empresa y al fijado para los afiliados activos
# end is not igual al de la Empresa y al fijado para los afiliados activos
# 96
#         indicados en la letra d) precedente;
# end is yes indicados en la letra d) precedente;
# 96
#      f) Con los intereses que devenguen los préstamos en dinero;
# end is yes Con los intereses que devenguen los prestamos en dinero;
# 97
#      g) Con las donaciones, herencias, legados, aportes extraordinarios,
# end is not Con las donaciones, herencias, legados, aportes extraordinarios,
# 98
#         erogaciones voluntarias y asignaciones que la empresa, los afiliados
# end is not erogaciones voluntarias y asignaciones que la empresa, los afiliados
# 98
#         o cualquier tercero otorgue al Servicio de Bienestar, y
# end is yes o cualquier tercero otorgue al Servicio de Bienestar, y
# 98
#      h) Con los demás bienes o recursos que adquiera o reciba a cualquier
# end is not Con los demas bienes o recursos que adquiera o reciba a cualquier
# 99
#         título.
# end is yes titulo.
# empty
# empty
# 99
#      Artículo 17º.- Los fondos del Servicio de Bienestar deberán ser depositados en una cuenta corriente bancaria por repartición, en contra de las cuales deberán girar conjuntamente un apoderado clase "A" y "B", designados de acuerdo a la normativa interna de la Empresa.
# end is yes Los fondos del Servicio de Bienestar deberan ser depositados en una cuenta corriente bancaria por reparticion, en contra de las cuales deberan girar conjuntamente un apoderado clase "A" y "B", designados de acuerdo a la normativa interna de la Empresa.
# empty
# 100
#      TÍTULO V
# end is not
# 101
#      Disposiciones Generales
# end is not Disposiciones Generales
# empty
# empty
# empty
# 101
#      Artículo 18º.- No podrá establecerse en las normas o procedimientos internos, diferencia alguna entre los afiliados con respecto a los beneficios que otorga el presente Reglamento.
# end is yes No podra establecerse en las normas o procedimientos internos, diferencia alguna entre los afiliados con respecto a los beneficios que otorga el presente Reglamento.
# empty
# empty
# 101
#      Artículo 19º.- Los afiliados tendrán derecho a percibir la totalidad de los beneficios médicos que otorgue el Servicio de Bienestar a contar del primer día hábil del mes siguiente de efectuado el descuento de su remuneración mensual, de la cuota de incorporación y el aporte mensual. Los subsidios y préstamos contemplados en los artículos 4º y 5º del Reglamento, podrán solicitarse tres meses después que el afiliado se incorpore al Servicio de Bienestar o dentro de los plazos especiales establecidos en el presente Reglamento.
# end is yes Los afiliados tendran derecho a percibir la totalidad de los beneficios medicos que otorgue el Servicio de Bienestar a contar del primer dia habil del mes siguiente de efectuado el descuento de su remuneracion mensual, de la cuota de incorporacion y el aporte mensual. Los subsidios y prestamos contemplados en los articulos 4º y 5º del Reglamento, podran solicitarse tres meses despues que el afiliado se incorpore al Servicio de Bienestar o dentro de los plazos especiales establecidos en el presente Reglamento.
# empty
# empty
# 103
#      Artículo 20º.- El derecho a solicitar los beneficios que concede el Servicio de Bienestar caducará luego de transcurridos seis meses desde la fecha en que haya ocurrido el hecho constitutivo de la causal que se invoque para solicitarlos.
# end is yes El derecho a solicitar los beneficios que concede el Servicio de Bienestar caducara luego de transcurridos seis meses desde la fecha en que haya ocurrido el hecho constitutivo de la causal que se invoque para solicitarlos.
# empty
# 104
#      En el caso de los trabajadores que se acogen a jubilación, este plazo comenzará a regir desde la fecha en que se declare la calidad de tal, para los beneficios comprendidos entre esta fecha y la del cese de sus funciones.
# end is yes En el caso de los trabajadores que se acogen a jubilacion, este plazo comenzara a regir desde la fecha en que se declare la calidad de tal, para los beneficios comprendidos entre esta fecha y la del cese de sus funciones.
# empty
# empty
# 105
#      Artículo 21º.- Ningún miembro del Consejo Administrativo podrá votar en un asunto que le interese personalmente o pueda beneficiar a su cónyuge, a sus padres, hijos o hermanos.
# end is yes Ningun miembro del Consejo Administrativo podra votar en un asunto que le interese personalmente o pueda beneficiar a su conyuge, a sus padres, hijos o hermanos.
# empty
# empty
# 106
#      Artículo 22º.- Todos los informes y antecedentes de que conozca el Consejo Administrativo y que se refieran a situaciones personales y familiares de los afiliados, tendrán carácter de confidenciales.
# end is yes Todos los informes y antecedentes de que conozca el Consejo Administrativo y que se refieran a situaciones personales y familiares de los afiliados, tendran caracter de confidenciales.
# empty
# empty
# 107
#      Artículo 23º.- El afiliado que renuncie al Servicio de Bienestar deberá pagar, a la fecha de su renuncia, en su solo acto, el total de los valores adeudados a esa fecha.
# end is yes El afiliado que renuncie al Servicio de Bienestar debera pagar, a la fecha de su renuncia, en su solo acto, el total de los valores adeudados a esa fecha.
# empty
# empty
# 108
#      Artículo 24º.- El afiliado que no perciba remuneraciones de Enami por un período determinado, por permiso maternal, permiso sin goce de remuneraciones, medicina preventiva y otros, tendrá la obligación de pagar mensualmente, en forma directa al Servicio de Bienestar, el aporte y las cuotas correspondientes de sus deudas. Esto también aplicará para aquellos afiliados que se encuentren percibiendo remuneraciones de Enami de forma mensual, cuando los aportes y cuotas no se integren en su totalidad al Servicio de Bienestar.
# end is yes El afiliado que no perciba remuneraciones de Enami por un periodo determinado, por permiso maternal, permiso sin goce de remuneraciones, medicina preventiva y otros, tendra la obligacion de pagar mensualmente, en forma directa al Servicio de Bienestar, el aporte y las cuotas correspondientes de sus deudas. Esto tambien aplicara para aquellos afiliados que se encuentren percibiendo remuneraciones de Enami de forma mensual, cuando los aportes y cuotas no se integren en su totalidad al Servicio de Bienestar.
# empty
# 110
#      Los afiliados deberán estar al día en el cumplimiento de las obligaciones contraídas con el Servicio de Bienestar para tener derecho a los beneficios que éste les otorgue.
# end is yes Los afiliados deberan estar al dia en el cumplimiento de las obligaciones contraidas con el Servicio de Bienestar para tener derecho a los beneficios que este les otorgue.
# empty
# empty
# 111
#      Artículo 25º.- En el caso de los Fondos a Rendir Cuenta señalados en la letra c) del artículo 5º, se dispone que, si el afiliado no diera cumplimiento en el plazo establecido, deberá descontarse de inmediato el total del fondo girado. Además, se deberá calificar la causa de la no rendición oportuna de cuenta y, en caso de engaño debidamente comprobado, el afiliado podrá ser sancionado en la forma establecida en el Reglamento General, para cuyo efecto se pondrán los antecedentes en conocimiento del Consejo Administrativo.
# end is yes En el caso de los Fondos a Rendir Cuenta señalados en la letra c) del articulo 5º, se dispone que, si el afiliado no diera cumplimiento en el plazo establecido, debera descontarse de inmediato el total del fondo girado. Ademas, se debera calificar la causa de la no rendicion oportuna de cuenta y, en caso de engaño debidamente comprobado, el afiliado podra ser sancionado en la forma establecida en el Reglamento General, para cuyo efecto se pondran los antecedentes en conocimiento del Consejo Administrativo.
# empty
# 113
#      En los casos en que el Servicio de Bienestar haya otorgado un Fondo a Rendir Cuenta para pagar atenciones médicas, los socios afiliados a una Isapre tendrán la obligación de restituir al Servicio de Bienestar las bonificaciones que perciban de éstas. En el evento que no efectúe el ingreso, el afiliado podrá ser sancionado en la forma establecida en el Reglamento General, para cuyo efecto se pondrán los antecedentes en conocimiento del Consejo Administrativo.
# end is yes En los casos en que el Servicio de Bienestar haya otorgado un Fondo a Rendir Cuenta para pagar atenciones medicas, los socios afiliados a una Isapre tendran la obligacion de restituir al Servicio de Bienestar las bonificaciones que perciban de estas. En el evento que no efectue el ingreso, el afiliado podra ser sancionado en la forma establecida en el Reglamento General, para cuyo efecto se pondran los antecedentes en conocimiento del Consejo Administrativo.
# empty
# empty
# 115
#      Artículo 26º.- Los traslados médicos deberán justificarse mediante la presentación de certificado médico. Podrá contemplarse por indicación médica un solo acompañante si el estado de salud así lo amerita.
# end is yes Los traslados medicos deberan justificarse mediante la presentacion de certificado medico. Podra contemplarse por indicacion medica un solo acompañante si el estado de salud asi lo amerita.
# empty
# empty
# 117
#      Artículo 27º.- Las recetas médicas para compra de medicamentos extendidas para tratamientos permanentes o por períodos de tiempo prolongados, tendrán una duración de 6 meses para los efectos de invocar los beneficios del Servicio de Bienestar. Una vez vencido el plazo, el socio deberá solicitar una nueva receta médica por el tiempo que el profesional determine y el Servicio de Bienestar la bonificará por un nuevo período de 6 meses y así sucesivamente.
# end is yes Las recetas medicas para compra de medicamentos extendidas para tratamientos permanentes o por periodos de tiempo prolongados, tendran una duracion de 6 meses para los efectos de invocar los beneficios del Servicio de Bienestar. Una vez vencido el plazo, el socio debera solicitar una nueva receta medica por el tiempo que el profesional determine y el Servicio de Bienestar la bonificara por un nuevo periodo de 6 meses y asi sucesivamente.
# empty
# 119
#      Artículos transitorios
# end is not Articulos transitorios
# empty
# empty
# empty
# 120
#      Artículo 1º.- Los actuales afiliados al Servicio de Bienestar mantendrán su calidad de tales con todos los derechos contemplados en el presente Reglamento.
# end is yes Los actuales afiliados al Servicio de Bienestar mantendran su calidad de tales con todos los derechos contemplados en el presente Reglamento.
# empty
# empty
# 120
#      Artículo 2º.- El presente Reglamento comenzará a regir desde el día primero del mes siguiente a la fecha de publicación en el Diario Oficial del decreto supremo del Ministerio del Trabajo y Previsión Social que lo apruebe.
# end is yes El presente Reglamento comenzara a regir desde el dia primero del mes siguiente a la fecha de publicacion en el Diario Oficial del decreto supremo del Ministerio del Trabajo y Prevision Social que lo apruebe.
# empty
# 121
#      Los beneficios otorgados bajo la vigencia del Reglamento aprobado por el decreto supremo Nº 163, del Ministerio del Trabajo y Previsión Social, de 31 de octubre de 1995, continuarán rigiendo en las condiciones en que fueron otorgados hasta su total extinción.
# end is yes Los beneficios otorgados bajo la vigencia del Reglamento aprobado por el decreto supremo Nº 163, del Ministerio del Trabajo y Prevision Social, de 31 de octubre de 1995, continuaran rigiendo en las condiciones en que fueron otorgados hasta su total extincion.
# empty
# empty
# 122
#      Artículo 3º.- Los representantes titulares y suplentes de los afiliados en el Consejo Administrativo, conforme a lo dispuesto en el artículo 9, serán elegidos dentro del plazo de 60 días, contados desde la fecha en que el presente Reglamento entre en vigencia, y asumirán a contar del día 1º del mes siguiente a aquel en que se realice la votación.
# end is yes Los representantes titulares y suplentes de los afiliados en el Consejo Administrativo, conforme a lo dispuesto en el articulo 9, seran elegidos dentro del plazo de 60 dias, contados desde la fecha en que el presente Reglamento entre en vigencia, y asumiran a contar del dia 1º del mes siguiente a aquel en que se realice la votacion.
# empty
# 123
#      El Sindicato de Trabajadores deberá designar los representantes, titulares y suplentes, dentro del mismo plazo indicado en el inciso anterior, cuando proceda, de acuerdo al inciso 3º del artículo 18º del Reglamento General.
# end is yes El Sindicato de Trabajadores debera designar los representantes, titulares y suplentes, dentro del mismo plazo indicado en el inciso anterior, cuando proceda, de acuerdo al inciso 3º del articulo 18º del Reglamento General.
# empty
# 124
#      Anótese, comuníquese y publíquese.- Por orden del Presidente de la República, Juan Carlos Jobet Eluchans, Ministro del Trabajo y Previsión Social.- Hernán de Solminihac Tampier, Ministro de Minería.

# %%
json_file
# Out:
# {'418ca899c646b9c1b2d21392d7241dad4e381f2b': {'HEADING': {'tags': [],
#    'sentences': {'418ca89_1': {'text': 'Tipo Norma :Decreto 112 EXENTO',
#      'labels': []},
#     '418ca89_2': {'text': 'Fecha Publicacion :09-01-2014', 'labels': []},
#     '418ca89_3': {'text': 'Fecha Promulgacion :21-10-2013', 'labels': []},
#     '418ca89_4': {'text': 'Organismo :MINISTERIO DEL TRABAJO Y PREVISION SOCIAL; SUBSECRETARIA DE PREVISION SOCIAL',
#      'labels': []},
#     '418ca89_5': {'text': 'Titulo :DEROGA REGLAMENTO PARTICULAR DEL SERVICIO DE BIENESTAR DE LOS TRABAJADORES DE LA EMPRESA NACIONAL DE MINERIA, APROBADO POR DECRETO Nº 163, DE 1995, Y APRUEBA NUEVO REGLAMENTO PARTICULAR DEL MISMO SERVICIO',
#      'labels': []},
#     '418ca89_6': {'text': 'Tipo Version :Texto Original De : 09-ENE-2014',
#      'labels': []},
#     '418ca89_7': {'text': 'Inicio Vigencia :09-01-2014', 'labels': []},
#     '418ca89_8': {'text': 'Fin Vigencia :20-06-2014', 'labels': []},
#     '418ca89_9': {'text': 'Id Norma :1058088', 'labels': []},
#     '418ca89_10': {'text': 'URL :https://www.leychile.cl/N?i=1058088&f=2014-01-09',
#      'labels': []}}},
#   'DEROGA REGLAMENTO PARTICULAR DEL SERVICIO DE BIENESTAR DE LOS TRABAJADORES DE LA EMPRESA NACIONAL DE MINERIA, APROBADO POR DECRETO Nº 163, DE 1995, Y APRUEBA NUEVO REGLAMENTO PARTICULAR DEL MISMO SERVICIO': {'tags': [],
#    'sentences': {}},
#   'VISTO': {'tags': [],
#    'sentences': {'418ca89_11': {'text': 'Lo dispuesto en el articulo 134 de la ley Nº 11.764',
#      'labels': []},
#     '418ca89_12': {'text': 'en el articulo 24 de la ley Nº 16.395',
#      'labels': []},
#     '418ca89_13': {'text': 'en la ley Nº 17.538', 'labels': []},
#     '418ca89_14': {'text': 'en el decreto supremo Nº 28, de 1994, del Ministerio del Trabajo y Prevision Social, y decreto supremo Nº 4, de 2013, del Ministerio del Trabajo y Prevision Social',
#      'labels': []},
#     '418ca89_15': {'text': 'en la resolucion Nº 1.600, de 2008, de la Contraloria General de la Republica',
#      'labels': []},
#     '418ca89_16': {'text': 'en lo informado por la Superintendencia de Seguridad Social, y en la facultad que me confiere el articulo 32 Nº 6 de la Constitucion Politica de la Republica.',
#      'labels': []}}},
#   'RESUELVO': {'tags': [],
#    'sentences': {'418ca89_17': {'text': 'Derogase el Reglamento del Servicio de Bienestar de la Empresa Nacional de Mineria, aprobado por DS Nº 163, del 31 de octubre de 1995, modificado por DS Nº 2, del 4 de enero de 2005, y el decreto exento Nº 7 de 1 de febrero de 2010, todos del Ministerio del Trabajo y Prevision Social, Subsecretaria de Prevision Social',
#      'labels': []},
#     '418ca89_18': {'text': 'Apruebase el siguiente Reglamento para el Servicio de Bienestar de los Trabajadores de la Empresa Nacional de Mineria',
#      'labels': []},
#     '418ca89_19': {'text': ' Del Servicio de Bienestar El Servicio de Bienestar de la Empresa Nacional de Mineria, en adelante "el Servicio de Bienestar", tendra por objeto proveer asistencia medica, economica y social a los trabajadores afiliados y a sus cargas familiares legalmente acreditadas, en la medida que sus recursos financieros lo permitan y todo ello dentro de las normas que se establecen en el DS Nº 28, de 1994, del Ministerio del Trabajo y Prevision Social, en adelante "Reglamento General", y en el presente Reglamento.',
#      'labels': []},
#     '418ca89_20': {'text': ' De los beneficios, subsidios y prestamos Los afiliados al Servicio de Bienestar y sus cargas familiares legalmente acreditadas, de acuerdo a las disponibilidades presupuestarias, tendran derecho a gozar de los beneficios, subsidios y prestamos sociales en la forma que en cada caso se indica.',
#      'labels': []},
#     '418ca89_21': {'text': 'Parrafo Primero De los beneficios de salud El Servicio de Bienestar otorgara los siguientes beneficios a todos sus afiliados y cargas familiares legalmente acreditadas, por los siguientes conceptos:',
#      'labels': []},
#     '418ca89_22': {'text': 'Traslados y estadia por motivos medicos',
#      'labels': []},
#     '418ca89_23': {'text': 'El Consejo Administrativo determinara anualmente, en su primera sesion, los porcentajes de las bonificaciones que seran de cargo del Servicio de Bienestar, y el monto maximo a que podran ascender para cada prestacion',
#      'labels': []},
#     '418ca89_24': {'text': 'Estos beneficios seran informados a los socios a traves de circulares',
#      'labels': []},
#     '418ca89_25': {'text': 'Adicionalmente, el Servicio de Bienestar otorgara los siguientes beneficios medicos a todos sus afiliados activos y pasivos, y a sus respectivas cargas familiares legalmente acreditadas, siempre que no los hayan percibido, en virtud de un contrato de seguro complementario de salud contratado al efecto por la Empresa Nacional de Mineria:',
#      'labels': []},
#     '418ca89_26': {'text': 'Consulta medica, consulta medica domiciliaria, interconsulta y junta medica;',
#      'labels': []},
#     '418ca89_27': {'text': 'Intervencion quirurgica, atencion de anestesista y',
#      'labels': []},
#     '418ca89_28': {'text': 'Examenes de laboratorio, rayos X, histopatologicos y',
#      'labels': []},
#     '418ca89_29': {'text': 'especializados de caracter medico;', 'labels': []},
#     '418ca89_30': {'text': 'Tratamientos medicos especializados;',
#      'labels': []},
#     '418ca89_31': {'text': 'Consulta y tratamientos especializados para la recuperacion de la salud efectuados por el personal profesional o tecnico autorizado de colaboracion medica;',
#      'labels': []},
#     '418ca89_32': {'text': 'Adquisicion de anteojos, lentes de contacto, audifonos y',
#      'labels': []},
#     '418ca89_33': {'text': 'Toma de muestras de examenes a domicilio;',
#      'labels': []},
#     '418ca89_34': {'text': 'Atencion de urgencia, primeros auxilios y enfermeria;',
#      'labels': []},
#     '418ca89_35': {'text': 'Insumos necesarios para el otorgamiento de las prestaciones referidas en las letras b), c), f), g), h), , j) y l) precedentes.',
#      'labels': []},
#     '418ca89_36': {'text': 'Para los afiliados pasivos que ya no cuenten con un seguro complementario de salud contratado por la Empresa Nacional de Mineria, los porcentajes que se determinen para las bonificaciones indicadas en este articulo se entenderan referidos a los derechos arancelarios fijados para la modalidad de libre eleccion del DFL Nº 1, de 2005, del Ministerio de Salud',
#      'labels': []},
#     '418ca89_37': {'text': 'Respecto de las prestaciones que no estuvieren consideradas en dicho arancel, el porcentaje de la ayuda se aplicara sobre el valor real de la prestacion, no pudiendo exceder el monto del beneficio del tope maximo que hubiere fijado el Consejo Administrativo',
#      'labels': []},
#     '418ca89_38': {'text': 'El Servicio de Bienestar podra financiar, de acuerdo con sus disponibilidades presupuestarias, el valor de las primas de seguros con cargo a sus propios recursos, y contratar seguros de vida para sus afiliados y seguros de salud para ellos y sus cargas legalmente acreditadas, con el objeto de solventar los gastos de salud no cubiertos por los sistemas de salud previsional',
#      'labels': []},
#     '418ca89_39': {'text': 'Parrafo Segundo De los subsidios de orden economico El Servicio de Bienestar otorgara los siguientes subsidios no sujetos a restitucion, por las causales y de acuerdo con las modalidades que a continuacion se indican:',
#      'labels': []},
#     '418ca89_40': {'text': 'Matrimonio: Se otorgara un subsidio a cada afiliado que contraiga matrimonio. Si ambos contrayentes fueren afiliados, el subsidio se pagara a cada uno de ellos;',
#      'labels': []},
#     '418ca89_41': {'text': 'Nacimiento: Se otorgara al afiliado un subsidio cuando compruebe el nacimiento de cada hijo con el certificado correspondiente. En caso de nacimientos multiples, se otorgara este subsidio por cada hijo nacido vivo.',
#      'labels': []},
#     '418ca89_42': {'text': 'Si ambos padres son afiliados, el subsidio de nacimiento lo percibira cada uno de ellos;',
#      'labels': []},
#     '418ca89_43': {'text': 'Fallecimiento: Se otorgara un subsidio por fallecimiento del afiliado y de cada una de sus cargas familiares, incluido el mortinato a partir del quinto mes de gestacion y el fallecimiento del hijo recien nacido que no hubiere sido aun reconocido como carga familiar.',
#      'labels': []},
#     '418ca89_44': {'text': 'En caso de fallecimiento del afiliado, esta ayuda se pagara en el siguiente orden de precedencia:',
#      'labels': []},
#     '418ca89_45': {'text': 'A la persona que el afiliado haya designado expresamente para este efecto.',
#      'labels': []},
#     '418ca89_46': {'text': 'Al conyuge sobreviviente', 'labels': []},
#     '418ca89_47': {'text': 'A los herederos del causante', 'labels': []},
#     '418ca89_48': {'text': 'A la persona que haya efectuado los gastos, los que deberan ser debidamente acreditados.',
#      'labels': []},
#     '418ca89_49': {'text': 'Si ambos padres son afiliados, el subsidio de fallecimiento en caso de mortinato o de fallecimiento del recien nacido que no hubiere sido aun reconocido como carga familiar lo percibira cada uno de ellos',
#      'labels': []},
#     '418ca89_50': {'text': 'Becas de estudio: El afiliado tendra derecho, una vez al año, al pago de este beneficio, cuando curse estudios regulares de enseñanza basica, media, tecnica especializada o superior, en establecimientos del Estado o reconocidos por este, y',
#      'labels': []},
#     '418ca89_51': {'text': 'Ayuda medica: En caso de enfermedad grave y/o tratamiento medico prolongado de alto costo, calificados como tales por el Consejo Administrativo, del afiliado o de sus cargas familiares legalmente acreditadas, se podra otorgar al afiliado un subsidio economico complementario a los contemplados en el articulo 3º del presente Reglamento. Se exceptuan, para estos efectos, las enfermedades y',
#      'labels': []},
#     '418ca89_52': {'text': 'tratamientos oncologicos del afiliado en la parte cubierta por seguros contratados por la Empresa Nacional de Mineria.',
#      'labels': []},
#     '418ca89_53': {'text': 'Parrafo Tercero De los prestamos y Fondos a Rendir Cuenta El Servicio de Bienestar concedera los prestamos no reajustables que a continuacion se señalan:',
#      'labels': []},
#     '418ca89_54': {'text': 'Prestamo asistencial: Se otorgara como ayuda a los beneficios medicos establecidos en el articulo 3º.',
#      'labels': []},
#     '418ca89_55': {'text': 'Prestamo de emergencia: Se otorgara para atender necesidades y problemas socioeconomicos del afiliado.',
#      'labels': []},
#     '418ca89_56': {'text': 'Fondos a Rendir Cuenta: Los Fondos a Rendir Cuenta deberan entregarse solo por concepto de enfermedad y deberan rendirse antes de noventa (90) dias, contados desde la fecha de su otorgamiento.',
#      'labels': []},
#     '418ca89_57': {'text': 'El monto maximo de los prestamos antes señalados sera determinado anualmente por el Consejo Administrativo, y su reintegro debera efectuarse en un plazo no superior a 24 meses, respecto de la letra a), y a 12 meses en el caso de la letra b)',
#      'labels': []},
#     '418ca89_58': {'text': 'Los plazos indicados en el inciso anterior podran ser reducidos a solicitud del afiliado, en cuyo caso los intereses correspondientes se devengaran hasta la fecha de los pagos respectivos',
#      'labels': []},
#     '418ca89_59': {'text': 'Para conceder un prestamo el Consejo Administrativo debera considerar, especialmente, las posibilidades de recuperacion de los dineros prestados',
#      'labels': []},
#     '418ca89_60': {'text': 'Ademas, sera requisito indispensable la constitucion de la garantia de dos codeudores solidarios, que sean trabajadores con contrato de trabajo de duracion indefinida y su solvencia sera calificada por dicho Consejo Administrativo',
#      'labels': []},
#     '418ca89_61': {'text': 'Para solicitar cualquier tipo de prestamo el afiliado debera tener, por lo menos, tres meses de afiliacion ininterrumpida al Servicio de Bienestar',
#      'labels': []},
#     '418ca89_62': {'text': 'El reintegro de los prestamos señalados en las letras a) y b) del articulo 5º, debera hacerse en cuotas mensuales, iguales y sucesivas',
#      'labels': []},
#     '418ca89_63': {'text': 'Las referidas cuotas seran descontadas a partir del mes siguiente al de su otorgamiento',
#      'labels': []},
#     '418ca89_64': {'text': 'La tasa de interes que devengaran estos prestamos sera fijada anualmente por el Consejo Administrativo, antes del inicio de cada ejercicio financiero, y consistira en un porcentaje del interes corriente para operaciones no reajustables fijado por la Superintendencia de Bancos e Instituciones Financieras, vigente al dia primero del mes en que se otorga el prestamo',
#      'labels': []},
#     '418ca89_65': {'text': 'Para que el afiliado solicite un nuevo prestamo de aquellos señalados en las letras a), b) y c) del articulo 5º, sera necesario haber pagado la totalidad de la deuda que mantenga por el mismo concepto',
#      'labels': []},
#     '418ca89_66': {'text': 'El afiliado, de manera previa a la obtencion de cualquiera de los prestamos señalados en el articulo 5º, debera autorizar expresamente y por escrito al Servicio de Bienestar para realizar estos descuentos en sus remuneraciones para asi pagar dichos prestamos',
#      'labels': []},
#     '418ca89_67': {'text': 'Estos descuentos en su conjunto no podran ser superiores al quince por ciento (15%) de la remuneracion total del afiliado',
#      'labels': []},
#     '418ca89_68': {'text': ' Del Consejo Administrativo El Servicio de Bienestar sera administrado por un Consejo Administrativo compuesto de ocho miembros e integrado de la siguiente forma:',
#      'labels': []},
#     '418ca89_69': {'text': 'Por el Vicepresidente Ejecutivo, en su calidad de Jefe Superior de la Empresa, o por la persona que este designe en su reemplazo, quien lo presidira.',
#      'labels': []},
#     '418ca89_70': {'text': 'Por dos representantes de la Empresa Nacional de Mineria elegidos por el Vicepresidente Ejecutivo de la Empresa, uno de los cuales actuara como Vicepresidente del Consejo Administrativo y reemplazara al Presidente en ausencia o impedimento de este. En caso de ausencia o impedimento del Vicepresidente del Consejo Administrativo sera reemplazado por su suplente en el cargo.',
#      'labels': []},
#     '418ca89_71': {'text': 'Por el Fiscal de la empresa o el abogado de la institucion que este designe al efecto. En este ultimo caso se debera designar un abogado titular y otro suplente, y',
#      'labels': []},
#     '418ca89_72': {'text': 'Por cuatro representantes de los trabajadores afiliados, uno de los cuales sera designado por el Sindicato de Trabajadores, cuando proceda, de acuerdo con lo dispuesto en el inciso tercero del articulo 18 del Reglamento General.',
#      'labels': []},
#     '418ca89_73': {'text': 'El Contador del Servicio de Bienestar actuara como Secretario del Consejo Administrativo, teniendo derecho a voz pero no a voto',
#      'labels': []},
#     '418ca89_74': {'text': 'Los representantes de los trabajadores afiliados en el Consejo Administrativo, a que se refiere esta letra, deberan cumplir los requisitos establecidos en el articulo 12º de este Reglamento',
#      'labels': []},
#     '418ca89_75': {'text': 'Los representantes titulares y suplentes de los trabajadores afiliados al Consejo Administrativo, seran elegidos por estos en votacion directa y secreta en un solo acto',
#      'labels': []},
#     '418ca89_76': {'text': 'Resultaran elegidos los que obtengan las mas altas mayorias, duraran dos años en sus funciones y podran ser reelegidos hasta por dos periodos consecutivos',
#      'labels': []},
#     '418ca89_77': {'text': 'En caso de impedimento o ausencia temporal, seran reemplazados por los suplentes',
#      'labels': []},
#     '418ca89_78': {'text': 'Se entenderan elegidos suplentes los afiliados que tengan las siguientes mayorias',
#      'labels': []},
#     '418ca89_79': {'text': 'La eleccion de los representantes de los trabajadores afiliados en el Consejo Administrativo se llevara a efecto 15 dias antes de la expiracion de sus funciones',
#      'labels': []},
#     '418ca89_80': {'text': 'El escrutinio final se practicara por los integrantes a que se refieren las letras a), b) y c) del articulo 9º y por un representante de los afiliados de la letra d) del mismo articulo, elegidos por ellos mismos y sera publico',
#      'labels': []},
#     '418ca89_81': {'text': 'Para ser elegido representante de los afiliados al Consejo Administrativo, se requiere:',
#      'labels': []},
#     '418ca89_82': {'text': 'Ser afiliado del Servicio de Bienestar con una antigüedad no inferior a seis meses;',
#      'labels': []},
#     '418ca89_83': {'text': 'No ser integrante del Consejo Administrativo en representacion de la entidad empleadora;',
#      'labels': []},
#     '418ca89_84': {'text': 'No haber sido objeto de medida disciplinaria alguna durante el año anterior de la eleccion, y',
#      'labels': []},
#     '418ca89_85': {'text': 'Estar al dia en el cumplimiento de sus obligaciones con el Servicio de Bienestar.',
#      'labels': []},
#     '418ca89_86': {'text': 'El Consejo Administrativo celebrara sesiones ordinarias y extraordinarias',
#      'labels': []},
#     '418ca89_87': {'text': 'En las sesiones extraordinarias solo podran tratarse las materias determinadas en la convocatoria o en el acuerdo que las origine',
#      'labels': []},
#     '418ca89_88': {'text': 'Las citaciones a ambos tipos de sesiones se haran por escrito por el Presidente del Consejo del Servicio de Bienestar, con 72 horas de anticipacion a lo menos',
#      'labels': []},
#     '418ca89_89': {'text': 'El Consejo Administrativo sesionara a lo menos cada dos meses, con la mayoria absoluta de sus miembros, y sus decisiones se tomaran por simple mayoria, salvo las excepciones que se consignen en el presente Reglamento',
#      'labels': []},
#     '418ca89_90': {'text': 'En caso de empate decidira el voto del Presidente',
#      'labels': []},
#     '418ca89_91': {'text': ' Del financiamiento, presupuesto y control de cuentas El Servicio de Bienestar se financiara con los siguientes recursos:',
#      'labels': []},
#     '418ca89_92': {'text': 'Con una cuota de incorporacion que pagaran al ingresar los trabajadores afiliados, equivalente al 1% de sus remuneraciones mensuales imponibles para pensiones o de sus pensiones segun corresponda;',
#      'labels': []},
#     '418ca89_93': {'text': 'Con un aporte de la Empresa equivalente a la cuota de incorporacion de los trabajadores afiliados;',
#      'labels': []},
#     '418ca89_94': {'text': 'Con un aporte mensual sobre la totalidad de las remuneraciones imponibles para pensiones de los trabajadores afiliados al Servicio de Bienestar, que sera de cargo de la Empresa, el cual no podra ser inferior al 1%;',
#      'labels': []},
#     '418ca89_95': {'text': 'Con un aporte mensual sobre la totalidad de las remuneraciones imponibles para pensiones de los trabajadores afiliados al Servicio de Bienestar, que sera de cargo de estos, el que no podra exceder del 3%;',
#      'labels': []},
#     '418ca89_96': {'text': 'Con un aporte mensual sobre la totalidad de su pension de jubilacion, de cargo de los jubilados, cuyo porcentaje debera ser igual al de la Empresa y al fijado para los afiliados activos indicados en la letra d) precedente;',
#      'labels': []},
#     '418ca89_97': {'text': 'Con los intereses que devenguen los prestamos en dinero;',
#      'labels': []},
#     '418ca89_98': {'text': 'Con las donaciones, herencias, legados, aportes extraordinarios, erogaciones voluntarias y asignaciones que la empresa, los afiliados o cualquier tercero otorgue al Servicio de Bienestar, y',
#      'labels': []},
#     '418ca89_99': {'text': 'Con los demas bienes o recursos que adquiera o reciba a cualquier titulo.',
#      'labels': []},
#     '418ca89_100': {'text': 'Los fondos del Servicio de Bienestar deberan ser depositados en una cuenta corriente bancaria por reparticion, en contra de las cuales deberan girar conjuntamente un apoderado clase "A" y "B", designados de acuerdo a la normativa interna de la Empresa',
#      'labels': []},
#     '418ca89_101': {'text': ' Disposiciones Generales No podra establecerse en las normas o procedimientos internos, diferencia alguna entre los afiliados con respecto a los beneficios que otorga el presente Reglamento.',
#      'labels': []},
#     '418ca89_102': {'text': 'Los afiliados tendran derecho a percibir la totalidad de los beneficios medicos que otorgue el Servicio de Bienestar a contar del primer dia habil del mes siguiente de efectuado el descuento de su remuneracion mensual, de la cuota de incorporacion y el aporte mensual',
#      'labels': []},
#     '418ca89_103': {'text': 'Los subsidios y prestamos contemplados en los articulos 4º y 5º del Reglamento, podran solicitarse tres meses despues que el afiliado se incorpore al Servicio de Bienestar o dentro de los plazos especiales establecidos en el presente Reglamento',
#      'labels': []},
#     '418ca89_104': {'text': 'El derecho a solicitar los beneficios que concede el Servicio de Bienestar caducara luego de transcurridos seis meses desde la fecha en que haya ocurrido el hecho constitutivo de la causal que se invoque para solicitarlos',
#      'labels': []},
#     '418ca89_105': {'text': 'En el caso de los trabajadores que se acogen a jubilacion, este plazo comenzara a regir desde la fecha en que se declare la calidad de tal, para los beneficios comprendidos entre esta fecha y la del cese de sus funciones',
#      'labels': []},
#     '418ca89_106': {'text': 'Ningun miembro del Consejo Administrativo podra votar en un asunto que le interese personalmente o pueda beneficiar a su conyuge, a sus padres, hijos o hermanos',
#      'labels': []},
#     '418ca89_107': {'text': 'Todos los informes y antecedentes de que conozca el Consejo Administrativo y que se refieran a situaciones personales y familiares de los afiliados, tendran caracter de confidenciales',
#      'labels': []},
#     '418ca89_108': {'text': 'El afiliado que renuncie al Servicio de Bienestar debera pagar, a la fecha de su renuncia, en su solo acto, el total de los valores adeudados a esa fecha',
#      'labels': []},
#     '418ca89_109': {'text': 'El afiliado que no perciba remuneraciones de Enami por un periodo determinado, por permiso maternal, permiso sin goce de remuneraciones, medicina preventiva y otros, tendra la obligacion de pagar mensualmente, en forma directa al Servicio de Bienestar, el aporte y las cuotas correspondientes de sus deudas',
#      'labels': []},
#     '418ca89_110': {'text': 'Esto tambien aplicara para aquellos afiliados que se encuentren percibiendo remuneraciones de Enami de forma mensual, cuando los aportes y cuotas no se integren en su totalidad al Servicio de Bienestar',
#      'labels': []},
#     '418ca89_111': {'text': 'Los afiliados deberan estar al dia en el cumplimiento de las obligaciones contraidas con el Servicio de Bienestar para tener derecho a los beneficios que este les otorgue',
#      'labels': []},
#     '418ca89_112': {'text': 'En el caso de los Fondos a Rendir Cuenta señalados en la letra c) del articulo 5º, se dispone que, si el afiliado no diera cumplimiento en el plazo establecido, debera descontarse de inmediato el total del fondo girado',
#      'labels': []},
#     '418ca89_113': {'text': 'Ademas, se debera calificar la causa de la no rendicion oportuna de cuenta y, en caso de engaño debidamente comprobado, el afiliado podra ser sancionado en la forma establecida en el Reglamento General, para cuyo efecto se pondran los antecedentes en conocimiento del Consejo Administrativo',
#      'labels': []},
#     '418ca89_114': {'text': 'En los casos en que el Servicio de Bienestar haya otorgado un Fondo a Rendir Cuenta para pagar atenciones medicas, los socios afiliados a una Isapre tendran la obligacion de restituir al Servicio de Bienestar las bonificaciones que perciban de estas',
#      'labels': []},
#     '418ca89_115': {'text': 'En el evento que no efectue el ingreso, el afiliado podra ser sancionado en la forma establecida en el Reglamento General, para cuyo efecto se pondran los antecedentes en conocimiento del Consejo Administrativo',
#      'labels': []},
#     '418ca89_116': {'text': 'Los traslados medicos deberan justificarse mediante la presentacion de certificado medico',
#      'labels': []},
#     '418ca89_117': {'text': 'Podra contemplarse por indicacion medica un solo acompañante si el estado de salud asi lo amerita',
#      'labels': []},
#     '418ca89_118': {'text': 'Las recetas medicas para compra de medicamentos extendidas para tratamientos permanentes o por periodos de tiempo prolongados, tendran una duracion de 6 meses para los efectos de invocar los beneficios del Servicio de Bienestar',
#      'labels': []},
#     '418ca89_119': {'text': 'Una vez vencido el plazo, el socio debera solicitar una nueva receta medica por el tiempo que el profesional determine y el Servicio de Bienestar la bonificara por un nuevo periodo de 6 meses y asi sucesivamente',
#      'labels': []},
#     '418ca89_120': {'text': 'Articulos transitorios Los actuales afiliados al Servicio de Bienestar mantendran su calidad de tales con todos los derechos contemplados en el presente Reglamento.',
#      'labels': []},
#     '418ca89_121': {'text': 'El presente Reglamento comenzara a regir desde el dia primero del mes siguiente a la fecha de publicacion en el Diario Oficial del decreto supremo del Ministerio del Trabajo y Prevision Social que lo apruebe',
#      'labels': []},
#     '418ca89_122': {'text': 'Los beneficios otorgados bajo la vigencia del Reglamento aprobado por el decreto supremo Nº 163, del Ministerio del Trabajo y Prevision Social, de 31 de octubre de 1995, continuaran rigiendo en las condiciones en que fueron otorgados hasta su total extincion',
#      'labels': []},
#     '418ca89_123': {'text': 'Los representantes titulares y suplentes de los afiliados en el Consejo Administrativo, conforme a lo dispuesto en el articulo 9, seran elegidos dentro del plazo de 60 dias, contados desde la fecha en que el presente Reglamento entre en vigencia, y asumiran a contar del dia 1º del mes siguiente a aquel en que se realice la votacion',
#      'labels': []},
#     '418ca89_124': {'text': 'El Sindicato de Trabajadores debera designar los representantes, titulares y suplentes, dentro del mismo plazo indicado en el inciso anterior, cuando proceda, de acuerdo al inciso 3º del articulo 18º del Reglamento General',
#      'labels': []}}}}}

# %%
out_folder = Path("C:/Users/user/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Notebooks/Data/Processed/")
filename = "Chile.json"
file = out_folder / filename
with open(file, 'w') as fp:
    json.dump(json_file, fp, indent=4)

# %%
print(len(json_file))
# for k in sorted(sentences_dict):
#     print(k, ":", sentences_dict[k])

# %% [markdown]
# #### Short summary

# %%
print("After preprocessing there are {} different headings in El Salvador policies".format(len(bag_of_words)))
print("{} documents have been processed".format(i))
print("There are {} lines of text as sentences".format(len(sentences)))

# %% [markdown]
# #### Dictionary items sorted by occurrence

# %%
dict( sorted(bag_of_words.items(), key=operator.itemgetter(1),reverse=True))

# %% [markdown]
# #### Dictionary items sorted by heading text

# %%
for k in sorted(bag_of_words):
    print(k, ":", bag_of_words[k])

# %% [markdown]
# #### Saving sentences as csv

# %%
print(sentences[0:2])

# %%
# path = Path("C:/Users/user/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Notebooks/Data/")
path = Path("C:/Users/jordi/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Notebooks/Data/")
filename = "sentences.npy"
file = path / filename
np_sentences = np.array(sentences)
with open(file, 'wb') as f:
    np.save(f, np_sentences)

# %% [markdown]
# ### Pipeline to process one file from HD folder
# This is a pipeline to process a test file in a local folder.

# %%
path = "C:/Users/jordi/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Documents_de_mostra/Chile/"
# path = "C:/Users/user/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Documents_de_mostra/Chile/"
files = os.listdir(path)
print(files[0])

# %%
# path = "C:/Users/user/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Documents_de_mostra/Chile/"
path = "C:/Users/jordi/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Documents_de_mostra/Chile/"
data_folder = Path(path)
filename = "00d91bcac2667290e3fb42452f5241be28b031c2"


files = os.listdir(path)
files = ["002c53058e85d383b057fa4cc25a6eb8e7d401e3"]

bag_of_words = {}
json_file = {}

i = 0
for filename in files:
#     if i == 0:
    file_ = data_folder / filename
    with open(file_, 'r', encoding = 'utf-8') as file:
        lines = file.readlines()
#         print("\n", filename, "\n")
        json_file[filename] = {}
        line_counter = 0
        heading_flag = True
        heading_content = False
        has_section = False
        json_file[filename]["HEADING"] = {"tags" : [], "sentences" : {}}
        for line in lines:
            line = clean_whitespace(line)
            # Processing document heading
            if heading_flag:
                if "Tipo Norma" in line:
                    heading_content = True
                if heading_content:
                    line = full_cleaning(line)
                    if line != None:
                        if ":" in line:
                            line_counter += 1
                            sentence_id = filename[0:7] + '_' + str(line_counter)
                            json_file[filename]["HEADING"]["sentences"][sentence_id] = {"text" : line, "labels" : []}
                            json_file[filename]["HEADING"]["sentences"][sentence_id]["text"] = line
                        else:
                            json_file[filename]["HEADING"]["sentences"][sentence_id]["text"] = json_file[filename]["HEADING"]["sentences"][sentence_id]["text"] + " " + line
#                 print("**", line)
                heading_flag, heading_content = end_of_heading(line, heading_flag, heading_content)

            # Breaking when document signatures are found    
            elif end_of_document(line):
#                 print(line)
                break
            # Getting section headings
            elif (uppercase_ratio(line) == 1 and len(line) > 10 and line_counter > 0) or is_section(line):
#                 print("line--", line)
                line = remove_accents(line)
                line = clean_bugs(line)
                line = clean_sentence(line)
                if line == None:
                    continue
                else:
                    has_section = True
                    section = merge_concepts(line)
#                     print("**", section)
                    json_file[filename][section] = {"tags" : [], "sentences" : {}}
#                     bag_of_words = add_to_dict(section, bag_of_words, duplicates_dict)
                    if section == "VISTO" and len(split_into_sentences(line, ":")) > 1:
                        visto = split_into_sentences(line, ":")
                        for sentence in split_into_sentences(visto[1], ";"):
                            line_counter += 1
                            sentence_id = filename[0:7] + '_' + str(line_counter)
                            json_file[filename][section]["sentences"][sentence_id] = {"text" : sentence, "labels" : []}

            elif has_section:
                line = full_cleaning(line)
                if line == None:
                    continue                    
                else:
                    line = change_decimal_points(line)
                    for sentence in split_into_sentences(line, "."):
                        line_counter += 1
                        sentence_id = filename[0:7] + '_' + str(line_counter)
                        json_file[filename][section]["sentences"][sentence_id] = {"text" : sentence, "labels" : []}
        i += 1
    #     data = file.read().replace('\n', '')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-92f8fc79458e> in <module>
#       5
#       6
# ----> 7 files = os.listdir(path)
#       8 files = ["002c53058e85d383b057fa4cc25a6eb8e7d401e3"]
#       9
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/jordi/Google Drive/Els_meus_documents/projectes/CompetitiveIntelligence/WRI/Documents_de_mostra/Chile/'

# %%
json_file
# Out:
# {'002c53058e85d383b057fa4cc25a6eb8e7d401e3': {'HEADING': {'tags': [],
#    'sentences': {'002c530_1': {'text': 'Tipo Norma :Decreto 3157 EXENTO',
#      'labels': []},
#     '002c530_2': {'text': 'Fecha Publicacion :16-09-2016', 'labels': []},
#     '002c530_3': {'text': 'Fecha Promulgacion :18-08-2016', 'labels': []},
#     '002c530_4': {'text': 'Organismo :MUNICIPALIDAD DE PANQUEHUE',
#      'labels': []},
#     '002c530_5': {'text': 'Titulo :APRUEBA "ORDENANZA PARA LA EXTRACCION DE ARIDOS EN CAUCES Y ALVEOS DE CURSOS NATURALES DE AGUA QUE CONSTITUYEN BIENES NACIONALES DE USO PUBLICO Y EN POZOS LASTREROS DE PROPIEDAD PARTICULAR EN LA COMUNA DE PANQUEHUE" Y SUS RESPECTIVOS ANEXOS',
#      'labels': []},
#     '002c530_6': {'text': 'Tipo Version :Unica De : 16-SEP-2016',
#      'labels': []},
#     '002c530_7': {'text': 'Inicio Vigencia :16-09-2016', 'labels': []},
#     '002c530_8': {'text': 'Id Norma :1094879', 'labels': []},
#     '002c530_9': {'text': 'URL :https://www.leychile.cl/N?i=1094879&f=2016-09-16',
#      'labels': []}}},
#   'APRUEBA "ORDENANZA PARA LA EXTRACCION DE ARIDOS EN CAUCES Y ALVEOS DE CURSOS NATURALES DE AGUA QUE CONSTITUYEN BIENES NACIONALES DE USO PUBLICO Y EN POZOS LASTREROS DE PROPIEDAD PARTICULAR EN LA COMUNA DE PANQUEHUE" Y SUS RESPECTIVOS ANEXOS': {'tags': [],
#    'sentences': {'002c530_10': {'text': '3,157 exento- Panquehue, 18 de agosto de 2016',
#      'labels': []}}},
#   'VISTO': {'tags': [], 'sentences': {}},
#   'CONSIDERANDO': {'tags': [],
#    'sentences': {'002c530_17': {'text': 'Decreto N° 3,157, de fecha 18 de agosto de 2016, que aprueba la Ordenanza para la Extraccion de Aridos en Cauces y Alveos de cursos naturales de agua que constituyen Bienes Nacionales de Uso Publico y en Pozos Lastreros de propiedad particular, de la comuna de Panquehue, como a continuacion se indica',
#      'labels': []}}},
#   'RESUELVO': {'tags': [],
#    'sentences': {'002c530_15': {'text': 'Apruebese la "Ordenanza para la extraccion de Aridos en Cauces y Alveos de Cursos Naturales de Agua que constituyen Bienes Nacionales de Uso Publico y en Pozos Lastreros de Propiedad Particular en la comuna de Panquehue" y sus respectivos anexos',
#      'labels': []}}},
#   'ORDENANZA PARA LA EXTRACCION DE ARIDOS EN CAUCES Y ALVEOS DE CURSOS NATURALES DE AGUA QUE CONSTITUYEN BIENES NACIONALES DE USO PUBLICO Y EN POZOS LASTREROS DE PROPIEDAD PARTICULAR, DE LA COMUNA DE PANQUEHUE': {'tags': [],
#    'sentences': {'002c530_16': {'text': 'Panquehue, 18 de agosto de 2016',
#      'labels': []}}},
#   'OBJETO': {'tags': [],
#    'sentences': {'002c530_18': {'text': 'La presente Ordenanza tiene como objetivo fijar los procedimientos generales para la extraccion de aridos ya sea de Bienes Nacionales de Uso Publico y/o Pozos Lastreros en propiedad particular, reseñados en esta Ordenanza para la comuna de Panquehue',
#      'labels': []},
#     '002c530_19': {'text': 'De conformidad al articulo 36° de la Ley 18,695 de la Ley Organica Constitucional de Municipalidades, los Bienes Municipales o Nacionales de Uso Publico, incluido su subsuelo, que administre la Municipalidad, podran ser objeto de permisos',
#      'labels': []},
#     '002c530_20': {'text': 'Por consiguiente, para extraer aridos de los cauces de los rios, esteros y/o pozos lastreros, se requiere previamente el otorgamiento de un permiso municipal, el cual sera visado tecnicamente por la Direccion de Obras Hidraulicas del Ministerio de Obras Publicas o la institucion que lo supla en sus funciones',
#      'labels': []},
#     '002c530_21': {'text': 'Quedaran comprendidos en esta Ordenanza los siguientes Bienes Nacionales de Uso Publico, de administracion municipal, que en toda su extension corresponden a los cauces, dentro del territorio de la comuna de Panquehue:',
#      'labels': []},
#     '002c530_22': {'text': 'Otros esteros y cursos de aguas de la comuna',
#      'labels': []},
#     '002c530_23': {'text': 'Para definir el area y extension del cauce, se estara a lo dispuesto en el articulo 30° del Codigo de Aguas',
#      'labels': []}}},
#   'DERECHOS, OBLIGACIONES Y PROHIBICIONES': {'tags': [],
#    'sentences': {'002c530_109': {'text': 'Son obligaciones del beneficiario del permiso, las siguientes:',
#      'labels': []},
#     '002c530_110': {'text': 'Materializar en terreno los vertices del proyecto mediante monolitos de hormigon, ademas dejar estacas en cada uno de los perfiles transversales del proyecto',
#      'labels': []},
#     '002c530_111': {'text': 'Las excavaciones deben situarse dentro del cauce',
#      'labels': []},
#     '002c530_112': {'text': 'Por ningun motivo deben situarse en las riberas, pues contribuyen a debilitar su compactacion y estabilidad',
#      'labels': []},
#     '002c530_113': {'text': 'Las excavaciones deben ser orientadas en direccion paralela al eje del cauce',
#      'labels': []},
#     '002c530_114': {'text': 'Por ningun motivo deben orientarse en direccion transversal al eje del cauce (ribera a ribera) seccionandolo',
#      'labels': []},
#     '002c530_115': {'text': 'Las excavaciones no deben vulnerar, ni amagar obras de encauzamiento y defensas existentes (enrocado - gaviones), canales, bocatomas de regadio y otras',
#      'labels': []},
#     '002c530_116': {'text': 'El material excedente debera situarse en la ribera, conformando un pretil',
#      'labels': []},
#     '002c530_117': {'text': 'La explotacion de aridos no debe perjudicar a terceros, ni dificultar el libre escurrimiento de las aguas, por ningun motivo se debe procesar el material dentro del cauce, como tampoco hacer acopio dentro de el',
#      'labels': []},
#     '002c530_118': {'text': 'La extraccion debe obedecer a un perfil de escurrimiento de tipo "trapezoidal"',
#      'labels': []},
#     '002c530_119': {'text': 'Por ningun motivo se podra excavar bajo la cota de fondo que se señala en el perfil longitudinal del proyecto El ancho basal del perfil de explotacion no debe exceder la dimension indicada en el proyecto',
#      'labels': []},
#     '002c530_120': {'text': 'Todo daño de cualquier naturaleza que con motivo de la ejecucion de los trabajos autorizados, le cause a terceros o a cualquier obra de infraestructura, por negligencia, incumplimiento, o errores en la manipulacion del cauce, sera de exclusiva responsabilidad del beneficiario del permiso',
#      'labels': []},
#     '002c530_121': {'text': 'La zona especificada de extraccion, longitud y ancho estara medido por el eje del cauce',
#      'labels': []},
#     '002c530_122': {'text': 'Al termino de las faenas de extraccion de aridos, se exigira efectuar faenas de encauzamiento del rio, a fin de eliminar todo obstaculo que obstruya el libre escurrimiento de las aguas',
#      'labels': []},
#     '002c530_123': {'text': 'Le queda estrictamente prohibido realizar extracciones de aridos a menos de 300 metros de un puente, ya sea aguas arriba como aguas abajo',
#      'labels': []},
#     '002c530_124': {'text': 'Queda estrictamente prohibido a beneficiarios de permisos, obstruir el libre transito de personas, vehiculos y animales por el Bien Nacional de Uso Publico respectivo, las cercas e instalaciones que se permitiran lo seran unicamente cuanto su existencia se justifique y no perturbe el uso y goce del Bien Nacional de Uso Publico, autorizacion que se solicitara al Director de Obras Municipales',
#      'labels': []}}},
#   'PERMISOS': {'tags': [],
#    'sentences': {'002c530_64': {'text': 'Se otorgara permiso para extraer aridos en forma artesanal a determinadas personas naturales, solo frente a situaciones sociales y tecnicamente calificadas, y que tengan capacidad de extraer no mas de quince metros cubicos (15m3) de aridos al mes',
#      'labels': []},
#     '002c530_65': {'text': 'Estas personas tambien seran inscritas en el registro respectivo, para su posterior control; la referencia de esta extraccion sera hecha por el Municipio',
#      'labels': []},
#     '002c530_66': {'text': 'Sera a traves de un informe de la Dideco que determinara la situacion social del interesado',
#      'labels': []}}},
#   'SANCIONES': {'tags': [],
#    'sentences': {'002c530_80': {'text': 'El permiso, materia de la presente Ordenanza se extinguira, en conformidad con la Ley 18,695, Organica Constitucional de Municipalidades, por las siguientes causales:',
#      'labels': []},
#     '002c530_81': {'text': 'Cumplimiento del plazo por el que se otorgo;',
#      'labels': []},
#     '002c530_82': {'text': 'Incumplimiento grave de las obligaciones impuestas al beneficiario de un permiso, o;',
#      'labels': []},
#     '002c530_83': {'text': 'Mutuo acuerdo entre la Municipalidad y beneficiario de permiso, cuando ocurran razones de interes publico, calificados por la Municipalidad',
#      'labels': []},
#     '002c530_84': {'text': 'Todas aquellas faltas graves a la presente Ordenanza, relacionadas principalmente con detrimento del patrimonio municipal y/o publico, en terminos de percepcion de ingresos o de materias tecnicas que signifiquen intervencion no autorizada del cauce y de su entorno, tales como:',
#      'labels': []},
#     '002c530_85': {'text': 'El no pago oportuno de los derechos municipales en los casos que corresponda',
#      'labels': []},
#     '002c530_86': {'text': 'Transportar aridos sin guia de despacho o factura correspondiente',
#      'labels': []},
#     '002c530_87': {'text': 'Utilizar una misma guia de despacho o factura para diferentes volumenes de aridos transportados',
#      'labels': []},
#     '002c530_88': {'text': 'Realizar excavaciones o acopios de material en lugares expresamente prohibidos',
#      'labels': []},
#     '002c530_89': {'text': 'Por incumplimiento de los planes tecnicos señalados en el Informe Tecnico aprobatorio de la Direccion de Obras Hidraulicas presentados para la obtencion del permiso',
#      'labels': []},
#     '002c530_90': {'text': 'Extraccion de una cantidad mayor de material que el autorizado',
#      'labels': []},
#     '002c530_91': {'text': 'Por maltratar de cualquier forma al personal municipal que fiscalice',
#      'labels': []},
#     '002c530_92': {'text': 'Por extraer material sin autorizacion alguna para aquello',
#      'labels': []},
#     '002c530_93': {'text': 'y cualquier otra transgresion de la ley 11,402, articulo 11° y consideraciones tecnicas de la Direccion de Obras Hidraulicas',
#      'labels': []},
#     '002c530_94': {'text': 'Seran sancionadas con la suspension temporal de los permisos de extraccion por treinta dias y en caso de reiteracion de estas faltas se podra poner termino al permiso de extraccion',
#      'labels': []},
#     '002c530_95': {'text': 'La falta indicada en la letra sera sancionada con la caducidad del permiso de extraccion',
#      'labels': []},
#     '002c530_96': {'text': 'La falta indicada en la letra sera denunciada al Juzgado de Policia Local aplicandosele la multa maxima; la reiteracion del beneficiario, dara lugar a la peticion de fuerza publica al Gobernador Provincial para dar cumplimiento forzado de la clausura',
#      'labels': []},
#     '002c530_97': {'text': 'Las infracciones señaladas en este articulo seran sancionadas con multa unica de cincuenta Unidades Tributarias Mensuales por cada falta que cometa el beneficiario de un permiso',
#      'labels': []},
#     '002c530_98': {'text': 'No obstante lo anterior, ante faltas que se mencionan a continuacion, dara lugar a multa que no podra exceder de la cinco Unidades Tributarias Mensuales, en conformidad con la Ley 18,695 Organica Constitucional de Municipalidades, faltas que incluso podran originar la suspension de la calidad del beneficiario de un permiso, en caso de reiteracion comprobada',
#      'labels': []},
#     '002c530_99': {'text': 'Dichas faltas son las siguientes:', 'labels': []},
#     '002c530_100': {'text': 'Por no otorgamiento de las guias de control de aridos entregadas por la Municipalidad',
#      'labels': []},
#     '002c530_101': {'text': 'Por estar ejerciendo el permiso una persona distinta al titular del mismo',
#      'labels': []},
#     '002c530_102': {'text': 'Por no aportar informacion veraz respecto de la cantidad de arido extraido',
#      'labels': []},
#     '002c530_103': {'text': 'Personal de la Direccion de Obras Municipales e Inspectoria Municipal, revisara permanentemente la faena en terreno, verificara si el beneficiario del permiso otorgado ha dado cumplimiento con los compromisos de encauzamiento y mantencion del rio, y de las obligaciones que le son exigidas en el proyecto autorizado, en caso contrario, se negara cualquier nuevo permiso, sin perjuicio de las demas sanciones establecidas en este reglamento o leyes especiales que regulen la materia, de todo lo cual se informara a la Direccion de Obras Hidraulicas para los fines pertinentes',
#      'labels': []},
#     '002c530_104': {'text': 'Para los efectos administrativos, la Direccion de Obras Municipales llevara un Registro Publico de los permisos que se otorguen para la extraccion de aridos',
#      'labels': []},
#     '002c530_105': {'text': 'Este Registro sera ordenado numericamente y correspondera al numero del decreto alcaldicio, en el orden que sean otorgados los permisos',
#      'labels': []},
#     '002c530_106': {'text': 'Con el objeto de proteger el medio ambiente y de cautelar los intereses municipales, la Ilustre Municipalidad implementara un sistema de fiscalizacion de los procedimientos tecnicos de extraccion y del volumen de aridos extraidos revisando las guias de despacho y las facturas emitidas por el beneficiario de un permiso',
#      'labels': []},
#     '002c530_107': {'text': 'La presente Ordenanza queda sujeta a la fiscalizacion de la Direccion General de Aguas, Direccion de Obras Hidraulicas, Direccion de Obras Municipales, los inspectores municipales y carabineros de Chile, quienes podran recibir las denuncias, o en su caso denunciar el incumplimiento de las obligaciones y prohibiciones establecidas en la presente Ordenanza',
#      'labels': []},
#     '002c530_108': {'text': 'El Tribunal competente para conocer de las infracciones a esta Ordenanza sera el Juzgado de Policia Local de la comuna de Panquehue',
#      'labels': []}}},
#   'DISPOSICIONES GENERALES': {'tags': [],
#    'sentences': {'002c530_125': {'text': 'La presente Ordenanza debera ser aprobada por el Concejo Municipal, igual procedimiento regira para sus modificaciones',
#      'labels': []},
#     '002c530_126': {'text': 'Esta Ordenanza regira a contar de su promulgacion, previa publicacion en el Diario Oficial',
#      'labels': []},
#     '002c530_127': {'text': 'Esta Ordenanza tendra aplicacion en todo lo que no contravenga lo establecido en el articulo 10° letra de la ley 19,300 y sus modificaciones posteriores',
#      'labels': []},
#     '002c530_128': {'text': 'Los permisos constituidos con anterioridad a esta Ordenanza, se sujetaran a sus preceptos, sin embargo en lo relativo al  "DEL TERMINO DEL PERMISO, DE LAS SANCIONES Y DE LOS PROCEDIMIENTOS DE FISCALIZACION" se aplicara In Actum',
#      'labels': []}}}}}

# %% [markdown]
# #### Dictionary items sorted by occurrence

# %%
dict( sorted(bag_of_words.items(), key=operator.itemgetter(1),reverse=True))

# %% [markdown]
# #### Dictionary items sorted by heading text

# %%
for k in sorted(bag_of_words):
    print(k, ":", bag_of_words[k])
