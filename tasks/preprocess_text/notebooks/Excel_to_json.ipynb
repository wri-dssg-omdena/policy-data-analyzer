# %% [markdown]
# # Structuring excell sheet info into json

# %% [markdown]
# ## Imports

# %%
from pathlib import Path
import json
import pandas as pd

# %% [markdown]
# ## Loading original data form excel

# %%
path = Path("../input/")
filename = "WRI Policy Tags Complete File phrases extraction all.xlsx"
file = path / filename
df = pd.read_excel(file)
# Out:
#                                             Document  \
# 0  2019 ACUERDO por el que se emiten los Lineamie...
# 1  2019 ACUERDO por el que se emiten los Lineamie...
# 2  2019 ACUERDO por el que se emiten los Lineamie...
# 3  2019 ACUERDO por el que se emiten los Lineamie...
# 4  2019 ACUERDO por el que se emiten los Lineamie...
#
#                                        Original Text  \
# 0  Generar empleo y garantizara la población camp...
# 1  \nEl Programa incentivará a los sujetos agrari...
# 2  Los sujetos agrarios beneficiados por el progr...
# 3  El sujeto de derecho, recibirá un apoyo económ...
# 4  El sujeto de derecho, recibirá en especie las ...
#
#   Relevant Sentences (for Environment, Incentives, Land Type)   \
# 0  Generar empleo y garantizara la población camp...
# 1  \nEl Programa incentivará a los sujetos agrari...
# 2  Los sujetos agrarios beneficiados por el progr...
# 3  El sujeto de derecho, recibirá un apoyo económ...
# 4  El sujeto de derecho, recibirá en especie las ...
#
#   Relevant Phrases (for Environment, Incentives, Land Type)   \
# 0  garantizara la población campesina el bienesta...
# 1  incentivará a los sujetos agrarios a establece...
# 2  Los sujetos agrarios beneficiados por el progr...
# 3   recibirá un apoyo económico de $5,000.00 (Cin...
# 4  recibirá en especie las plantas necesarias par...
#
#                                 Incentive Instrument  \
# 0  Direct payment (PES), Credit, Technical assist...
# 1  Direct payment (PES), Credit, Technical assist...
# 2                     Supplies, Technical assistance
# 3                              Direct payment (PES)
# 4                                         Supplies
#
#                 Land Use Type   Category     Unique Policy #  \
# 0  Forest, Agriculture (Crop)  Incentive  1 (Sembrando Vida)
# 1  Forest, Agriculture (Crop)  Incentive  1 (Sembrando Vida)
# 2  Forest, Agriculture (Crop)  Incentive  1 (Sembrando Vida)
# 3  Forest, Agriculture (Crop)  Incentive  1 (Sembrando Vida)
# 4  Forest, Agriculture (Crop)  Incentive  1 (Sembrando Vida)
#
#                                            Key words
# 0  insumo, crédito, capacitación, asistencia técnica
# 1                                         incentivar
# 2  apoyo económico, apoyos en especie, insumos, h...
# 3                                              pesos
# 4                                            recibir

# %%
print(df.shape)
df
# Out:
# (103, 9)
#                                               Document  \
# 0    2019 ACUERDO por el que se emiten los Lineamie...
# 1    2019 ACUERDO por el que se emiten los Lineamie...
# 2    2019 ACUERDO por el que se emiten los Lineamie...
# 3    2019 ACUERDO por el que se emiten los Lineamie...
# 4    2019 ACUERDO por el que se emiten los Lineamie...
# ..                                                 ...
# 98   2007 Decreto Nº 223 - Ley para la Conservación...
# 99   2007 Decreto Nº 223 - Ley para la Conservación...
# 100  2007 Decreto Nº 223 - Ley para la Conservación...
# 101  2007 Decreto Nº 223 - Ley para la Conservación...
# 102                   2002 Ley de Ciencia y Tecnología
#
#                                          Original Text  \
# 0    Generar empleo y garantizara la población camp...
# 1    \nEl Programa incentivará a los sujetos agrari...
# 2    Los sujetos agrarios beneficiados por el progr...
# 3    El sujeto de derecho, recibirá un apoyo económ...
# 4    El sujeto de derecho, recibirá en especie las ...
# ..                                                 ...
# 98   Quienes aprovechen tierras de pastoreo y opten...
# 99   De los apoyos e incentivos\nArtículo 53.- La S...
# 100  Generación y transferencia de tecnologías, for...
# 101  Los municipios y las delegaciones de las depen...
# 102  El Ejecutivo Federal, por conducto de las Secr...
#
#     Relevant Sentences (for Environment, Incentives, Land Type)   \
# 0    Generar empleo y garantizara la población camp...
# 1    \nEl Programa incentivará a los sujetos agrari...
# 2    Los sujetos agrarios beneficiados por el progr...
# 3    El sujeto de derecho, recibirá un apoyo económ...
# 4    El sujeto de derecho, recibirá en especie las ...
# ..                                                 ...
# 98   Quienes aprovechen tierras de pastoreo y opten...
# 99   De los apoyos e incentivos;\n La Secretaría fo...
# 100  Generación y transferencia de tecnologías, for...
# 101  Los municipios y las delegaciones de las depen...
# 102  El Ejecutivo Federal, por conducto de las Secr...
#
#     Relevant Phrases (for Environment, Incentives, Land Type)   \
# 0    garantizara la población campesina el bienesta...
# 1    incentivará a los sujetos agrarios a establece...
# 2    Los sujetos agrarios beneficiados por el progr...
# 3     recibirá un apoyo económico de $5,000.00 (Cin...
# 4    recibirá en especie las plantas necesarias par...
# ..                                                 ...
# 98   Quienes aprovechen tierras de pastoreo;\n cont...
# 99   apoyos e incentivos;\n sistema coherente y suf...
# 100  Generación y transferencia de tecnologías, for...
# 101   medidas económicas y financieras para el fome...
# 102   Secretarías de Hacienda y Crédito Público, de...
#
#                                   Incentive Instrument  \
# 0    Direct payment (PES), Credit, Technical assist...
# 1    Direct payment (PES), Credit, Technical assist...
# 2                       Supplies, Technical assistance
# 3                                Direct payment (PES)
# 4                                           Supplies
# ..                                                 ...
# 98                Technical assistance, Direct payment
# 99                Technical assistance, Direct payment
# 100               Technical assistance, Direct payment
# 101                                            Unknown
# 102                                            Unknown
#
#                                          Land Use Type               Category  \
# 0                           Forest, Agriculture (Crop)              Incentive
# 1                           Forest, Agriculture (Crop)              Incentive
# 2                           Forest, Agriculture (Crop)              Incentive
# 3                           Forest, Agriculture (Crop)              Incentive
# 4                           Forest, Agriculture (Crop)              Incentive
# ..                                                 ...                    ...
# 98   Forest, Agriculture (Crop), Agriculture (Pasture)  Incentive (Intention)
# 99   Forest, Agriculture (Crop), Agriculture (Pasture)  Incentive (Intention)
# 100  Forest, Agriculture (Crop), Agriculture (Pasture)  Incentive (Intention)
# 101  Forest, Agriculture (Crop), Agriculture (Pasture)  Incentive (Intention)
# 102                                            Unknown  Incentive (Intention)
#
#                                        Unique Policy #  \
# 0                                   1 (Sembrando Vida)
# 1                                   1 (Sembrando Vida)
# 2                                   1 (Sembrando Vida)
# 3                                   1 (Sembrando Vida)
# 4                                   1 (Sembrando Vida)
# ..                                                 ...
# 98   5 (Ley para la Conservación y Restauración de ...
# 99   5 (Ley para la Conservación y Restauración de ...
# 100  5 (Ley para la Conservación y Restauración de ...
# 101  5 (Ley para la Conservación y Restauración de ...
# 102                                 6 (Ley de Ciencia)
#
#                                              Key words
# 0    insumo, crédito, capacitación, asistencia técnica
# 1                                           incentivar
# 2    apoyo económico, apoyos en especie, insumos, h...
# 3                                                pesos
# 4                                              recibir
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
#
# [103 rows x 9 columns]
